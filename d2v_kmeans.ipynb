# %%
import os
import gensim
from gensim import corpora, models
import smart_open 
import numpy as np
from numpy import random
random.seed(555)
from scipy.cluster.vq import vq, kmeans, whiten
from sklearn.decomposition import TruncatedSVD
from collections import defaultdict
# Out:
# C:\Users\lisrba\Anaconda3\lib\site-packages\gensim\utils.py:855: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# 檔案路徑
amazon_corpus_path = "C:" + os.sep + "temp" + os.sep + "BLACK-DECKER.csv"

# %%
# 斷詞 & 標籤
def read_corpus(fname, tokens_only=False):
    with smart_open.smart_open(fname, encoding="iso-8859-1") as f:
        for i, line in enumerate(f):
            if tokens_only:
                yield gensim.utils.simple_preprocess(line)
            else:
                # For training data, add tags
                yield gensim.models.doc2vec.LabeledSentence(gensim.utils.simple_preprocess(line), ['SENT_%s' % i])

# %%
# 訓練組與測試組
train_corpus = list(read_corpus(amazon_corpus_path))
test_corpus = list(read_corpus(amazon_corpus_path, tokens_only=True))

# %%
train_corpus[:2]
# Out:
# [LabeledSentence(words=['ve', 'owned', 'some', 'type', 'of', 'dustbuster', 'handvac', 'for', 'the', 'last', 'twenty', 'years', 'and', 'don', 'think', 've', 'ever', 'ever', 'had', 'one', 'that', 'didn', 'hate', 'too', 'little', 'suction', 'power', 'not', 'enough', 'charge', 'time', 'the', 'suction', 'nozzle', 'is', 'awkward', 'to', 'use', 'and', 'the', 'batteries', 'are', 'always', 'dead', 'after', 'couple', 'minutes', 'can', 'keep', 'them', 'plugged', 'into', 'the', 'wall', 'all', 'the', 'time', 'but', 'that', 'kills', 'the', 'battery', 'and', 'wastes', 'electricity', 'have', 'found', 'it', 'much', 'more', 'effective', 'to', 'just', 'use', 'the', 'suction', 'hose', 'on', 'my', 'upright', 'even', 'though', 'that', 'means', 'lugging', 'my', 'vacuum', 'around', 'so', 'decided', 'to', 'see', 'what', 'is', 'new', 'in', 'handvac', 'technology', 'and', 'if', 'they', 'have', 'improved', 'at', 'all', 'over', 'the', 'last', 'ten', 'years', 'fortunately', 'can', 'say', 'that', 'they', 'have', 'the', 'black', 'and', 'decker', 'lithium', 'ion', 'dustbuster', 'is', 'the', 'same', 'handvac', 'as', 'the', 'black', 'decker', 'chv', 'dustbuster', 'volt', 'cordless', 'cyclonic', 'hand', 'vac', 'except', 'it', 'contains', 'lithium', 'ion', 'lib', 'battery', 'whereas', 'the', 'standard', 'chv', 'contains', 'nickel', 'cadmium', 'ni', 'cd', 'battery', 'if', 'you', 're', 'trying', 'to', 'decide', 'between', 'the', 'two', 'devices', 'would', 'recommend', 'this', 'lithium', 'ion', 'model', 'due', 'to', 'the', 'advantages', 'of', 'the', 'battery', 'higher', 'energy', 'density', 'this', 'means', 'that', 'the', 'lib', 'battery', 'can', 'hold', 'more', 'energy', 'per', 'volume', 'in', 'this', 'case', 'the', 'chv', 'holds', 'about', 'twice', 'the', 'amount', 'of', 'energy', 'as', 'the', 'chv', 'greater', 'power', 'density', 'this', 'refers', 'to', 'bursts', 'of', 'power', 'the', 'battery', 'is', 'capable', 'it', 'works', 'well', 'when', 'combined', 'with', 'the', 'higher',
'the', 'future', 'to', 'see', 'just', 'how', 'long', 'it', 'can', 'run', 'on', 'full', 'charge', 'the', 'fact', 'that', 'it', 'is', 'lithium', 'ion', 'is', 'great', 'that', 'it', 'should', 'last', 'longer', 'and', 'perform', 'better', 'than', 'previous', 'nicad', 'batteries', 'after', 'few', 'years', 'the', 'old', 'style', 'dustbusters', 'just', 'don', 'take', 'charge', 'well', 'fyi', 'used', 'two', 'fat', 'shaped', 'hooks', 'mounted', 'few', 'inches', 'apart', 'on', 'the', 'wall', 'to', 'create', 'platform', 'for', 'the', 'vac', 'll', 'post', 'picture', 'if', 'don', 'see', 'similar', 'pic'], tags=['SENT_1'])]

# %%
# 建模
model = models.Doc2Vec(alpha=0.025, min_alpha=0.025)  # use fixed learning rate
model.build_vocab(train_corpus)

# %%
# 學習（學習速率遞減）
epoch = 10
for _ in range(epoch):
    model.train(train_corpus)
    model.alpha -= 0.002  # decrease the learning rate
    model.min_alpha = model.alpha  # fix the learning rate, no decay
print ('done training')
# Out:
# done training

# %%
# 儲存模型
model.save("C:" + os.sep + "temp" + os.sep +"try.d2v")

# %%
# 載入模型
model = gensim.models.Doc2Vec.load("C:" + os.sep + "temp" + os.sep +"try.d2v")

# %%
# 把每篇文章的向量塞進矩陣裡面
lenx=len(train_corpus)
leny=len(model.infer_vector(train_corpus[0].words))
print(lenx,leny)
a = np.zeros((lenx,leny))
for i_sent in range(len(train_corpus)):
    a[i_sent,:] = model.infer_vector(test_corpus[i_sent])
print(a[:2])
# Out:
# 9362 100
# [[ 0.71777129 -0.2968137   1.74602664 -0.30613655 -2.69307899 -0.43241048
#    1.12778926  0.26941639  0.38615209 -0.41628286 -0.76238769 -0.09876788
#   -1.12781191 -0.85713768  0.62653118 -1.49333346 -0.08015751 -1.22722721
#   -0.1390937   1.40933192 -0.89079672  0.27064511  1.13283479 -0.26122171
#    2.10870814 -0.77381921  1.96802855  1.11911893 -1.14450192 -0.45961979
#    0.34697917 -0.52431965 -0.84373212 -0.51649266  0.47457075 -0.69516867
#   -0.10425612  0.79353291 -0.60305548 -0.57055169 -0.22832471  1.01737738
#    2.06921506  0.14518255  0.92332911  0.16651233 -0.20290974  2.01038456
#   -1.28398776 -0.95935118  1.339203   -1.23555207 -0.53434384 -1.69657874
#   -1.3845191  -0.3434324  -0.25409126 -0.57073379  0.04967006  0.74818397
#    0.76053321 -2.11183715  0.38309515  0.24115428  0.80337095  0.87139839
#   -0.26672438  0.00822973 -0.80505943  0.87872058 -0.78241342  0.0992297
#    0.70013189  1.19461274  0.63134563  1.00228322  1.96896958 -0.0401099
#   -0.30581975 -1.25995636  0.21811023  2.22086978  1.09347641 -0.74970579
#   -0.76243383  0.16142106 -0.4309276   0.50526577  0.14083217  0.58221763
#    0.63723183  0.08197775 -0.81761968 -0.6551984   0.72339386  1.10233641
#   -0.08197992  0.47316909  0.1789819   0.77284104]
#  [ 0.04132375  0.23081121 -0.02715294  0.19273436 -0.42224783 -0.35056433
#    0.27360505 -0.34640145 -0.2775552   0.42734551 -1.31363356  0.13163629
#   -0.12816073 -1.09344101  0.31346348  0.12124172  0.32656971 -0.49066383
#   -0.02132419  0.09182074 -0.42308542 -0.12381197  0.24042478 -0.24197595
#    0.48993644 -0.90845251 -0.44847903 -0.3734422  -0.02196096 -0.01565605
#   -0.0421328   0.18860927 -0.60320252  0.47478068  0.1327353   0.01099083
#   -0.51101655  0.06709961  0.92737883  0.48990992 -0.06119496  0.27510506
#    0.21372052 -0.63051325  0.38689527  0.26930702 -0.55032742 -0.79999238
#    0.21388705 -0.81360483  0.01944277 -0.27911288 -0.5906226  -0.04468016
#   -0.41215241  0.10049406  0.69464749  0.11262937  0.14112258 -0.35765588
#    0.24131449  0.02365629  0.08635575 -0.25462273  0.2534973   0.25983799
#    0.20888843  0.0454847  -0.3386319  -0.36177009 -0.65057707 -0.18983686
#   -0.3206934  -0.05784809 -0.39522454 -0.54321033  0.91246909  0.20892261
#   -0.11748882 -0.56393588  0.04556644  0.05302723  1.02679145  0.73125941
#   -0.15452862 -0.60861552 -0.15695553  0.18132077 -0.12498043  0.41731465
#   -0.07103474  0.01547964 -0.0587742  -0.43993118  0.34605992  0.17116414
#    0.32890949 -0.12206427  0.35353222 -0.03690451]]

# %%
# 正規化（？）
sim_matrix = whiten(a)

# %%
# Kmeans分7群（7是隨便挑的，之後要用elbow method或輪廓係數找最佳群組數）
centroid, destortion = kmeans(sim_matrix, 7, iter=100, thresh=1e-05)
labels, dist = vq(sim_matrix, centroid)
print(labels[0])
# Out:
# 2

# %%
# 按標籤將屬於該群的文章INDEX存起來

cluster0 = []
cluster1 = []
cluster2 = []
cluster3 = []
cluster4 = []
cluster5 = []
cluster6 = []

for i in range(len(labels)):
    if (labels[i] == 0):
        cluster0.append(i);
    elif (labels[i] == 1):
        cluster1.append(i);
    elif (labels[i] == 2):
        cluster2.append(i);
    elif (labels[i] == 3):
        cluster3.append(i);
    elif (labels[i] == 4):
        cluster4.append(i);
    elif (labels[i] == 5):
        cluster5.append(i);
    elif (labels[i] == 6):
        cluster6.append(i);

# %%
# 標籤為0的群組文章INDEX
print(cluster0)
# Out:
# [59, 911, 2336, 2417, 2588, 2984, 3043, 3142, 3160, 3260, 3303, 3306, 3322, 3343, 3362, 3367, 3372, 3390, 3396, 3397, 3400, 3420, 3425, 3429, 3437, 3440, 3456, 3458, 3467, 3469, 3483, 3484, 3488, 3510, 3527, 3531, 3544, 3558, 3559, 3562, 3569, 3571, 3581, 3583, 3585, 3595, 3601, 3602, 3604, 3666, 3767, 3829, 3904, 4112, 4257, 4301, 4337, 4528, 4549, 4550, 4605, 4704, 4721, 4733, 4737, 4759, 4770, 4804, 4841, 4846, 4848, 4898, 4903, 4907, 4940, 5023, 5024, 5026, 5037, 5038, 5125, 5180, 5190, 5202, 5225, 5253, 5267, 5298, 5326, 5371, 5392, 5400, 5457, 5478, 5484, 5489, 5503, 5538, 5561, 5628, 5641, 5664, 5689, 5751, 5815, 5820, 5848, 5849, 5854, 5856, 5896, 5906, 5910, 5949, 5953, 5974,
180, 8181, 8191, 8192, 8193, 8195, 8196, 8197, 8202, 8203, 8207, 8208, 8210, 8211, 8215, 8219, 8223, 8227, 8229, 8231, 8232, 8234, 8236, 8247, 8249, 8254, 8257, 8259, 8260, 8264, 8271, 8276, 8277, 8280, 8283, 8294, 8298, 8299, 8300, 8304, 8307, 8310, 8313, 8317, 8319, 8326, 8328, 8330, 8332, 8336, 8338, 8341, 8345, 8346, 8354, 8356, 8358, 8360, 8361, 8363, 8365, 8366, 8373, 8374, 8381, 8383, 8384, 8386, 8387, 8389, 8393, 8395, 8401, 8404, 8406, 8408, 8411, 8414, 8418, 8419, 8422, 8425, 8428, 8430, 8431, 8435, 8437, 8440, 8450, 8451, 8452, 8455, 8457, 8459, 8460, 8464, 8465, 8467, 8469, 8471, 8475, 8481, 8484, 8487, 8490, 8496, 8502, 8503, 8504, 8509, 8513, 8516, 8518, 8520, 8521, 8522, 8525, 8526, 8528, 8531, 8536, 8537, 8538, 8539, 8540, 8542, 8546, 8548, 8551, 8555, 8558, 8565, 8567, 8568, 8569, 8585, 8586, 8587, 8589, 8593, 8596, 8598, 8605, 8608, 8609, 8612, 8615, 8616, 8618, 8619, 8627, 8630, 8631, 8632, 8634, 8636, 8641, 8642, 8645, 8647, 8652, 8653, 8655, 8657, 8660, 8665, 8666, 8668,  ...

# %%
# 按文章INDEX將文章分群

corpus_clu0 = []
corpus_clu1 = []
corpus_clu2 = []
corpus_clu3 = []
corpus_clu4 = []
corpus_clu5 = []
corpus_clu6 = []

for j in range(len(cluster0)):
    corpus_clu0.append(train_corpus[cluster0[j]]);
for j in range(len(cluster1)):
    corpus_clu1.append(train_corpus[cluster1[j]]);    
for j in range(len(cluster2)):
    corpus_clu2.append(train_corpus[cluster2[j]]);
for j in range(len(cluster3)):
    corpus_clu3.append(train_corpus[cluster3[j]]); 
for j in range(len(cluster4)):
    corpus_clu4.append(train_corpus[cluster4[j]]);     
for j in range(len(cluster5)):
    corpus_clu5.append(train_corpus[cluster5[j]]);
for j in range(len(cluster6)):
    corpus_clu6.append(train_corpus[cluster6[j]]);

# %%
# 看看第0群的第0篇文章內容與標籤
print(corpus_clu0[0])
# Out:
# LabeledSentence(['have', 'it', 'in', 'order', 'but', 'it', 'funny', 'how', 'the', 'first', 'picture', 'shows', 'dirt', 'on', 'narrow', 'location', 'but', 'that', 'the', 'physical', 'size', 'of', 'the', 'vacuum', 'is', 'not', 'able', 'to', 'physically', 'fit', 'to', 'clean', 'the', 'whole', 'mess'], ['SENT_59'])

# %%
# 看看第0群的第0篇文章標籤
print(corpus_clu0[0].tags)
# Out:
# ['SENT_59']

# %%
# 看看第0群的第0篇文章內容
print(corpus_clu0[0].words)
# Out:
# ['have', 'it', 'in', 'order', 'but', 'it', 'funny', 'how', 'the', 'first', 'picture', 'shows', 'dirt', 'on', 'narrow', 'location', 'but', 'that', 'the', 'physical', 'size', 'of', 'the', 'vacuum', 'is', 'not', 'able', 'to', 'physically', 'fit', 'to', 'clean', 'the', 'whole', 'mess']

# %%
# 只挑文章內容存進去各個群組
corpus_clu0_wordlist = []
corpus_clu1_wordlist = []
corpus_clu2_wordlist = []
corpus_clu3_wordlist = []
corpus_clu4_wordlist = []
corpus_clu5_wordlist = []
corpus_clu6_wordlist = []

for i in range(len(corpus_clu0)):
    corpus_clu0_wordlist.append(corpus_clu0[i].words)
for i in range(len(corpus_clu1)):
    corpus_clu1_wordlist.append(corpus_clu1[i].words)
for i in range(len(corpus_clu2)):
    corpus_clu2_wordlist.append(corpus_clu2[i].words)
for i in range(len(corpus_clu3)):
    corpus_clu3_wordlist.append(corpus_clu3[i].words)
for i in range(len(corpus_clu4)):
    corpus_clu4_wordlist.append(corpus_clu4[i].words)
for i in range(len(corpus_clu5)):
    corpus_clu5_wordlist.append(corpus_clu5[i].words)
for i in range(len(corpus_clu6)):
    corpus_clu6_wordlist.append(corpus_clu6[i].words)

# %%
# 看看第0個群組的前2篇文章
corpus_clu0_wordlist[:2]
# Out:
# [['have',
#   'it',
#   'in',
#   'order',
#   'but',
#   'it',
#   'funny',
#   'how',
#   'the',
#   'first',
#   'picture',
#   'shows',
#   'dirt',
#   'on',
#   'narrow',
#   'location',
#   'but',
#   'that',
#   'the',
#   'physical',
#   'size',
#   'of',
#   'the',
#   'vacuum',
#   'is',
#   'not',
#   'able',
#   'to',
#   'physically',
#   'fit',
#   'to',
#   'clean',
#   'the',
#   'whole',
#   'mess'],
#  ['power',
#   'is',
#   'great',
#   'holds',
#   'good',
#   'charge',
#   'my',
#   'previous',
#   'one',
#   'had',
#   'fixture',
#   'to',
#   'hold',
#   'it',
#   'on',
#   'the',
#   'wall',
#   'for',
#   'this',
#   'one',
#   'the',
#   'recharging',
#   'base',
#   'sits',
#   'on',
#   'the',
#   'floor',
#   'and',
#   'if',
#   'knocked',
#   'over',
#   'or',
#   'set',
#   'slightly',
#   'off',
#   'the',
#   'base',
#   'it',
#   'doesn',
#   'charge']]

# %%
# 把只出現一次的字移除
from collections import defaultdict
from pprint import pprint  # pretty-printer

def remove_less_than_one(corpus_clu_wordlist):
    frequency = defaultdict(int)
    for text in corpus_clu_wordlist:
         for token in text:
            frequency[token] += 1

    corpus_clu_wordlist = [[token for token in text if frequency[token] > 1]
                             for text in corpus_clu_wordlist]
    return corpus_clu_wordlist;

# %%
remove_less_than_one(corpus_clu0_wordlist)
remove_less_than_one(corpus_clu1_wordlist)
remove_less_than_one(corpus_clu2_wordlist)
remove_less_than_one(corpus_clu3_wordlist)
remove_less_than_one(corpus_clu4_wordlist)
remove_less_than_one(corpus_clu5_wordlist)
remove_less_than_one(corpus_clu6_wordlist)
# Out:
# [['we',
#   'have',
#   'been',
#   'buying',
#   'new',
#   'handheld',
#   'vacuum',
#   'every',
#   'months',
#   'for',
#   'the',
#   'past',
#   'years',
#   'or',
#   'so',
#   'typically',
#   'after',
#   'year',
#   'the',
#   'performance',
#   'is',
#   'so',
#   'poor',
#   'due',
#   'to',
#   'battery',
#   'recharging',
#   'issues',
#   'that',
#   'the',
#   'vacs',
#   'become',
#   'useless',
#   'after',
#   'reading',
#   'the',
#   'reviews',
#   'on',
#   'amazon',
#   'about',
#   'this',
#   'one',
#   'decided',
#   'to',
#   'take',
#   'chance',
#   'on',
#   'it',
#   'even',
#   'though',
#   'typically',
#   'try',
#   'to',
#   'find',
#   'higher',
#   'voltage',
#   'items',
#   'won',
#   'go',
#   'into',
#   'much',
#   'detail',
#   'about',
#   'the',
#   'product',
#   'because',
#   'others',
#   'have',
#   'done',
#   'good',
#   'job',
#   'explaining',
#   'the',
#   'features',
#   'for',
#   'us',
#   'it',
#   'works',
#   'very',
#   'well',
#   'it',
#   'sits',
#   'on',
#   'its',
#   'charger',
#   'inside',
#   'floor',
#   'level',
#   'kitchen',
#   'cabinet',
#   'where',
#   'it',
#   'is',
#   'easy',
#   'to',
#   'remove',
#   'from',
#   'the',
#   'charger',
#   'and',
#   'easy',
#   'to',
#   'return',
#   'the',
#   'blue',
#   'light',
#   'bothers',
#   'no',
#   'one',
#   'my',
#   'wife',
#   'and',
#   'children',
#   'use',
#   'it',
#   'often',
#   'but',
#   'only',
#   'once',
#   'has',
#   'anyone',
#   'used',
#   'it',
#   'long',
#   'enough',
#   'to',
#   'where',
#   'it',
#   'had',
#   'to',
#   'be',
#   'recharged',
#   'to',
#   'continue',
#   'this',
#   'is',
#   'the',
#   'of',
#   'the',
#   'performance',
#   'we',
#   'have',
#   'seen',
#   'with',
#   'all',
#   'the',
#   'other',
#   'handheld',
#   'vacuums',
#   'we',
#   'have',
#   'owned',
#   'last',
#   'week',
#   'after',
#   'using',
#   'the',
#   'vacuum',
#   'for',
#   'about',
#   'months',
#   'it',
#   'just',
#   'stopped',
#   'no',
#   'performance',
#   'up',
#   'to',
#   'the',
#   'no',
#   'of',
#   'any',
#   'kind',
#   'the',
#   'unit',
#   'and',
#   'found',
#   'it',
#   'to',
#   'be',
#   'very',
#   'simply',
#   'and',
#   'designed',
#   'as',
#   'such',
#   'motor',
#   'battery',
#   'pack',
#   'charging',
#   'terminal',
#   'light',
#   'and',
#   'on',
#   'off',
#   'switch',
#   'the',
#   'only',
#   'other',
#   'component',
#   'is',
#   'small',
#   'amp',
#   'breaker',
#   'between',
#   'the',
#   'switch',
#   'and',
#   'the',
#   'power',
#   'it',
#   'is',
#   'very',
#   'small',
#   'single',
#   'use',
#   'item',
#   'that',
#   'apparently',
#   'can',
#   'only',
#   'be',
#   'ordered',
#   'from',
#   'order',
#   'the',
#   'item',
#   'cannot',
#   'be',
#   'replaced',
#   'with',
#   'another',
#   'breaker',
#   'of',
#   'similar',
#   'because',
#   'there',
#   'is',
#   'not',
#   'enough',
#   'room',
#   'in',
#   'the',
#   'vacuum',
#   'for',
#   'anything',
#   'other',
#   'than',
#   'this',
#   'small',
#   'part',
#   'contacted',
#   'my',
#   'good',
#   'friends',
#   'at',
#   'black',
#   'and',
#   'decker',
#   'to',
#   'that',
#   'they',
#   'sell',
#   'me',
#   'replacement',
#   'but',
#   'they',
#   'they',
#   'noted',
#   'that',
#   'the',
#   'vacuum',
#   'was',
#   'still',
#   'under',
#   'warranty',
#   'but',
#   'that',
#   'had',
#   'the',
#   'warranty',
#   'by',
#   'opening',
#   'it',
#   'do',
#   'not',
#   'know',
#   'the',
#   'purpose',
#   'of',
#   'this',
#   'breaker',
#   'other',
#   'than',
#   'to',
#   'stop',
#   'running',
#   'vacuum',
#   'if',
#   'certain',
#   'amp',
#   'or',
#   'is',
#   'reached',
#   'but',
#   'once',
#   'that',
#   'happens',
#   'or',
#   'if',
#   'the',
#   'breaker',
#   'just',
#   'fails',
#   'the',
#   'results',
#   'are',
#   'even',
#   'though',
#   'all',
#   'of',
#   'the',
#   'other',
#   'components',
#   'may',
#   'be',
#   'in',
#   'perfect',
#   'condition',
#   'with',
#   'this',
#   'in',
#   'mind',
#   'wonder',
#   'if',
#   'it',
#   'is',
#   'likely',
#   'that',
#   'all',
#   'of',
#   'your',
#   'vacuums',
#   'will',
#   'eventually',
#   'fail',
#   'because',
#   'of',
#   'the',
#   'breaker',
#   'btw',
#   'it',
#   'seems',
#   'they',
#   'could',
#   'have',
#   'used',
#   'slightly',
#   'larger',
#   'breaker',
#   'at',
#   'cost',
#   'of',
#   'less',
#   'than',
#   'per',
#   'unit',
#   'for',
#   'the',
#   'breaker',
#   'with',
#   'slight',
#   'design',
#   'to',
#   'allow',
#   'the',
#   'consumer',
#   'access',
#   'to',
#   'the',
#   'button',
#   'for',
#   'your',
#   'information'],
#  ['pretty',
#   'sweet',
#   'little',
#   'vacuum',
#   'bought',
#   'this',
#   'specifically',
#   'for',
#   'cleaning',
#   'dirt',
#   'dog',
#   'hair',
#   'off',
#   'of',
#   'our',
#   'bed',
#   'before',
#   'at',
#   'night',
#   'we',
#   're',
#   'the',
#   'type',
#   'of',
#   'people',
#   'that',
#   'let',
#   'our',
#   'dogs',
#   'of',
#   'them',
#   'play',
#   'around',
#   'on',
#   'the',
#   'bed',
#   'during',
#   'the',
#   'day',
#   'all',
#   'they',
#   'want',
#   'they',
#   'often',
#   'track',
#   'in',
#   'lots',
#   'of',
#   'dirt',
#   'and',
#   'shed',
#   'everywhere',
#   'so',
#   'the',
#   'bed',
#   'can',
#   'quickly',
#   'become',
#   'can',
#   'say',
#   'that',
#   'am',
#   'more',
#   'than',
#   'pleased',
#   'with',
#   'this',
#   'purchase',
#   'it',
#   'quickly',
#   'and',
#   'easily',
#   'gets',
#   'everything',
#   'off',
#   'the',
#   'sheets',
#   'before',
#   'time',
#   'if',
#   'it',
#   'helps',
#   'we',
#   'use',
#   'microfiber',
#   'sheets',
#   'that',
#   'dog',
#   'hair',
#   'does',
#   'not',
#   'tend',
#   'to',
#   'stick',
#   'to',
#   'as',
#   'some',
#   'others',
#   'have',
#   'mentioned',
#   'it',
#   'is',
#   'fairly',
#   'noisy',
#   'but',
#   'rather',
#   'that',
#   'than',
#   'it',
#   'blow',
#   'hehehe',
#   'not',
#   'sure',
#   'yet',
#   'how',
#   'feel',
#   'about',
#   'the',
#   'charging',
#   'base',
#   'on',
#   'one',
#   'hand',
#   'it',
#   'super',
#   'easy',
#   'to',
#   'use',
#   'there',
#   'no',
#   'need',
#   'to',
#   'plug',
#   'anything',
#   'in',
#   'you',
#   'just',
#   'set',
#   'the',
#   'vacuum',
#   'on',
#   'the',
#   'pad',
#   'and',
#   'that',
#   'that',
#   'on',
#   'the',
#   'other',
#   'hand',
#   'in',
#   'house',
#   'full',
#   'of',
#   'animals',
#   'have',
#   'to',
#   'keep',
#   'it',
#   'somewhere',
#   'where',
#   'it',
#   'can',
#   'get',
#   'knocked',
#   'over',
#   'seeing',
#   'as',
#   'it',
#   'just',
#   'itself',
#   'on',
#   'the',
#   'charging',
#   'pad',
#   'this',
#   'design',
#   'also',
#   'means',
#   'you',
#   'can',
#   'easily',
#   'wall',
#   'mount',
#   'or',
#   'similar',
#   'the',
#   'charging',
#   'base',
#   'and',
#   'the',
#   'vacuum',
#   'must',
#   'be',
#   'upright',
#   'for',
#   'charging',
#   'the',
#   'battery',
#   'last',
#   'plenty',
#   'long',
#   'for',
#   'general',
#   'use',
#   'actually',
#   'haven',
#   'used',
#   'it',
#   'long',
#   'enough',
#   'for',
#   'it',
#   'to',
#   'run',
#   'out',
#   'of',
#   'battery',
#   'from',
#   'full',
#   'charge',
#   'so',
#   'not',
#   'exactly',
#   'sure',
#   'what',
#   'the',
#   'run',
#   'time',
#   'is',
#   'yet',
#   'the',
#   'nozzle',
#   'can',
#   'be',
#   'extended',
#   'by',
#   'pulling',
#   'out',
#   'on',
#   'the',
#   'gray',
#   'part',
#   'this',
#   'means',
#   'you',
#   'won',
#   'lose',
#   'the',
#   'attachments',
#   'long',
#   'story',
#   'short',
#   'would',
#   'highly',
#   'recommend',
#   'this',
#   'to',
#   'anyone',
#   'like',
#   'another',
#   'reviewer',
#   'remember',
#   'the',
#   'original',
#   'dustbuster',
#   'of',
#   'my',
#   'and',
#   'this',
#   'technology',
#   'sure',
#   'has',
#   'come',
#   'long',
#   'way'],
#  ['bought',
#   'this',
#   'item',
#   'when',
#   'there',
#   'was',
#   'off',
#   'discount',
#   'on',
#   'black',
#   'decker',
#   'purchase',
#   'am',
#   'so',
#   'glad',
#   'did',
#   'because',
#   'this',
#   'product',
#   'is',
#   'better',
#   'than',
#   'my',
#   'old',
#   'dustbuster',
#   'that',
#   'worked',
#   'for',
#   'over',
#   'years',
#   'this',
#   'new',
#   'black',
#   'and',
#   'decker',
#   'handheld',
#   'vacuum',
#   'is',
#   'truly',
#   'amazing',
#   'it',
#   'has',
#   'even',
#   'taken',
#   'the',
#   'place',
#   'of',
#   'my',
#   'dustpan',
#   'sweep',
#   'into',
#   'small',
#   'pile',
#   'and',
#   'use',
#   'this',
#   'product',
#   'to',
#   'suck',
#   'up',
#   'every',
#   'of',
#   'dust',
#   'like',
#   'that',
#   'it',
#   'is',
#   'powerful',
#   'and',
#   'that',
#   'the',
#   'small',
#   'brush',
#   'attachment',
#   'that',
#   'flips',
#   'into',
#   'place',
#   'at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'unit',
#   'this',
#   'way',
#   'll',
#   'never',
#   'lose',
#   'the',
#   'attachment',
#   'also',
#   'like',
#   'that',
#   'it',
#   'charges',
#   'standing',
#   'up',
#   'on',
#   'its',
#   'end',
#   'so',
#   'it',
#   'takes',
#   'up',
#   'less',
#   'space',
#   'than',
#   'my',
#   'previous',
#   'model',
#   'all',
#   'in',
#   'all',
#   'couldn',
#   'be'],
#  ['just',
#   'opened',
#   'this',
#   'on',
#   'christmas',
#   'morning',
#   'it',
#   'filthy',
#   'did',
#   'not',
#   'buy',
#   'it',
#   'used',
#   'or',
#   'from',
#   'but',
#   'directly',
#   'from',
#   'amazon',
#   'there',
#   'was',
#   'no',
#   'washable',
#   'filter',
#   'even',
#   'included',
#   'even',
#   'though',
#   'the',
#   'indicates',
#   'that',
#   'one',
#   'is',
#   'provided',
#   'see',
#   'pictures',
#   'also',
#   'no',
#   'directions',
#   'and',
#   'for',
#   'some',
#   'reason',
#   'received',
#   'several',
#   'extra',
#   'attachments',
#   'that',
#   'were',
#   'not',
#   'part',
#   'of',
#   'the',
#   'sale',
#   'and',
#   'are',
#   'not',
#   'even',
#   'to',
#   'this',
#   'particular',
#   'device',
#   'nothing',
#   'good',
#   'to',
#   'say',
#   'about',
#   'this',
#   'experience',
#   'at',
#   'all'],
#  ['have',
#   'the',
#   'ch',
#   'great',
#   'operating',
#   'vac',
#   'did',
#   'the',
#   'job',
#   'well',
#   'but',
#   'didn',
#   'like',
#   'the',
#   'battery',
#   'life',
#   'saw',
#   'the',
#   'high',
#   'ratings',
#   'on',
#   'this',
#   'chv',
#   'so',
#   'had',
#   'to',
#   'have',
#   'it',
#   'even',
#   'though',
#   'it',
#   'is',
#   'twice',
#   'the',
#   'price',
#   'didn',
#   'pay',
#   'attention',
#   'that',
#   'this',
#   'had',
#   'charging',
#   'base',
#   'and',
#   'not',
#   'hang',
#   'on',
#   'the',
#   'wall',
#   'charger',
#   'now',
#   'had',
#   'to',
#   'find',
#   'special',
#   'table',
#   'space',
#   'for',
#   'it',
#   'and',
#   'out',
#   'of',
#   'the',
#   'way',
#   'my',
#   'ch',
#   'hung',
#   'on',
#   'the',
#   'wall',
#   'in',
#   'perfect',
#   'location',
#   'and',
#   'what',
#   'with',
#   'the',
#   'piercing',
#   'blue',
#   'led',
#   'charging',
#   'light',
#   'stuck',
#   'piece',
#   'of',
#   'blue',
#   'tape',
#   'on',
#   'it',
#   'and',
#   'the',
#   'otherwise',
#   'can',
#   'use',
#   'it',
#   'as',
#   'night',
#   'light',
#   'in',
#   'my',
#   'dining',
#   'room',
#   'btw',
#   'it',
#   'is',
#   'great',
#   'working',
#   'vac',
#   'like',
#   'the',
#   'ch',
#   'which',
#   'still',
#   'use',
#   'in',
#   'my',
#   'garage'],
#  ['good',
#   'for',
#   'but',
#   'wish',
#   'it',
#   'was',
#   'stronger',
#   'charger',
#   'possible',
#   'fire',
#   'on',
#   'the',
#   'wire',
#   'slides',
#   'off',
#   'over',
#   'time',
#   'the',
#   'movement',
#   'of',
#   'the',
#   'wire',
#   'causes',
#   'crazy',
#   'green',
#   'to',
#   'and',
#   'even',
#   'took',
#   'video',
#   'but',
#   'amazon',
#   'doesn',
#   'allow',
#   'that',
#   'guess',
#   'was',
#   'lucky',
#   'caught',
#   'this',
#   'problem',
#   'instead',
#   'of',
#   'finding',
#   'out',
#   'the',
#   'hard',
#   'way',
#   'my',
#   'falls',
#   'to',
#   'the',
#   'ground',
#   'quite',
#   'often',
#   'and',
#   'could',
#   'have',
#   'the',
#   'charger',
#   'even',
#   'slightly',
#   'also',
#   'have',
#   'dog',
#   'that',
#   'comes',
#   'in',
#   'my',
#   'room',
#   'time',
#   'to',
#   'time',
#   'that',
#   'could',
#   'have',
#   'been',
#   'hurt',
#   'it',
#   'not',
#   'as',
#   'if',
#   'was',
#   'rough',
#   'with',
#   'the',
#   'charger',
#   'as',
#   'only',
#   'plug',
#   'it',
#   'in',
#   'for',
#   'brief',
#   'periods',
#   'at',
#   'time',
#   'and',
#   'don',
#   'have',
#   'pets',
#   'or',
#   'children',
#   'with',
#   'them'],
#  ['purchased',
#   'chv',
#   'volt',
#   'lithium',
#   'ion',
#   'cordless',
#   'dust',
#   'buster',
#   'as',
#   'christmas',
#   'gift',
#   'for',
#   'my',
#   'mother',
#   'when',
#   'she',
#   'opened',
#   'it',
#   'it',
#   'initially',
#   'appeared',
#   'to',
#   'work',
#   'but',
#   'on',
#   'the',
#   'same',
#   'evening',
#   'that',
#   'we',
#   'opened',
#   'it',
#   'seemed',
#   'to',
#   'be',
#   'having',
#   'trouble',
#   'taking',
#   'full',
#   'charge',
#   'she',
#   'around',
#   'with',
#   'it',
#   'for',
#   'all',
#   'of',
#   'and',
#   'it',
#   'seemed',
#   'to',
#   'work',
#   'little',
#   'finally',
#   'in',
#   'early',
#   'february',
#   'she',
#   'told',
#   'me',
#   'that',
#   'it',
#   'just',
#   'wasn',
#   'working',
#   'at',
#   'all',
#   'it',
#   'home',
#   'and',
#   'the',
#   'led',
#   'blinks',
#   'rapidly',
#   'when',
#   'placed',
#   'on',
#   'the',
#   'charging',
#   'cradle',
#   'from',
#   'the',
#   'manual',
#   'this',
#   'means',
#   'that',
#   'the',
#   'battery',
#   'is',
#   'defective',
#   'it',
#   'is',
#   'past',
#   'the',
#   'day',
#   'return',
#   'limit',
#   'for',
#   'the',
#   'and',
#   'am',
#   'left',
#   'holding',
#   'the',
#   'bag',
#   'can',
#   'send',
#   'it',
#   'back',
#   'to',
#   'with',
#   'shipping',
#   'this',
#   'is',
#   'just',
#   'disappointing',
#   'big',
#   'hassle',
#   'also',
#   'bought',
#   'second',
#   'one',
#   'as',
#   'christmas',
#   'gift',
#   'for',
#   'someone',
#   'else',
#   'and',
#   'that',
#   'one',
#   'to',
#   'be',
#   'working',
#   'ok',
#   'so',
#   'learn',
#   'from',
#   'my',
#   'mistake',
#   'if',
#   'you',
#   'do',
#   'buy',
#   'one',
#   'of',
#   'these',
#   'and',
#   'notice',
#   'any',
#   'initial',
#   'charging',
#   'issues',
#   'send',
#   'it',
#   'back',
#   'immediately',
#   'it',
#   'not',
#   'going',
#   'to',
#   'get',
#   'well',
#   'on',
#   'it',
#   'own'],
#  ['for',
#   'about',
#   'one',
#   'year',
#   'time',
#   'on',
#   'and',
#   'off',
#   'have',
#   'tried',
#   'to',
#   'find',
#   'cordless',
#   'vacuum',
#   'to',
#   'be',
#   'used',
#   'primarily',
#   'in',
#   'my',
#   'car',
#   'knew',
#   'that',
#   'above',
#   'all',
#   'else',
#   'it',
#   'must',
#   'use',
#   'lithium',
#   'battery',
#   'because',
#   'my',
#   'previous',
#   'hand',
#   'vac',
#   'and',
#   'plenty',
#   'of',
#   'other',
#   'devices',
#   'used',
#   'nickel',
#   'cadmium',
#   'batteries',
#   'they',
#   'are',
#   'so',
#   'consistently',
#   'terrible',
#   'that',
#   'refuse',
#   'to',
#   'ever',
#   'buy',
#   'something',
#   'that',
#   'uses',
#   'ni',
#   'cd',
#   'batteries',
#   'again',
#   'my',
#   'last',
#   'hand',
#   'vac',
#   'being',
#   'dirt',
#   'devil',
#   'which',
#   'was',
#   'useable',
#   'for',
#   'about',
#   'minutes',
#   'at',
#   'best',
#   'and',
#   'though',
#   'tried',
#   'to',
#   'maintain',
#   'the',
#   'battery',
#   'properly',
#   'it',
#   'was',
#   'still',
#   'within',
#   'about',
#   'year',
#   'one',
#   'of',
#   'my',
#   'favorite',
#   'to',
#   'shop',
#   'is',
#   'com',
#   'and',
#   'they',
#   'frequently',
#   'sell',
#   'vacuums',
#   'of',
#   'all',
#   'and',
#   'from',
#   'dyson',
#   'had',
#   'bought',
#   'and',
#   'do',
#   'really',
#   'like',
#   'my',
#   'dc',
#   'upright',
#   'ball',
#   'vacuum',
#   'so',
#   'was',
#   'buying',
#   'cordless',
#   'dc',
#   'vacuum',
#   'which',
#   'can',
#   'be',
#   'used',
#   'as',
#   'hand',
#   'held',
#   'or',
#   'as',
#   'floor',
#   'vac',
#   'the',
#   'major',
#   'downside',
#   'they',
#   'are',
#   'expensive',
#   'the',
#   'best',
#   'price',
#   'you',
#   'll',
#   'likely',
#   'see',
#   'is',
#   'about',
#   'for',
#   'two',
#   'other',
#   'things',
#   'me',
#   'to',
#   'look',
#   'elsewhere',
#   'as',
#   'well',
#   'the',
#   'battery',
#   'lasts',
#   'about',
#   'minutes',
#   'at',
#   'best',
#   'but',
#   'usually',
#   'about',
#   'minutes',
#   'of',
#   'usefulness',
#   'and',
#   'the',
#   'thing',
#   'is',
#   'rather',
#   'large',
#   'and',
#   'bulky',
#   'for',
#   'hand',
#   'vac',
#   'so',
#   'off',
#   'to',
#   'the',
#   'web',
#   'went',
#   'to',
#   'try',
#   'and',
#   'find',
#   'vacuum',
#   'with',
#   'decent',
#   'ratings',
#   'and',
#   'lithium',
#   'battery',
#   'eventually',
#   'stumbled',
#   'upon',
#   'the',
#   'black',
#   'decker',
#   'chv',
#   'glad',
#   'did',
#   'the',
#   'vacuum',
#   'features',
#   'an',
#   'attractive',
#   'design',
#   'it',
#   'compact',
#   'it',
#   'got',
#   'an',
#   'absolutely',
#   'tiny',
#   'charging',
#   'base',
#   'and',
#   'still',
#   'functional',
#   'happily',
#   'and',
#   'other',
#   'course',
#   'lithium',
#   'battery',
#   'one',
#   'likely',
#   'won',
#   'need',
#   'the',
#   'user',
#   'guide',
#   'to',
#   'figure',
#   'out',
#   'how',
#   'everything',
#   'works',
#   'cleaning',
#   'and',
#   'using',
#   'the',
#   'vac',
#   'are',
#   'all',
#   'quite',
#   'intuitive',
#   'still',
#   'the',
#   'manual',
#   'all',
#   'the',
#   'information',
#   'you',
#   'll',
#   'need',
#   'while',
#   'being',
#   'brief',
#   'you',
#   'can',
#   'read',
#   'the',
#   'entire',
#   'guide',
#   'in',
#   'just',
#   'few',
#   'minutes',
#   'happily',
#   'the',
#   'vacuum',
#   'is',
#   'bag',
#   'less',
#   'canister',
#   'design',
#   'and',
#   'the',
#   'filter',
#   'is',
#   'mesh',
#   'design',
#   'which',
#   'is',
#   'easy',
#   'to',
#   'clean',
#   'from',
#   'the',
#   'battery',
#   'eventually',
#   'wearing',
#   'out',
#   'there',
#   'nothing',
#   'else',
#   'you',
#   'll',
#   'need',
#   'to',
#   'buy',
#   'or',
#   'replace',
#   'in',
#   'the',
#   'of',
#   'this',
#   'vacuum',
#   'major',
#   'improvement',
#   'over',
#   'older',
#   'hand',
#   'vacuums',
#   'to',
#   'be',
#   'sure',
#   'not',
#   'no',
#   'or',
#   'paper',
#   'filters',
#   'right',
#   'out',
#   'the',
#   'box',
#   'put',
#   'the',
#   'vacuum',
#   'on',
#   'it',
#   'charging',
#   'base',
#   'and',
#   'the',
#   'battery',
#   'was',
#   'full',
#   'within',
#   'an',
#   'hour',
#   'one',
#   'thing',
#   'to',
#   'note',
#   'is',
#   'the',
#   'extremely',
#   'bright',
#   'charging',
#   'indicator',
#   'while',
#   'it',
#   'doesn',
#   'bother',
#   'me',
#   'was',
#   'still',
#   'surprised',
#   'how',
#   'bright',
#   'it',
#   'is',
#   'you',
#   'can',
#   'practically',
#   'use',
#   'the',
#   'thing',
#   'as',
#   'night',
#   'light',
#   'the',
#   'charging',
#   'base',
#   'itself',
#   'is',
#   'small',
#   'simple',
#   'and',
#   'functional',
#   'it',
#   'disc',
#   'perhaps',
#   'inches',
#   'in',
#   'virtually',
#   'flat',
#   'and',
#   'the',
#   'vacuum',
#   'simply',
#   'rests',
#   'on',
#   'top',
#   'of',
#   'it',
#   'it',
#   'very',
#   'easy',
#   'to',
#   'seat',
#   'the',
#   'vacuum',
#   'on',
#   'it',
#   'and',
#   'getting',
#   'it',
#   'to',
#   'charge',
#   'the',
#   'vacuum',
#   'itself',
#   'is',
#   'very',
#   'light',
#   'weight',
#   'and',
#   'glad',
#   'that',
#   'they',
#   'went',
#   'with',
#   'design',
#   'for',
#   'the',
#   'business',
#   'end',
#   'of',
#   'the',
#   'nozzle',
#   'it',
#   'makes',
#   'vacuuming',
#   'tight',
#   'spaces',
#   'much',
#   'easier',
#   'and',
#   'gets',
#   'the',
#   'job',
#   'done',
#   'well',
#   'the',
#   'nozzle',
#   'features',
#   'an',
#   'interesting',
#   'flip',
#   'down',
#   'brush',
#   'which',
#   'is',
#   'convenient',
#   'since',
#   'you',
#   'don',
#   'have',
#   'to',
#   'worry',
#   'about',
#   'losing',
#   'the',
#   'attachment',
#   'but',
#   'unfortunately',
#   'only',
#   'half',
#   'of',
#   'the',
#   'assembly',
#   'has',
#   'bristles',
#   'it',
#   'works',
#   'well',
#   'enough',
#   'but',
#   'thinking',
#   'it',
#   'be',
#   'better',
#   'to',
#   'have',
#   'full',
#   'brush',
#   'attachment',
#   'suction',
#   'for',
#   'the',
#   'vacuum',
#   'is',
#   'excellent',
#   'and',
#   'compares',
#   'to',
#   'floor',
#   'vac',
#   'with',
#   'hose',
#   'attachment',
#   'for',
#   'effectiveness',
#   'it',
#   'actually',
#   'the',
#   'aging',
#   'plug',
#   'in',
#   'canister',
#   'vacuum',
#   'had',
#   'been',
#   'using',
#   'to',
#   'clean',
#   'my',
#   'car',
#   'out',
#   'with',
#   'the',
#   'old',
#   'in',
#   'with',
#   'the',
#   'new',
#   'suppose',
#   'and',
#   'this',
#   'one',
#   'is',
#   'cordless',
#   'noise',
#   'level',
#   'is',
#   'less',
#   'so',
#   'than',
#   'most',
#   'floor',
#   'vacs',
#   'but',
#   'this',
#   'device',
#   'isn',
#   'exactly',
#   'quiet',
#   'not',
#   'complaining',
#   'about',
#   'the',
#   'noise',
#   'level',
#   'but',
#   'you',
#   'wouldn',
#   'want',
#   'to',
#   'vacuum',
#   'in',
#   'the',
#   'middle',
#   'of',
#   'the',
#   'night',
#   'your',
#   'family',
#   'and',
#   'wouldn',
#   'appreciate',
#   'it',
#   'battery',
#   'life',
#   'is',
#   'very',
#   'good',
#   'for',
#   'cordless',
#   'vacuum',
#   'thus',
#   'far',
#   've',
#   'only',
#   'needed',
#   'it',
#   'for',
#   'about',
#   'minutes',
#   'at',
#   'time',
#   'but',
#   'did',
#   'use',
#   'it',
#   'once',
#   'for',
#   'approximately',
#   'minutes',
#   'straight',
#   'and',
#   'the',
#   'suction',
#   'was',
#   'mostly',
#   'consistent',
#   'notice',
#   'that',
#   'the',
#   'suction',
#   'is',
#   'strongest',
#   'the',
#   'first',
#   'minutes',
#   'of',
#   'use',
#   'it',
#   'then',
#   'off',
#   'bit',
#   'but',
#   'is',
#   'still',
#   'fairly',
#   'consistent',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'way',
#   'through',
#   'consider',
#   'the',
#   'first',
#   'couple',
#   'of',
#   'minutes',
#   'mode',
#   'or',
#   'something',
#   'like',
#   'that',
#   'in',
#   'any',
#   'case',
#   'it',
#   'huge',
#   'improvement',
#   'over',
#   'my',
#   'previous',
#   'ni',
#   'cd',
#   'vac',
#   'which',
#   'was',
#   'useable',
#   'for',
#   'only',
#   'minutes',
#   'before',
#   'beginning',
#   'the',
#   'steady',
#   'to',
#   'note',
#   'disassembly',
#   'and',
#   'cleaning',
#   'are',
#   'breeze',
#   'though',
#   'you',
#   'might',
#   'have',
#   'to',
#   'with',
#   'the',
#   'nozzle',
#   'to',
#   'get',
#   'it',
#   'to',
#   'lock',
#   'down',
#   'tight',
#   'with',
#   'the',
#   'base',
#   'try',
#   'rotating',
#   'the',
#   'nozzle',
#   'assembly',
#   'back',
#   'and',
#   'forth',
#   'to',
#   'get',
#   'it',
#   'locked',
#   'down',
#   'if',
#   'you',
#   'don',
#   'the',
#   'nozzle',
#   'end',
#   'might',
#   'fall',
#   'off',
#   'during',
#   'use',
#   'one',
#   'thing',
#   'to',
#   'consider',
#   'though',
#   'is',
#   'that',
#   'you',
#   'll',
#   'be',
#   'paying',
#   'far',
#   'more',
#   'for',
#   'this',
#   'cordless',
#   'vac',
#   'than',
#   'you',
#   'would',
#   'for',
#   'corded',
#   'one',
#   'you',
#   'can',
#   'find',
#   'corded',
#   'hand',
#   'vac',
#   'that',
#   'performs',
#   'just',
#   'as',
#   'well',
#   'for',
#   'or',
#   'less',
#   'is',
#   'the',
#   'worth',
#   'the',
#   'convenience',
#   'of',
#   'cordless',
#   'vacuum',
#   'for',
#   'me',
#   'yes',
#   'it',
#   'is',
#   'but',
#   'if',
#   'the',
#   'price',
#   'bothers',
#   'you',
#   'strongly',
#   'recommend',
#   'plug',
#   'in',
#   'vacuum',
#   'over',
#   'the',
#   'future',
#   'you',
#   'll',
#   'otherwise',
#   'buy',
#   'if',
#   'you',
#   'go',
#   'for',
#   'cheap',
#   'cordless',
#   'ni',
#   'cd',
#   'batteries',
#   'are',
#   'garbage',
#   'so',
#   'in',
#   'this',
#   'is',
#   'an',
#   'excellent',
#   'cordless',
#   'vacuum',
#   'with',
#   'powerful',
#   'suction',
#   'good',
#   'design',
#   'and',
#   'at',
#   'least',
#   'minutes',
#   'of',
#   'useful',
#   'battery',
#   'life',
#   'recommend',
#   'purchasing',
#   'it',
#   'over',
#   'any',
#   'vac',
#   'with',
#   'ni',
#   'cd',
#   'battery',
#   'look',
#   'for',
#   'to',
#   'be',
#   'or',
#   'less'],
#  ['it',
#   'true',
#   'really',
#   'wanted',
#   'this',
#   'vacuum',
#   'to',
#   'blow',
#   'my',
#   'mind',
#   'but',
#   'it',
#   'was',
#   'of',
#   'me',
#   'to',
#   'set',
#   'my',
#   'expectations',
#   'that',
#   'high',
#   'had',
#   'read',
#   'so',
#   'many',
#   'positive',
#   'reviews',
#   'on',
#   'amazon',
#   'and',
#   'the',
#   'purchase',
#   'based',
#   'off',
#   'of',
#   'just',
#   'that',
#   'let',
#   'me',
#   'break',
#   'it',
#   'down',
#   'pros',
#   'lightweight',
#   'and',
#   'compact',
#   'battery',
#   'holds',
#   'really',
#   'long',
#   'charge',
#   'narrow',
#   'nose',
#   'is',
#   'super',
#   'useful',
#   'for',
#   'the',
#   'hard',
#   'to',
#   'reach',
#   'spots',
#   'nice',
#   'overall',
#   'design',
#   'right',
#   'down',
#   'to',
#   'the',
#   'colors',
#   'cons',
#   'it',
#   'is',
#   'loud',
#   'as',
#   'mean',
#   'seriously',
#   'it',
#   'louder',
#   'than',
#   'my',
#   'electrolux',
#   'floor',
#   'vacuum',
#   'that',
#   'kinda',
#   'crazy',
#   'suction',
#   'power',
#   'is',
#   'bit',
#   'mediocre',
#   'was',
#   'expecting',
#   'more',
#   'the',
#   'brush',
#   'tip',
#   'extension',
#   'is',
#   'absolutely',
#   'useless',
#   'honestly',
#   'it',
#   'makes',
#   'things',
#   'even',
#   'more',
#   'difficult',
#   'to',
#   'vacuum',
#   'it',
#   'does',
#   'nothing',
#   'so',
#   'bottom',
#   'line',
#   'is',
#   'if',
#   'you',
#   're',
#   'on',
#   'and',
#   'aren',
#   'about',
#   'cleaning',
#   'then',
#   'this',
#   'is',
#   'the',
#   'vacuum',
#   'for',
#   'you',
#   'otherwise',
#   'pay',
#   'bit',
#   'more',
#   'and',
#   'get',
#   'something',
#   'little',
#   'more',
#   'advanced'],
#  ['we',
#   've',
#   'owned',
#   'couple',
#   'of',
#   'different',
#   'hand',
#   'vacs',
#   'over',
#   'the',
#   'years',
#   'and',
#   'this',
#   'one',
#   'is',
#   'by',
#   'far',
#   'the',
#   'best',
#   'it',
#   'is',
#   'extremely',
#   'powerful',
#   'much',
#   'more',
#   'so',
#   'than',
#   'my',
#   'previous',
#   'dirt',
#   'devil',
#   'it',
#   'easy',
#   'to',
#   'clean',
#   'and',
#   'also',
#   'charges',
#   'very',
#   'fast',
#   'the',
#   'lithium',
#   'battery',
#   'is',
#   'well',
#   'worth',
#   'the',
#   'extra',
#   'cost',
#   'can',
#   'recommend',
#   'this',
#   'product',
#   'highly',
#   'enough',
#   'we',
#   'are',
#   'impressed'],
#  ['this',
#   'model',
#   'sucks',
#   'up',
#   'lot',
#   'of',
#   'space',
#   'and',
#   'is',
#   'not',
#   'as',
#   'versatile',
#   'as',
#   'the',
#   'phv',
#   'have',
#   'an',
#   'old',
#   'one',
#   'doesn',
#   'hold',
#   'the',
#   'charge',
#   'as',
#   'well',
#   'as',
#   'it',
#   'used',
#   'to',
#   'but',
#   'it',
#   'was',
#   'only',
#   'volt',
#   'and',
#   'got',
#   'my',
#   'money',
#   'worth',
#   'paid',
#   'with',
#   'no',
#   'shipping',
#   'on',
#   'an',
#   'bay',
#   'special',
#   'this',
#   'model',
#   'doesn',
#   'break',
#   'down',
#   'for',
#   'cleaning',
#   'as',
#   'easily',
#   'as',
#   'the',
#   'swivel',
#   'vac',
#   'and',
#   'you',
#   'cannot',
#   'get',
#   'inside',
#   'the',
#   'canister',
#   'to',
#   'wipe',
#   'out',
#   'the',
#   'dust',
#   'the',
#   'pet',
#   'hair',
#   'carries',
#   'an',
#   'electric',
#   'charge',
#   'and',
#   'sticks',
#   'to',
#   'the',
#   'motor',
#   'don',
#   'like',
#   'having',
#   'to',
#   'use',
#   'my',
#   'canister',
#   'type',
#   'vacuum',
#   'to',
#   'suck',
#   'it',
#   'out',
#   'not',
#   'happy',
#   'with',
#   'it',
#   'and',
#   'it',
#   'cannot',
#   'be',
#   'returned',
#   'once',
#   'it',
#   'is',
#   'opened',
#   'what',
#   'waste',
#   'of',
#   'money',
#   'will',
#   'be',
#   'another',
#   'swivel',
#   'vac',
#   'not',
#   'the',
#   'with',
#   'not',
#   'so',
#   'reviews',
#   'or',
#   'maybe',
#   'even',
#   'go',
#   'back',
#   'to',
#   'the'],
#  ['don',
#   'know',
#   'if',
#   'everyone',
#   'else',
#   'had',
#   'low',
#   'expectations',
#   'or',
#   'what',
#   'the',
#   'battery',
#   'life',
#   'is',
#   'nothing',
#   'to',
#   'write',
#   'home',
#   'about',
#   'this',
#   'was',
#   'as',
#   'top',
#   'essential',
#   'for',
#   'back',
#   'to',
#   'school',
#   'maybe',
#   'college',
#   'kids',
#   'are',
#   'buying',
#   'or',
#   'receiving',
#   'these',
#   'and',
#   'for',
#   'all',
#   'they',
#   'know',
#   'it',
#   'is',
#   'good',
#   'vac',
#   'college',
#   'kids',
#   'aren',
#   'cleaning',
#   'let',
#   'be',
#   'real',
#   'charged',
#   'it',
#   'the',
#   'first',
#   'time',
#   'overnight',
#   'and',
#   'was',
#   'lucky',
#   'to',
#   'get',
#   'mins',
#   'of',
#   'use',
#   'time',
#   'out',
#   'of',
#   'that',
#   'charge',
#   'it',
#   'was',
#   'terrible',
#   'not',
#   'to',
#   'mention',
#   'if',
#   'you',
#   'leave',
#   'it',
#   'off',
#   'the',
#   'charger',
#   'for',
#   'day',
#   'again',
#   'you',
#   'will',
#   'maybe',
#   'get',
#   'minutes',
#   'if',
#   'you',
#   're',
#   'lucky',
#   'find',
#   'this',
#   'ridiculous',
#   'and',
#   'totally',
#   'for',
#   'what',
#   'the',
#   'ion',
#   'battery',
#   'doing',
#   'this',
#   'thing',
#   'was',
#   'such',
#   'pain',
#   'corded',
#   'vac',
#   'would',
#   'have',
#   'been',
#   'better',
#   'as',
#   'stated',
#   'in',
#   'my',
#   'video',
#   'wanted',
#   'one',
#   'could',
#   'clean',
#   'the',
#   'filter',
#   'myself',
#   'this',
#   'was',
#   'hassle',
#   'to',
#   'get',
#   'the',
#   'filter',
#   'in',
#   'and',
#   'out',
#   'the',
#   'cleaning',
#   'aspect',
#   'was',
#   'pain',
#   'because',
#   'there',
#   'is',
#   'two',
#   'pieces',
#   'and',
#   'you',
#   'have',
#   'to',
#   'get',
#   'them',
#   'back',
#   'in',
#   'just',
#   'right',
#   'the',
#   'design',
#   'of',
#   'the',
#   'vac',
#   'was',
#   'not',
#   'thought',
#   'out',
#   'very',
#   'well',
#   'there',
#   'is',
#   'smaller',
#   'hole',
#   'in',
#   'the',
#   'top',
#   'which',
#   'is',
#   'stupid',
#   'because',
#   'inevitably',
#   'there',
#   'will',
#   'be',
#   'something',
#   'you',
#   'vacuumed',
#   'up',
#   'and',
#   'you',
#   'need',
#   'to',
#   'wipe',
#   'off',
#   'the',
#   'inside',
#   'so',
#   'its',
#   'not',
#   'all',
#   'around',
#   'if',
#   'this',
#   'happens',
#   'you',
#   'better',
#   'have',
#   'baby',
#   'hands',
#   'or',
#   'baby',
#   'bottle',
#   'brush',
#   'to',
#   'get',
#   'in',
#   'there',
#   'the',
#   'suction',
#   'power',
#   'is',
#   'abysmal',
#   'it',
#   'was',
#   'struggling',
#   'to',
#   'get',
#   'up',
#   'cat',
#   'food',
#   'crumbs',
#   'and',
#   'litter',
#   'had',
#   'to',
#   'tilt',
#   'it',
#   'and',
#   'scoop',
#   'it',
#   'in',
#   'to',
#   'get',
#   'it',
#   'to',
#   'suck',
#   'it',
#   'up',
#   'what',
#   'waste',
#   'of',
#   'time',
#   'and',
#   'money',
#   'can',
#   'stand',
#   'this',
#   'thing',
#   'will',
#   'say',
#   'too',
#   'its',
#   'loud',
#   'decided',
#   'to',
#   'step',
#   'up',
#   'and',
#   'get',
#   'the',
#   'black',
#   'decker',
#   'bdh',
#   'pl',
#   'max',
#   'lithium',
#   'pivot',
#   'vacuum',
#   'volt',
#   'do',
#   'yourself',
#   'favor',
#   'and',
#   'spend',
#   'the',
#   'extra',
#   'money',
#   'you',
#   'will',
#   'be',
#   'happy',
#   'you',
#   'did',
#   'gave',
#   'it',
#   'two',
#   'stars',
#   'because',
#   'have',
#   'worse',
#   'if',
#   'that',
#   'makes',
#   'this',
#   'thing',
#   'any',
#   'more'],
#  ['purchased',
#   'this',
#   'same',
#   'thing',
#   'last',
#   'year',
#   'for',
#   'around',
#   'this',
#   'time',
#   'have',
#   'only',
#   'used',
#   'it',
#   'of',
#   'times',
#   'and',
#   'it',
#   'will',
#   'not',
#   'hold',
#   'charge',
#   'called',
#   'amazon',
#   'about',
#   'it',
#   'because',
#   'it',
#   'was',
#   'not',
#   'even',
#   'year',
#   'old',
#   'they',
#   'will',
#   'not',
#   'do',
#   'anything',
#   'about',
#   'it',
#   'since',
#   'it',
#   'has',
#   'been',
#   'over',
#   'days'],
#  ['usually',
#   'wait',
#   'longer',
#   'before',
#   'writing',
#   'review',
#   'but',
#   'there',
#   'were',
#   'so',
#   'many',
#   'reviews',
#   'that',
#   'thought',
#   'would',
#   'write',
#   'this',
#   'early',
#   'review',
#   'would',
#   'also',
#   'recommend',
#   'going',
#   'to',
#   'website',
#   'which',
#   'many',
#   'of',
#   'my',
#   'own',
#   'results',
#   'first',
#   'the',
#   'continuous',
#   'run',
#   'time',
#   'for',
#   'me',
#   'was',
#   'mins',
#   'the',
#   'recharge',
#   'time',
#   'was',
#   'hours',
#   'from',
#   'being',
#   'totally',
#   'drained',
#   'it',
#   'would',
#   'be',
#   'less',
#   'depending',
#   'how',
#   'it',
#   'was',
#   'used',
#   'these',
#   'are',
#   'similar',
#   'to',
#   'what',
#   'is',
#   'on',
#   'the',
#   'website',
#   'liked',
#   'the',
#   'new',
#   'stand',
#   'for',
#   'charging',
#   'the',
#   'light',
#   'on',
#   'the',
#   'unit',
#   'is',
#   'bright',
#   'blue',
#   'but',
#   'did',
#   'not',
#   'bother',
#   'me',
#   'big',
#   'issue',
#   'for',
#   'me',
#   'was',
#   'when',
#   'first',
#   'got',
#   'it',
#   'and',
#   'put',
#   'it',
#   'on',
#   'the',
#   'charger',
#   'it',
#   'seemed',
#   'to',
#   'flash',
#   'fast',
#   'which',
#   'can',
#   'indicate',
#   'bad',
#   'battery',
#   'however',
#   'the',
#   'manual',
#   'idea',
#   'of',
#   'fast',
#   'and',
#   'my',
#   'idea',
#   'are',
#   'different',
#   'when',
#   'the',
#   'unit',
#   'is',
#   'totally',
#   'discharged',
#   'and',
#   'you',
#   'turn',
#   'it',
#   'flashes',
#   'really',
#   'fast',
#   'so',
#   'am',
#   'hoping',
#   'that',
#   'it',
#   'is',
#   'okay',
#   'and',
#   'is',
#   'working',
#   'great',
#   'this',
#   'is',
#   'not',
#   'an',
#   'real',
#   'powerful',
#   'vacuum',
#   'cleaner',
#   'just',
#   'used',
#   'for',
#   'picking',
#   'up',
#   'light',
#   'dirt',
#   'and',
#   'debris',
#   'and',
#   'the',
#   'pull',
#   'out',
#   'attachment',
#   'is',
#   'helpful',
#   'to',
#   'battery',
#   'and',
#   'he',
#   'that',
#   'lithium',
#   'batteries',
#   'will',
#   'actually',
#   'their',
#   'run',
#   'time',
#   'we',
#   'will',
#   'see',
#   'this',
#   'early',
#   'so',
#   'someone',
#   'will',
#   'not',
#   'be',
#   'by',
#   'some',
#   'of',
#   'the',
#   'other',
#   'reviews',
#   'late',
#   'comment',
#   'went',
#   'from',
#   'stars',
#   'to',
#   'because',
#   'it',
#   'failed',
#   'at',
#   'just',
#   'over',
#   'years',
#   'just',
#   'past',
#   'the',
#   'warranty'],
#  ['well',
#   'it',
#   'fits',
#   'on',
#   'the',
#   'wall',
#   'hanger',
#   'bracket',
#   'from',
#   'former',
#   'models',
#   'and',
#   'the',
#   'of',
#   'the',
#   'circular',
#   'base',
#   'is',
#   'small',
#   'that',
#   'it',
#   'can',
#   'sit',
#   'atop',
#   'the',
#   'hanging',
#   'unit',
#   'without',
#   'touching',
#   'the',
#   'wall',
#   'if',
#   'you',
#   'need',
#   'hanger',
#   'bracket',
#   'look',
#   'at',
#   'parts',
#   'like',
#   'com',
#   'and',
#   'for',
#   'part',
#   'wall',
#   'base',
#   'mine',
#   'arrived',
#   'yesterday',
#   'purchased',
#   'from',
#   'another',
#   'online',
#   'seller',
#   'with',
#   'an',
#   'price',
#   'so',
#   'have',
#   'only',
#   'had',
#   'time',
#   'to',
#   'charge',
#   'it',
#   'up',
#   'but',
#   'have',
#   'not',
#   'put',
#   'it',
#   'through',
#   'its',
#   'yet',
#   'just',
#   'wanted',
#   'to',
#   'let',
#   'folks',
#   'know',
#   'that',
#   'you',
#   'can',
#   'hang',
#   'it',
#   'on',
#   'the',
#   'wall',
#   'and',
#   'even',
#   'charge',
#   'it',
#   'there',
#   'would',
#   'have',
#   'given',
#   'it',
#   'five',
#   'stars',
#   'if',
#   'it',
#   'could',
#   'have',
#   'been',
#   'hung',
#   'on',
#   'the',
#   'wall',
#   'from',
#   'the',
#   'start',
#   'without',
#   'having',
#   'to',
#   'black',
#   'hanger',
#   'from',
#   'former',
#   'model',
#   'attach',
#   'some',
#   'photos',
#   'showing',
#   'how',
#   'it',
#   'fits',
#   'on',
#   'the',
#   'wall',
#   'hanger',
#   'even',
#   'with',
#   'the',
#   'charging',
#   'plate'],
#  ['my',
#   'dust',
#   'buster',
#   'was',
#   'shipped',
#   'quickly',
#   'and',
#   'have',
#   'found',
#   'it',
#   'to',
#   'be',
#   'as',
#   'advertised',
#   'use',
#   'it',
#   'for',
#   'vacuuming',
#   'my',
#   'truck',
#   'and',
#   'it',
#   'does',
#   'very',
#   'good',
#   'job',
#   'have',
#   'no',
#   'problem',
#   'in',
#   'vacuuming',
#   'the',
#   'upholstery',
#   'and',
#   'getting',
#   'in',
#   'all',
#   'the',
#   'nicks',
#   'and',
#   'crannies',
#   'some',
#   'report',
#   'that',
#   'it',
#   'is',
#   'too',
#   'noisy',
#   'and',
#   'they',
#   'must',
#   'wear',
#   'earplugs',
#   'have',
#   'no',
#   'idea',
#   'why',
#   'they',
#   'would',
#   'have',
#   'that',
#   'need',
#   'yes',
#   'it',
#   'makes',
#   'noise',
#   'but',
#   'it',
#   'is',
#   'vacuum',
#   'and',
#   'sucking',
#   'dirt',
#   'to',
#   'me',
#   'the',
#   'noise',
#   'is',
#   'not',
#   'at',
#   'all',
#   'cleaning',
#   'the',
#   'vacuum',
#   'is',
#   'very',
#   'easy',
#   'open',
#   'dump',
#   'close',
#   'the',
#   'only',
#   'change',
#   'would',
#   'make',
#   'in',
#   'the',
#   'design',
#   'of',
#   'this',
#   'vacuum',
#   'is',
#   'to',
#   'the',
#   'sucking',
#   'end',
#   'currently',
#   'it',
#   'is',
#   'approximately',
#   'wide',
#   'which',
#   'seems',
#   'little',
#   'small',
#   'when',
#   'cleaning',
#   'the',
#   'interior',
#   'of',
#   'my',
#   'truck',
#   'would',
#   'recommend',
#   'this',
#   'dust',
#   'buster',
#   'as',
#   'great',
#   'value'],
#  ['must',
#   'say',
#   'on',
#   'my',
#   'second',
#   'dust',
#   'buster',
#   'of',
#   'black',
#   'and',
#   'decker',
#   'and',
#   'what',
#   'can',
#   'say',
#   'is',
#   'that',
#   'live',
#   'within',
#   'miles',
#   'of',
#   'the',
#   'so',
#   'it',
#   'was',
#   'easy',
#   'to',
#   'take',
#   'the',
#   'original',
#   'back',
#   'and',
#   'get',
#   'replacement',
#   'sent',
#   'through',
#   'the',
#   'mail',
#   'here',
#   'what',
#   'find',
#   'acceptable',
#   'about',
#   'these',
#   'units',
#   'at',
#   'least',
#   'my',
#   'particular',
#   'unit',
#   'leave',
#   'mine',
#   'constantly',
#   'on',
#   'the',
#   'charger',
#   'so',
#   'it',
#   'will',
#   'have',
#   'fresh',
#   'charge',
#   'every',
#   'time',
#   'ready',
#   'to',
#   'use',
#   'it',
#   'don',
#   'even',
#   'use',
#   'it',
#   'that',
#   'much',
#   'just',
#   'to',
#   'the',
#   'cleaning',
#   'of',
#   'my',
#   'vehicle',
#   'out',
#   'of',
#   'the',
#   'box',
#   'it',
#   'seems',
#   'to',
#   'work',
#   'fine',
#   'enough',
#   'and',
#   'hold',
#   'charge',
#   'long',
#   'enough',
#   'but',
#   'the',
#   'problem',
#   'for',
#   'me',
#   'has',
#   'been',
#   'how',
#   'rapidly',
#   'the',
#   'battery',
#   'had',
#   'such',
#   'that',
#   'on',
#   'my',
#   'replacement',
#   'unit',
#   'just',
#   'months',
#   'into',
#   'brand',
#   'new',
#   'unit',
#   'same',
#   'thing',
#   'battery',
#   'won',
#   'hold',
#   'charge',
#   'and',
#   'it',
#   'only',
#   'last',
#   'for',
#   'about',
#   'seconds',
#   'now',
#   'going',
#   'to',
#   'try',
#   'and',
#   'take',
#   'it',
#   'back',
#   'one',
#   'more',
#   'time',
#   'and',
#   'was',
#   'wondering',
#   'if',
#   'read',
#   'on',
#   'this',
#   'review',
#   'board',
#   'if',
#   'this',
#   'is',
#   'common',
#   'problem',
#   'or',
#   'just',
#   'my',
#   'back',
#   'luck',
#   'can',
#   'imagine',
#   'that',
#   'it',
#   'this',
#   'wouldn',
#   'have',
#   'any',
#   'or',
#   'stars',
#   'if',
#   'that',
#   'the',
#   'case',
#   'it',
#   'must',
#   'be',
#   'dud',
#   'units',
#   'battery',
#   've',
#   'gotten',
#   'honestly',
#   'they',
#   'have',
#   'lost',
#   'power',
#   'so',
#   'fast',
#   'that',
#   'there',
#   'not',
#   'way',
#   'could',
#   'put',
#   'their',
#   'name',
#   'on',
#   'such',
#   'performance',
#   'anybody',
#   'else',
#   'have',
#   'this',
#   'problem'],
#  ['can',
#   'live',
#   'with',
#   'the',
#   'wonky',
#   'stand',
#   'maybe',
#   'but',
#   'my',
#   'main',
#   'issue',
#   'is',
#   'that',
#   'this',
#   'dustbuster',
#   'is',
#   'very',
#   'weak',
#   'doesn',
#   'really',
#   'suck',
#   'up',
#   'anything',
#   'unless',
#   'you',
#   'go',
#   'over',
#   'the',
#   'area',
#   'multiple',
#   'times',
#   'and',
#   'the',
#   'brush',
#   'keeps',
#   'on',
#   'back',
#   'and',
#   'forth',
#   'you',
#   'really',
#   'need',
#   'to',
#   'hold',
#   'the',
#   'brush',
#   'in',
#   'place',
#   'with',
#   'one',
#   'hand',
#   'while',
#   'you',
#   'use',
#   'it',
#   'same',
#   'with',
#   'the',
#   'extension',
#   'which',
#   'just',
#   'gets',
#   'pushed',
#   'back',
#   'in',
#   'when',
#   'you',
#   'touch',
#   'something',
#   'with',
#   'it',
#   'unless',
#   'you',
#   'hold',
#   'it',
#   'meh',
#   'had',
#   'high',
#   'hopes',
#   'for',
#   'this',
#   'vacuum',
#   'but',
#   'it',
#   'is',
#   'rather',
#   'useless',
#   'in',
#   'my',
#   'car',
#   'for',
#   'which',
#   'bought',
#   'it'],
#  ['this',
#   'thing',
#   'is',
#   'amazing',
#   'the',
#   'suction',
#   'is',
#   'strong',
#   'it',
#   'little',
#   'on',
#   'the',
#   'heavy',
#   'side',
#   'but',
#   'works',
#   'so',
#   'well',
#   'it',
#   'doesn',
#   'matter',
#   'my',
#   'only',
#   'complaint',
#   'is',
#   'the',
#   'way',
#   'it',
#   'empties',
#   'you',
#   'can',
#   'either',
#   'remove',
#   'the',
#   'white',
#   'bit',
#   'and',
#   'try',
#   'to',
#   'get',
#   'everything',
#   'out',
#   'through',
#   'small',
#   'hole',
#   'or',
#   'take',
#   'off',
#   'the',
#   'handle',
#   'remove',
#   'the',
#   'filter',
#   'and',
#   'dump',
#   'it',
#   'that',
#   'way',
#   'either',
#   'way',
#   'you',
#   'end',
#   'up',
#   'having',
#   'to',
#   'get',
#   'your',
#   'hands',
#   'dirty',
#   'but',
#   'that',
#   'such',
#   'minor',
#   'thing'],
#  ['died',
#   'on',
#   'me',
#   'in',
#   'only',
#   'months',
#   'just',
#   'would',
#   'not',
#   'turn',
#   'on',
#   'at',
#   'all',
#   'contacted',
#   'black',
#   'decker',
#   'and',
#   'they',
#   'sent',
#   'me',
#   'another',
#   'one',
#   'now',
#   'this',
#   'replacement',
#   'just',
#   'died',
#   'on',
#   'me',
#   'as',
#   'well',
#   'in',
#   'just',
#   'months',
#   'same',
#   'problem',
#   'don',
#   'buy',
#   'this',
#   'expensive',
#   'piece',
#   'of',
#   'junk',
#   'that',
#   'will',
#   'just',
#   'die',
#   'on',
#   'you',
#   'now',
#   'they',
#   'expect',
#   'me',
#   'to',
#   'and',
#   'take',
#   'it',
#   'to',
#   'get',
#   'ridiculous'],
#  ['one',
#   'of',
#   'the',
#   'most',
#   'difficult',
#   'items',
#   'to',
#   'make',
#   'on',
#   'purchasing',
#   'across',
#   'the',
#   'board',
#   'looked',
#   'at',
#   'reviews',
#   'on',
#   'many',
#   'different',
#   'models',
#   'and',
#   'they',
#   'were',
#   'all',
#   'over',
#   'the',
#   'place',
#   'good',
#   'to',
#   'bad',
#   'for',
#   'every',
#   'one',
#   'of',
#   'them',
#   'so',
#   'far',
#   'am',
#   'pleased',
#   'with',
#   'the',
#   'performance',
#   'of',
#   'this',
#   'model',
#   'but',
#   'not',
#   'big',
#   'fan',
#   'of',
#   'the',
#   'noise',
#   'level',
#   'have',
#   'only',
#   'used',
#   'couple',
#   'hand',
#   'vacs',
#   'over',
#   'the',
#   'years',
#   'and',
#   'this',
#   'one',
#   'is',
#   'quieter',
#   'than',
#   'those',
#   'were',
#   'maybe',
#   'they',
#   'are',
#   'all',
#   'this',
#   'loud',
#   'because',
#   'there',
#   'is',
#   'really',
#   'no',
#   'way',
#   'to',
#   'the',
#   'noise',
#   'like',
#   'in',
#   'full',
#   'size',
#   'vac',
#   'like',
#   'the',
#   'base',
#   'charger',
#   'it',
#   'sits',
#   'in',
#   'instead',
#   'of',
#   'hanging',
#   'on',
#   'the',
#   'wall',
#   'like',
#   'lot',
#   'of',
#   'them',
#   'this',
#   'way',
#   'you',
#   'can',
#   'just',
#   'it',
#   'away',
#   'in',
#   'corner',
#   'until',
#   'your',
#   'ready',
#   'to',
#   'use',
#   'it',
#   'it',
#   'is',
#   'well',
#   'balanced',
#   'and',
#   'light',
#   'weight',
#   'so',
#   'it',
#   'does',
#   'not',
#   'put',
#   'strain',
#   'on',
#   'your',
#   'wrist',
#   'if',
#   'your',
#   'using',
#   'it',
#   'for',
#   'long',
#   'period',
#   'of',
#   'time',
#   'also',
#   'didn',
#   'notice',
#   'any',
#   'loss',
#   'of',
#   'power',
#   'when',
#   'used',
#   'it',
#   'for',
#   'little',
#   'over',
#   'five',
#   'minutes',
#   'in',
#   'single',
#   'use',
#   'probably',
#   'due',
#   'to',
#   'the',
#   'lithium',
#   'ion',
#   'battery',
#   'it',
#   'seems',
#   'to',
#   'be',
#   'very',
#   'well',
#   'so',
#   'hopefully',
#   'it',
#   'will',
#   'last',
#   'many',
#   'years'],
#  ['works',
#   'as',
#   'one',
#   'would',
#   'hope',
#   'for',
#   'the',
#   'price',
#   'and',
#   'size',
#   'well',
#   'designed',
#   'neck',
#   'extension',
#   'very',
#   'useful',
#   'but',
#   'in',
#   'use',
#   'will',
#   'and',
#   'unlock',
#   'if',
#   'used',
#   'too',
#   'into',
#   'things',
#   'others',
#   'have',
#   'noted',
#   'this',
#   'the',
#   'base',
#   'charger',
#   'is',
#   'also',
#   'getting',
#   'the',
#   'unit',
#   'to',
#   'seat',
#   'for',
#   'charging',
#   'is',
#   'surprisingly',
#   'awkward',
#   'both',
#   'those',
#   'flaws',
#   'completely',
#   'and',
#   'for',
#   'me',
#   'the',
#   'noise',
#   'however',
#   'wow',
#   'more',
#   'it',
#   'the',
#   'pitch',
#   'of',
#   'the',
#   'noise',
#   'extremely',
#   'high',
#   'pitched',
#   'and',
#   'piercing',
#   'the',
#   'noise',
#   'cone',
#   'that',
#   'the',
#   'engine',
#   'is',
#   'but',
#   'you',
#   'really',
#   'get',
#   'the',
#   'full',
#   'of',
#   'it',
#   'at',
#   'certain',
#   'find',
#   'myself',
#   'trying',
#   'to',
#   'position',
#   'my',
#   'head',
#   'away',
#   'from',
#   'this',
#   'cone',
#   'though',
#   'hardly',
#   'an',
#   'exact',
#   'despite',
#   'the',
#   'high',
#   'rating',
#   'of',
#   'this',
#   'unit',
#   'click',
#   'over',
#   'to',
#   'the',
#   'land',
#   'of',
#   'three',
#   'stars',
#   'and',
#   'behold',
#   'the',
#   'wish',
#   'would',
#   'have',
#   'little',
#   'before',
#   'purchased',
#   'will',
#   'probably',
#   'keep',
#   'don',
#   'look',
#   'so',
#   'great',
#   'but',
#   'the',
#   'noise',
#   'is',
#   'real',
#   'and',
#   'will',
#   'honestly',
#   'be',
#   'to',
#   'ear',
#   'protection',
#   'while',
#   'use',
#   'this',
#   'thing',
#   'to',
#   'vacuum',
#   'up',
#   'the',
#   'cheerios',
#   'my',
#   'pet',
#   'keeps',
#   'spilling',
#   'all',
#   'over',
#   'the',
#   'damn',
#   'place'],
#  ['was',
#   'looking',
#   'at',
#   'the',
#   'dyson',
#   'dust',
#   'buster',
#   'and',
#   'after',
#   'reading',
#   'several',
#   'not',
#   'great',
#   'reviews',
#   'decided',
#   'to',
#   'check',
#   'out',
#   'the',
#   'black',
#   'decker',
#   'lithium',
#   'ion',
#   'dust',
#   'buster',
#   'the',
#   'reviews',
#   'indicated',
#   'that',
#   'it',
#   'was',
#   'better',
#   'than',
#   'the',
#   'dyson',
#   'and',
#   'it',
#   'was',
#   'lot',
#   'less',
#   'money',
#   'the',
#   'lithium',
#   'battery',
#   'was',
#   'an',
#   'important',
#   'factor',
#   'for',
#   'me',
#   'since',
#   'wanted',
#   'something',
#   'with',
#   'long',
#   'battery',
#   'life',
#   'and',
#   'quick',
#   'recharging',
#   'ability',
#   'also',
#   'needed',
#   'the',
#   'cyclonic',
#   'suction',
#   'otherwise',
#   'knew',
#   'that',
#   'all',
#   'would',
#   'be',
#   'doing',
#   'was',
#   'moving',
#   'crumbs',
#   'from',
#   'one',
#   'place',
#   'to',
#   'another',
#   'with',
#   'two',
#   'dogs',
#   'eating',
#   'dog',
#   'after',
#   'every',
#   'walk',
#   'we',
#   'have',
#   'lots',
#   'of',
#   'crumbs',
#   'ordered',
#   'online',
#   'through',
#   'my',
#   'amazon',
#   'prime',
#   'and',
#   'had',
#   'the',
#   'dust',
#   'buster',
#   'in',
#   'few',
#   'days',
#   'some',
#   'people',
#   'don',
#   'care',
#   'for',
#   'the',
#   'charging',
#   'base',
#   'and',
#   'that',
#   'you',
#   'cannot',
#   'mount',
#   'the',
#   'dust',
#   'buster',
#   'to',
#   'the',
#   'wall',
#   'but',
#   'we',
#   'put',
#   'ours',
#   'in',
#   'our',
#   'back',
#   'out',
#   'of',
#   'the',
#   'way',
#   'but',
#   'accessible',
#   'the',
#   'charging',
#   'base',
#   'serves',
#   'as',
#   'night',
#   'light',
#   'for',
#   'us',
#   'so',
#   'we',
#   'do',
#   'not',
#   'mind',
#   'either',
#   'the',
#   'charging',
#   'base',
#   'or',
#   'that',
#   'it',
#   'can',
#   'be',
#   'mounted',
#   'it',
#   'heavier',
#   'than',
#   'most',
#   'dust',
#   'busters',
#   'but',
#   'not',
#   'so',
#   'heavy',
#   'that',
#   'it',
#   'if',
#   'you',
#   'are',
#   'using',
#   'it',
#   'so',
#   'long',
#   'that',
#   'its',
#   'weight',
#   'is',
#   'an',
#   'issue',
#   'then',
#   'the',
#   'job',
#   'probably',
#   'called',
#   'for',
#   'the',
#   'vacuum',
#   'cleaner',
#   'not',
#   'dust',
#   'buster',
#   'some',
#   'people',
#   'also',
#   'commented',
#   'on',
#   'how',
#   'loud',
#   'it',
#   'is',
#   'it',
#   'dust',
#   'buster',
#   'no',
#   'one',
#   'said',
#   'they',
#   'were',
#   'quiet',
#   'and',
#   'besides',
#   'why',
#   'does',
#   'it',
#   'have',
#   'to',
#   'be',
#   'quiet',
#   'my',
#   'dyson',
#   'vacuum',
#   'cleaner',
#   'isn',
#   'quiet',
#   'either',
#   'and',
#   'it',
#   'requires',
#   'lot',
#   'more',
#   'effort',
#   'to',
#   'use',
#   'it',
#   'this',
#   'machine',
#   'is',
#   'for',
#   'quick',
#   'cleaning',
#   'not',
#   'whole',
#   'house',
#   'cleaning',
#   'although',
#   'have',
#   'used',
#   'it',
#   'to',
#   'vacuum',
#   'the',
#   'path',
#   'from',
#   'my',
#   'living',
#   'room',
#   'to',
#   'my',
#   'neighbor',
#   'condo',
#   'when',
#   'we',
#   'moved',
#   'tree',
#   'out',
#   'of',
#   'our',
#   'unit',
#   'into',
#   'and',
#   'the',
#   'tree',
#   'shed',
#   'of',
#   'its',
#   'leaves',
#   'in',
#   'the',
#   'process',
#   'oh',
#   'and',
#   'did',
#   'mention',
#   'that',
#   'it',
#   'sucks',
#   'there',
#   'were',
#   'so',
#   'many',
#   'leaves',
#   'that',
#   'emptied',
#   'the',
#   'cannister',
#   'twice',
#   'but',
#   'even',
#   'when',
#   'the',
#   'cannister',
#   'was',
#   'pretty',
#   'full',
#   'of',
#   'leaves',
#   'the',
#   'dust',
#   'buster',
#   'was',
#   'still',
#   'keeping',
#   'its',
#   'suction',
#   'great',
#   'little',
#   'unit',
#   'highly',
#   'recommend',
#   'it',
#   'the',
#   'dyson',
#   'and',
#   'save',
#   'some',
#   'money',
#   'http',
#   'amazon',
#   'com',
#   'product'],
#  ['after',
#   'months',
#   'of',
#   'with',
#   'this',
#   'at',
#   'my',
#   'end',
#   'it',
#   'will',
#   'only',
#   'pick',
#   'up',
#   'few',
#   'dust',
#   'before',
#   'it',
#   'clogs',
#   'up',
#   'and',
#   'has',
#   'to',
#   'be',
#   'opened',
#   'and',
#   'the',
#   'removed',
#   'that',
#   'project',
#   'in',
#   'itself',
#   'that',
#   'more',
#   'powerful',
#   'battery',
#   'more',
#   'power',
#   'at',
#   'first',
#   'its',
#   'like',
#   'jet',
#   'engine',
#   'makes',
#   'you',
#   'hopeful',
#   'but',
#   'then',
#   'you',
#   'start',
#   'to',
#   'use',
#   'it',
#   'and',
#   'in',
#   'the',
#   'unlikely',
#   'it',
#   'ever',
#   'picks',
#   'up',
#   'dust',
#   'don',
#   'count',
#   'on',
#   'it',
#   'ever',
#   'picking',
#   'up',
#   'anything',
#   'else',
#   'bread',
#   'crumbs',
#   'would',
#   'never',
#   'be',
#   'in',
#   'danger',
#   'for',
#   'their',
#   'lives',
#   'in',
#   'short',
#   'go',
#   'with',
#   'the',
#   'much',
#   'cheaper',
#   'models',
#   'giving',
#   'this',
#   'an',
#   'extra',
#   'star',
#   'because',
#   'the',
#   'charger',
#   'seems',
#   'well',
#   'made',
#   'and',
#   'gives',
#   'off',
#   'nice',
#   'light',
#   'indicating',
#   'charging',
#   'but',
#   'you',
#   'can',
#   'use',
#   'it',
#   'enough',
#   'to',
#   'have',
#   'it',
#   'discharge',
#   'much',
#   'so',
#   'what',
#   'the',
#   'point',
#   'fool',
#   'and',
#   'his',
#   'money'],
#  ['ve',
#   'had',
#   'several',
#   'black',
#   'and',
#   'decker',
#   'products',
#   'and',
#   'usually',
#   'find',
#   'them',
#   'reliable',
#   'this',
#   'one',
#   'works',
#   'well',
#   'but',
#   'think',
#   'they',
#   'and',
#   'easy',
#   'of',
#   'placement',
#   'on',
#   'the',
#   'charging',
#   'plate',
#   'in',
#   'favor',
#   'of',
#   'an',
#   'attractive',
#   'design',
#   'it',
#   'gets',
#   'stars',
#   'as',
#   'and',
#   'hand',
#   'held',
#   'vacuum',
#   'but',
#   'only',
#   'overall',
#   'for',
#   'the',
#   'hassle',
#   'of',
#   'getting',
#   'it',
#   'placed',
#   'correctly',
#   'on',
#   'the',
#   'charging',
#   'plate',
#   'so',
#   'that',
#   'it',
#   'stands',
#   'upright',
#   'for',
#   'charging'],
#  ['super',
#   'strong',
#   'the',
#   'suction',
#   'is',
#   'so',
#   'good',
#   'often',
#   'have',
#   'to',
#   'flip',
#   'the',
#   'brush',
#   'over',
#   'the',
#   'tip',
#   'just',
#   'to',
#   'break',
#   'up',
#   'the',
#   'seal',
#   'bit',
#   'on',
#   'just',
#   'using',
#   'it',
#   'to',
#   'go',
#   'around',
#   'the',
#   'baseboards',
#   'every',
#   'now',
#   'and',
#   'then',
#   'but',
#   'when',
#   'found',
#   'how',
#   'strong',
#   'it',
#   'was',
#   'began',
#   'using',
#   'it',
#   'to',
#   'tidy',
#   'up',
#   'nearly',
#   'everything',
#   'part',
#   'of',
#   'what',
#   'me',
#   'to',
#   'leave',
#   'review',
#   'was',
#   'my',
#   'about',
#   'completely',
#   'cleaning',
#   'my',
#   'the',
#   'keyboard',
#   'fan',
#   'vent',
#   'and',
#   'haven',
#   'looked',
#   'this',
#   'good',
#   'since',
#   'bought',
#   'it',
#   'nor',
#   'has',
#   'it',
#   'ran',
#   'so',
#   'not',
#   'even',
#   'going',
#   'to',
#   'get',
#   'into',
#   'how',
#   'much',
#   'it',
#   'helped',
#   'me',
#   'detail',
#   'my',
#   'car',
#   'it',
#   'true',
#   'it',
#   'doesn',
#   'have',
#   'wall',
#   'hanging',
#   'charger',
#   'and',
#   'it',
#   'does',
#   'bit',
#   'precariously',
#   'on',
#   'the',
#   'stand',
#   'if',
#   'so',
#   'it',
#   'probably',
#   'not',
#   'best',
#   'in',
#   'high',
#   'area',
#   'or',
#   'on',
#   'an',
#   'unstable',
#   'surface',
#   'store',
#   'it',
#   'under',
#   'corner',
#   'table',
#   'in',
#   'the',
#   'utility',
#   'room',
#   'and',
#   'it',
#   'been',
#   'perfect',
#   'there',
#   'haven',
#   'had',
#   'it',
#   'for',
#   'very',
#   'long',
#   'so',
#   'not',
# ...
#   'than',
#   'that',
#   'like',
#   'the',
#   'features',
#   'and',
#   'cleans',
#   'well'],
#  ['love',
#   'it',
#   'it',
#   'has',
#   'great',
#   'features',
#   'that',
#   'allow',
#   'it',
#   'to',
#   'clean',
#   'well',
#   'in',
#   'small',
#   'areas',
#   'it',
#   'is',
#   'also',
#   'cleverly',
#   'designed',
#   'so',
#   'that',
#   'cleaning',
#   'the',
#   'filter',
#   'is',
#   'convenient',
#   'and',
#   'thorough',
#   'highly',
#   'recommend',
#   'it'],
#  ['it',
#   'has',
#   'more',
#   'power',
#   'than',
#   'my',
#   'dyson',
#   'hand',
#   'vacuum',
#   'the',
#   'battery',
#   'also',
#   'lasts',
#   'longer',
#   'one',
#   'short',
#   'coming',
#   'the',
#   'vertical',
#   'charging',
#   'position',
#   'is',
#   'odd',
#   'and',
#   'it',
#   'is',
#   'not',
#   'easy',
#   'to',
#   'put',
#   'it',
#   'in',
#   'its',
#   'charging',
#   'seat'],
#  ['oh',
#   'dustbuster',
#   'you',
#   'are',
#   'one',
#   'of',
#   'the',
#   'great',
#   'things',
#   'to',
#   'come',
#   'out',
#   'of',
#   'the',
#   'now',
#   'in',
#   'with',
#   'your',
#   'lithium',
#   'battery',
#   'and',
#   'adjustable',
#   'features',
#   'love',
#   'you',
#   'even',
#   'more',
#   'so',
#   'glad',
#   'bought',
#   'this'],
#  ['it',
#   'perfect',
#   'for',
#   'our',
#   'stairs',
#   'bit',
#   'loud',
#   'though',
#   'but',
#   'what',
#   'isn',
#   'these',
#   'days',
#   'also',
#   'husband',
#   'uses',
#   'it',
#   'the',
#   'most',
#   'and',
#   'he',
#   'had',
#   'one',
#   'where',
#   'it',
#   'ran',
#   'out',
#   'of',
#   'power',
#   'after',
#   'about',
#   'minutes'],
#  ['great',
#   'vacuum',
#   'use',
#   'it',
#   'to',
#   'clean',
#   'up',
#   'tons',
#   'of',
#   'pet',
#   'hair',
#   'in',
#   'powerful',
#   'suction',
#   'excellent',
#   'battery',
#   'life',
#   'actually',
#   'charges',
#   'bit',
#   'on',
#   'the',
#   'pricey',
#   'side',
#   'but',
#   'totally',
#   'worth',
#   'it'],
#  ['pros',
#   'good',
#   'suction',
#   'battery',
#   'seems',
#   'to',
#   'last',
#   'reasonably',
#   'easy',
#   'to',
#   'empty',
#   'cons',
#   'the',
#   'vacuum',
#   'is',
#   'pretty',
#   'narrow',
#   'and',
#   'the',
#   'device',
#   'is',
#   'little',
#   'when',
#   'sitting',
#   'on',
#   'the',
#   'charger'],
#  ['very',
#   'happy',
#   'with',
#   'this',
#   'version',
#   'we',
#   've',
#   'use',
#   'dirt',
#   'devil',
#   'the',
#   'previous',
#   'version',
#   'of',
#   'this',
#   'one',
#   'and',
#   'all',
#   'were',
#   'not',
#   'even',
#   'close',
#   'my',
#   'wife',
#   'is',
#   'really',
#   'happy',
#   'also',
#   'which',
#   'is',
#   'great'],
#  ['lasted',
#   'weeks',
#   'and',
#   'just',
#   'long',
#   'enough',
#   'for',
#   'me',
#   'to',
#   'throw',
#   'out',
#   'all',
#   'the',
#   'packaging',
#   'nd',
#   'time',
#   'this',
#   'has',
#   'happened',
#   'and',
#   'read',
#   'that',
#   'it',
#   'happened',
#   'to',
#   'many',
#   'others',
#   'buy',
#   'at',
#   'your',
#   'own',
#   'risk'],
#  ['not',
#   'nearly',
#   'as',
#   'good',
#   'as',
#   'would',
#   'have',
#   'expected',
#   'it',
#   'does',
#   'ok',
#   'its',
#   'not',
#   'super',
#   'fast',
#   'and',
#   'it',
#   'usually',
#   'takes',
#   'several',
#   'passes',
#   'to',
#   'get',
#   'everything',
#   'even',
#   'just',
#   'tiny',
#   'little',
#   'crumbs'],
#  ['great',
#   'vacuum',
#   'at',
#   'great',
#   'price',
#   'very',
#   'easy',
#   'to',
#   'clean',
#   'and',
#   'simple',
#   'to',
#   'charge',
#   'it',
#   'is',
#   'very',
#   'powerful',
#   'it',
#   'comes',
#   'with',
#   'an',
#   'attached',
#   'brush',
#   'and',
#   'an',
#   'extension',
#   'for',
#   'tight',
#   'spots'],
#  ['really',
#   'love',
#   'this',
#   'little',
#   'vacuum',
#   'it',
#   'so',
#   'light',
#   'weight',
#   'and',
#   'convenient',
#   'to',
#   'use',
#   'use',
#   'it',
#   'every',
#   'day',
#   'anytime',
#   'see',
#   'web',
#   'dog',
#   'hair',
#   'pine',
#   'needles',
#   'whatever'],
#  ['very',
#   'strong',
#   'suction',
#   'and',
#   'easy',
#   'to',
#   'dump',
#   'the',
#   'cage',
#   'around',
#   'the',
#   'filter',
#   'stops',
#   'pet',
#   'fur',
#   'from',
#   'getting',
#   'stuck',
#   'which',
#   'is',
#   'smart',
#   'feature',
#   'over',
#   'the',
#   'old',
#   'and',
#   'cheaper',
#   'one',
#   'had'],
#  ['this',
#   'is',
#   'certainly',
#   'an',
#   'improvement',
#   'over',
#   'its',
#   'the',
#   'lithium',
#   'battery',
#   'makes',
#   'the',
#   'difference',
#   'use',
#   'it',
#   'all',
#   'the',
#   'time',
#   'for',
#   'many',
#   'applications',
#   'highly'],
#  ['great',
#   'little',
#   'vacuum',
#   'but',
#   'when',
#   'the',
#   'extender',
#   'is',
#   'out',
#   'it',
#   'open',
#   'gets',
#   'pushed',
#   'back',
#   'in',
#   'while',
#   'vacuuming',
#   'it',
#   'doesn',
#   'stay',
#   'locked',
#   'in',
#   'place',
#   'which',
#   'is',
#   'bummer'],
#  ['gets',
#   'clogged',
#   'really',
#   'easy',
#   'and',
#   'also',
#   'loses',
#   'suction',
#   'at',
#   'that',
#   'point',
#   'if',
#   'you',
#   'don',
#   'want',
#   'to',
#   'clean',
#   'this',
#   'every',
#   'ten',
#   'minutes',
#   'would',
#   'recommend',
#   'against',
#   'it'],
#  ['we',
#   'love',
#   'this',
#   'thing',
#   'also',
#   'ready',
#   'to',
#   'go',
#   'and',
#   'really',
#   'sucks',
#   'in',
#   'good',
#   'way',
#   'keep',
#   'it',
#   'cleaned',
#   'out',
#   'as',
#   'that',
#   'will',
#   'affect',
#   'how',
#   'it'],
#  ['the',
#   'battery',
#   'lasts',
#   'longer',
#   'but',
#   'doesn',
#   'have',
#   'as',
#   'much',
#   'power',
#   'as',
#   'expected',
#   'also',
#   'have',
#   'hard',
#   'time',
#   'placing',
#   'it',
#   'correctly',
#   'on',
#   'it',
#   'base'],
#  ['not',
#   'the',
#   'most',
#   'powerful',
#   'thing',
#   'out',
#   'there',
#   'but',
#   'really',
#   'nice',
#   'to',
#   'have',
#   'for',
#   'quick',
#   'clean',
#   'ups',
#   'around',
#   'the',
#   'house',
#   'it',
#   'small',
#   'and',
#   'light'],
#  ['use',
#   'this',
#   'thing',
#   'everyday',
#   'on',
#   'small',
#   'clean',
#   'ups',
#   'also',
#   'to',
#   'pick',
#   'up',
#   'dog',
#   'hair',
#   'that',
#   'my',
#   'little',
#   'leaves',
#   'around',
#   'the',
#   'house'],
#  ['very',
#   'powerful',
#   'hand',
#   'vac',
#   'battery',
#   'lasts',
#   'long',
#   'time',
#   'also',
#   'this',
#   'is',
#   'my',
#   'second',
#   'vacuum',
#   'clean',
#   'my',
#   'car',
#   'and',
#   'shop',
#   'with',
#   'it'],
#  ['product',
#   'received',
#   'quickly',
#   'and',
#   'in',
#   'perfect',
#   'shape',
#   'vacuum',
#   'does',
#   'great',
#   'job',
#   'for',
#   'hand',
#   'vac',
#   'which',
#   'is',
#   'what',
#   'needed'],
#  ['this',
#   'works',
#   'pretty',
#   'good',
#   'the',
#   'charge',
#   'lasts',
#   'for',
#   'while',
#   'and',
#   'its',
#   'easy',
#   'to',
#   'keep',
#   'my',
#   'family',
#   'room',
#   'clean'],
#  ['this',
#   'little',
#   'sweeper',
#   'is',
#   'champ',
#   'it',
#   'sweeps',
#   'up',
#   'everything',
#   'and',
#   'the',
#   'charge',
#   'lasts',
#   'for',
#   'long',
#   'time'],
#  ['blown',
#   'away',
#   'am',
#   'an',
#   'major',
#   'so',
#   'am',
#   'not',
#   'easily',
#   'impressed',
#   'first',
#   'thing',
#   'did',
#   'was',
#   'to',
#   'take',
#   'apart',
#   'the',
#   'charger',
#   'to',
#   'see',
#   'how',
#   'it',
#   'which',
#   'it',
#   'stops',
#   'at',
#   'about',
#   'this',
#   'is',
#   'good',
#   'the',
#   'of',
#   'lithiums',
#   'are',
#   'actually',
#   'not',
#   'bad',
#   'if',
#   'you',
#   'keep',
#   'the',
#   'batteries',
#   'between',
#   'and',
#   'the',
#   'unit',
#   'dies',
#   'at',
#   'around',
#   'do',
#   'not',
#   'let',
#   'it',
#   'sit',
#   'around',
#   'for',
#   'weeks',
#   'after',
#   'that',
#   'as',
#   'the',
#   'weaker',
#   'these',
#   'types',
#   'of',
#   'cells',
#   'get',
#   'the',
#   'more',
#   'they',
#   'or',
#   'plate',
#   'they',
#   'become',
#   'lithium',
#   'just',
#   'plain',
#   'lithium',
#   'the',
#   'base',
#   'will',
#   'the',
#   'battery',
#   'few',
#   'times',
#   'day',
#   'and',
#   'bring',
#   'it',
#   'if',
#   'necessary'],
#  ['this',
#   'thing',
#   'works',
#   'so',
#   'well',
#   'and',
#   'because',
#   'of',
#   'the',
#   'lithium',
#   'battery',
#   'worries',
#   'about',
#   'loss',
#   'battery',
#   'life',
#   'are',
#   'reduced',
#   'cleans',
#   'well',
#   'and',
#   'easy',
#   'to',
#   'clean',
#   'also',
#   'has',
#   'an',
#   'extension',
#   'for',
#   'slightly',
#   'harder',
#   'to',
#   'reach',
#   'places',
#   'would',
#   'buy',
#   'again',
#   'only',
#   'downside',
#   'is',
#   'that',
#   'is',
#   'on',
#   'the',
#   'loud',
#   'side',
#   'but',
#   'for',
#   'me',
#   'that',
#   'isn',
#   'concern'],
#  ['the',
#   'rechargeable',
#   'battery',
#   'in',
#   'this',
#   'model',
#   'only',
#   'lasted',
#   'about',
#   'months',
#   'there',
#   'are',
#   'lot',
#   'of',
#   'bad',
#   'reviews',
#   'about',
#   'this',
#   'model',
#   'and',
#   'the',
#   'battery',
#   'problem',
#   'the',
#   'replacement',
#   'battery',
#   'which',
#   'is',
#   'also',
#   'questionable',
#   'costs',
#   'almost',
#   'the',
#   'same',
#   'as',
#   'the',
#   'total',
#   'unit'],
#  ['excellent',
#   'little',
#   'portable',
#   'vacuum',
#   'cleaner',
#   'which',
#   'is',
#   'well',
#   'worth',
#   'its',
#   'price'],
#  ['ll',
#   'what',
#   'several',
#   'others',
#   'have',
#   'said',
#   'it',
#   'works',
#   'well',
#   'but',
#   'it',
#   'really',
#   'should',
#   'have',
#   'wall',
#   'mountable',
#   'charging',
#   'instead',
#   'you',
#   'have',
#   'to',
#   'devote',
#   'fairly',
#   'large',
#   'area',
#   'of',
#   'shelf',
#   'space',
#   'to',
#   'the',
#   'saucer',
#   'shaped',
#   'charging',
#   'base',
#   'and',
#   'then',
#   'balance',
#   'the',
#   'vacuum',
#   'on',
#   'that',
#   'to',
#   'charge',
#   'it',
#   'say',
#   'balance',
#   'because',
#   'it',
#   'doesn',
#   'snap',
#   'onto',
#   'the',
#   'base',
#   'it',
#   'just',
#   'sits',
#   'on',
#   'it',
#   'this',
#   'is',
#   'actually',
#   'another',
#   'because',
#   'can',
#   'risk',
#   'putting',
#   'it',
#   'on',
#   'shelf',
#   'in',
#   'the',
#   'garage',
#   'because',
#   'sure',
#   'as',
#   'anything',
#   'one',
#   'of',
#   'our',
#   'cats',
#   'would',
#   'go',
#   'to',
#   'and',
#   'knock',
#   'it',
#   'off',
#   'possibly',
#   'it',
#   'so',
#   'for',
#   'now',
#   'it',
#   'taking',
#   'up',
#   'space',
#   'in',
#   'my',
#   'home'],
#  ['unlike',
#   'my',
#   'old',
#   'dustbusters',
#   'which',
#   'had',
#   'the',
#   'charging',
#   'contacts',
#   'built',
#   'into',
#   'the',
#   'wall',
#   'mounted',
#   'base',
#   'from',
#   'which',
#   'the',
#   'vacuum',
#   'hung',
#   'when',
#   'stored',
#   'this',
#   'vacuum',
#   'stands',
#   'on',
#   'base',
#   'to',
#   'charge',
#   'and',
#   'the',
#   'base',
#   'can',
#   'not',
#   'be',
#   'hung',
#   'it',
#   'supposed',
#   'free',
#   'stand',
#   'like',
#   'or',
#   'work',
#   'of',
#   'art',
#   'found',
#   'it',
#   'very',
#   'design',
#   'and',
#   'returned',
#   'it'],
#  ['this',
#   'dust',
#   'buster',
#   'is',
#   'great',
#   'because',
#   'it',
#   'has',
#   'strong',
#   'suction',
#   'power',
#   'and',
#   'lasts',
#   'about',
#   'minutes',
#   'at',
#   'each',
#   'cleaning',
#   'truly',
#   'wonder',
#   'for',
#   'its',
#   'day'],
#  ['okay',
#   'know',
#   'this',
#   'is',
#   'hand',
#   'held',
#   'and',
#   'the',
#   'battery',
#   'life',
#   'isn',
#   'supposed',
#   'to',
#   'be',
#   'any',
#   'good',
#   'but',
#   'really',
#   'expect',
#   'minutes',
#   'before',
#   'the',
#   'battery',
#   'dies',
#   'we',
#   've',
#   'only',
#   'had',
#   'ours',
#   'month',
#   'or',
#   'so',
#   'and',
#   'the',
#   'battery',
#   'dies',
#   'after',
#   'about',
#   'minute',
#   'of',
#   'use',
#   'could',
#   'be',
#   'that',
#   'the',
#   'battery',
#   'is',
#   'worn',
#   'down',
#   'from',
#   'constant',
#   'recharging',
#   'but',
#   'if',
#   'so',
#   'then',
#   'very',
#   'disappointed',
#   'as',
#   'the',
#   'description',
#   'an',
#   'charging',
#   'shut',
#   'off',
#   'when',
#   'it',
#   'full',
#   'charge',
#   'just',
#   'to',
#   'that',
#   'issue',
#   'don',
#   'waste',
#   'your',
#   'money'],
#  ['love',
#   'this',
#   'little',
#   'vacuum',
#   'bought',
#   'this',
#   'for',
#   'my',
#   'car',
#   'but',
#   'found',
#   'that',
#   'its',
#   'good',
#   'for',
#   'so',
#   'much',
#   'more',
#   'its',
#   'times',
#   'easier',
#   'to',
#   'reach',
#   'things',
#   'than',
#   'chord',
#   'extension',
#   'on',
#   'floor',
#   'vac',
#   'can',
#   'reach',
#   'up',
#   'high',
#   'with',
#   'it',
#   'its',
#   'easy',
#   'to',
#   'disassemble',
#   'and',
#   'clean',
#   'love',
#   'that',
#   'can',
#   'out',
#   'the',
#   'filter',
#   'so',
#   'easily',
#   'the',
#   'part',
#   'about',
#   'vacuuming',
#   'is',
#   'this',
#   'little',
#   'chord',
#   'free',
#   'vac',
#   'is',
#   'the',
#   'best'],
#  ['the',
#   'front',
#   'just',
#   'falls',
#   'off',
#   'and',
#   'everything',
#   'it',
#   'sucked',
#   'up',
#   'falls',
#   'all',
#   'over',
#   'it',
#   'also',
#   'makes',
#   'much',
#   'higher',
#   'pitch',
#   'wine',
#   'than',
#   'any',
#   'other',
#   'hand',
#   'held',
#   'vac',
#   've',
#   'had',
#   'but',
#   'it',
#   'makes',
#   'pretty',
#   'night',
#   'night',
#   'when',
#   'plugged',
#   'in'],
#  ['this',
#   'item',
#   'really',
#   'sucks',
#   'the',
#   'recharging',
#   'stand',
#   'requires',
#   'the',
#   'unit',
#   'stand',
#   'upright',
#   'which',
#   'can',
#   'cause',
#   'some',
#   'difficulty',
#   'when',
#   'storing',
#   'prefer',
#   'the',
#   'old',
#   'design',
#   'that',
#   'was',
#   'cradle',
#   'that',
#   'hung',
#   'on',
#   'the',
#   'wall'],
#  ['bought',
#   'it',
#   'to',
#   'get',
#   'pet',
#   'hair',
#   'out',
#   'of',
#   'my',
#   'car',
#   'and',
#   'ended',
#   'up',
#   'having',
#   'to',
#   'drag',
#   'my',
#   'big',
#   'shark',
#   'vacuum',
#   'outside',
#   'to',
#   'get',
#   'the',
#   'job',
#   'done',
#   'not',
#   'much',
#   'power',
#   'and',
#   'the',
#   'battery',
#   'didn',
#   'last',
#   'me',
#   'very',
#   'long'],
#  ['great',
#   'suction',
#   'power',
#   'for',
#   'picking',
#   'up',
#   'just',
#   'about',
#   'anything',
#   'that',
#   'gathers',
#   'on',
#   'our',
#   'dark',
#   'hard',
#   'wood',
#   'floors',
#   'also',
#   'good',
#   'for',
#   'tight',
#   'areas'],
#  ['very',
#   'powerful',
#   'not',
#   'too',
#   'heavy',
#   'not',
#   'sure',
#   'if',
#   'lithium',
#   'is',
#   'worth',
#   'the',
#   'extra',
#   'money',
#   'as',
#   'don',
#   'know',
#   'much',
#   'about',
#   'batteries'],
#  ['have',
#   'been',
#   'buying',
#   'dustbusters',
#   'from',
#   'black',
#   'and',
#   'decker',
#   'from',
#   'the',
#   'year',
#   'they',
#   'are',
#   'awesome',
#   'and',
#   'was',
#   'very',
#   'excited',
#   'to',
#   'see',
#   'they',
#   'came',
#   'out',
#   'with',
#   'lithium',
#   'ion',
#   'battery',
#   'powered',
#   'one',
#   'however',
#   'after',
#   'taking',
#   'it',
#   'out',
#   'of',
#   'the',
#   'box',
#   'realized',
#   'had',
#   'to',
#   'return',
#   'it',
#   'should',
#   'have',
#   'known',
#   'better',
#   'when',
#   'looked',
#   'at',
#   'the',
#   'picture',
#   'they',
#   'have',
#   'on',
#   'the',
#   'box',
#   'it',
#   'sitting',
#   'on',
#   'table',
#   'in',
#   'living',
#   'room',
#   'who',
#   'puts',
#   'vacuum',
#   'in',
#   'the',
#   'this',
#   'is',
#   'not',
#   'vase',
#   'or',
#   'picture',
#   'to',
#   'be',
#   'it',
#   'for',
#   'convenience',
#   'for',
#   'quick',
#   'vacuum',
#   'jobs',
#   'it',
#   'doesn',
#   'hang',
#   'on',
#   'the',
#   'wall',
#   'it',
#   'sits',
#   'precariously',
#   'on',
#   'charging',
#   'platform',
#   'ok',
#   'except',
#   'for',
#   'this',
#   'if',
#   'you',
#   'want',
#   'to',
#   'put',
#   'it',
#   'on',
#   'shelf',
#   'the',
#   'shelf',
#   'has',
#   'to',
#   'have',
#   'enough',
#   'clearance',
#   'to',
#   'hold',
#   'this',
#   'thing',
#   'standing',
#   'straight',
#   'up',
#   'so',
#   'unless',
#   'you',
#   'have',
#   'nearly',
#   'forget',
#   'it',
#   'ok',
#   'you',
#   'have',
#   'less',
#   'room',
#   'put',
#   'it',
#   'on',
#   'the',
#   'shelf',
#   'but',
#   'take',
#   'it',
#   'apart',
#   'and',
#   'lay',
#   'the',
#   'tube',
#   'parts',
#   'next',
#   'to',
#   'it',
#   'so',
#   'much',
#   'for',
#   'space',
#   'saver',
#   'or',
#   'if',
#   'you',
#   'have',
#   'cabinet',
#   'put',
#   'it',
#   'up',
#   'on',
#   'top',
#   'ok',
#   'but',
#   'don',
#   'bump',
#   'the',
#   'cabinet',
#   'even',
#   'little',
#   'or',
#   'it',
#   'will',
#   'come',
#   'down',
#   'why',
#   'doesn',
#   'it',
#   'hang',
#   'on',
#   'the',
#   'wall',
#   'who',
#   'knows',
#   'but',
#   'sadly',
#   'had',
#   'to',
#   'return',
#   'it',
#   'because',
#   'it',
#   'doesn',
#   'match',
#   'my',
#   'living',
#   'room',
#   'decor',
#   'and',
#   'not',
#   'sticking',
#   'it',
#   'on',
#   'the',
#   'floor',
#   'in',
#   'the',
#   'hallway',
#   'so',
#   'before',
#   'you',
#   'buy',
#   'this',
#   'think',
#   'of',
#   'where',
#   'you',
#   're',
#   'going',
#   'to',
#   'it',
#   'what',
#   'bummer',
#   'they',
#   'took',
#   'great',
#   'style',
#   'and',
#   'made',
#   'it',
#   'better',
#   'which',
#   'was',
#   'worse',
#   'for',
#   'the',
#   'money',
#   'if',
#   'you',
#   'don',
#   'want',
#   'to',
#   'hang',
#   'it',
#   'up',
#   'might',
#   'as',
#   'well',
#   'get',
#   'wet',
#   'dry',
#   'hand',
#   'vac',
#   'for',
#   'the',
#   'same',
#   'price'],
#  ['but',
#   'not',
#   'in',
#   'the',
#   'tidying',
#   'up',
#   'the',
#   'house',
#   'way',
#   'more',
#   'in',
#   'that',
#   'money',
#   'down',
#   'the',
#   'which',
#   'we',
#   'consumers',
#   'have',
#   'become',
#   'all',
#   'to',
#   'to',
#   'of',
#   'late',
#   'solid',
#   'field',
#   'of',
#   'money',
#   'one',
#   'could',
#   'easily',
#   'spend',
#   'more',
#   'on',
#   'an',
#   'item',
#   'just',
#   'as',
#   'as',
#   'this',
#   'but',
#   'in',
#   'these',
#   'times',
#   'that',
#   'would',
#   'be',
#   'of']]

# %%
print(corpus_clu0_wordlist)
# Out:
# [['have', 'it', 'in', 'order', 'but', 'it', 'funny', 'how', 'the', 'first', 'picture', 'shows', 'dirt', 'on', 'narrow', 'location', 'but', 'that', 'the', 'physical', 'size', 'of', 'the', 'vacuum', 'is', 'not', 'able', 'to', 'physically', 'fit', 'to', 'clean', 'the', 'whole', 'mess'], ['power', 'is', 'great', 'holds', 'good', 'charge', 'my', 'previous', 'one', 'had', 'fixture', 'to', 'hold', 'it', 'on', 'the', 'wall', 'for', 'this', 'one', 'the', 'recharging', 'base', 'sits', 'on', 'the', 'floor', 'and', 'if', 'knocked', 'over', 'or', 'set', 'slightly', 'off', 'the', 'base', 'it', 'doesn', 'charge'], ['are', 'all', 'hand', 'vacuums', 'same', 'of', 'course', 'not', 'after', 'buying', 'and', 'working', 'this', 'about', 'months', 'concluded', 'it', 'is', 'the', 'best', 'the', 'charge', 'last', 'long', 'sucks', 'powerful', 'easy', 'to', 'empty', 'and', 'clean', 'don', 'like', 'the', 'platform', 'recharge', 'system', 'prefer', 'the', 'old', 'way', 'but', 'still', 'very', 'pleased', 'with', 'this', 'vacuum'], ['little', 'noisy', 'but', 'it', 'really', 'works', 'well', 'for', 'getting', 'into', 'corners', 'quite', 'powerful', 'holds', 'charge', 'long', 'time', 'little', 'hard', 'to', 'take', 'apart', 'to', 'empty', 'it', 'but', 'once', 'got', 'the', 'hang', 'of', 'it', 'it', 'really', 'wasn', 'much', 'of', 'problem'], ['powerful', 'light', 'useful', 'that', 'my', 'three', 'word', 'for', 'this', 'vacuum', 'cleaner', 'highly', 'recommend'], ['it', 'is', 'just', 'great', 'so', 'glad', 'ha'], ['powerful', 'but', 'the', 'whole', 'concept', 'design', 'is', 'awkward', 'from', 'the', 'crooked', 'position', 'on', 'base', 'and', 'impractical', 'wandjust', 'try', 'to', 'lengthen', 'it', 'and', 'fighting', 'with', 'each', 'emptying', 'of', 'the', 'dirt'], ['its', 'power', 'equals', 'hand', 'held', 'vacuums', 'with', 'stronger', 'motors', 'excellent', 'filtration', 'system', 'easy', 'and', 'the', 'best', 'cleaning', 'of', 'the', 'unit', 'with', 'compressed', 'air', 'hose'], ['love', 'it', 'easy', '
 2283, 'fidget': 1442, 'shells': 6593, 'give': 737, 'lightly': 3160, 'drowning': 8021, 'like': 246, 'hugely': 4840, 'care': 2287, 'extensible': 2859, 'safer': 7814, 'complete': 3468, 'snazzy': 7710, 'fiancée': 6462, 'guilty': 3156, 'created': 6312, 'accounts': 4635, 'difficulty': 4361, 'floorboards': 7897, 'button': 651, 'hallways': 3159, 'ramming': 4269, 'featurethree': 5765, 'glitter': 5498, 'reliability': 3482, 'mega': 4768, 'control': 3586, 'unwieldy': 5626, 'oomph': 2790, 'exorbitant': 8249, 'reassembling': 1466, 'lockable': 5831, 'unruly': 5676, 'dwindled': 6503, 'umpteen': 7110, 'willbe': 7026, 'individual': 2540, 'woman': 2527, 'stood': 1679, 'falling': 1868, 'good': 457, 'fur': 1825, 'translucent': 1741, 'scuffs': 7486, 'whirl': 5528, 'ond': 8172, 'beak': ...

# %%
# 顯示各篇文章出現的字的ID跟次數
corpus0 = [dictionary.doc2bow(text) for text in corpus_clu0_wordlist]
corpus1 = [dictionary.doc2bow(text) for text in corpus_clu1_wordlist]
corpus2 = [dictionary.doc2bow(text) for text in corpus_clu2_wordlist]
corpus3 = [dictionary.doc2bow(text) for text in corpus_clu3_wordlist]
corpus4 = [dictionary.doc2bow(text) for text in corpus_clu4_wordlist]
corpus5 = [dictionary.doc2bow(text) for text in corpus_clu5_wordlist]
corpus6 = [dictionary.doc2bow(text) for text in corpus_clu6_wordlist]

#corpora.MmCorpus.serialize('/tmp/deerwester.mm', corpus)  # store to disk, for later use
print(corpus0)
# Out:
# [[(26, 2), (29, 1), (39, 2), (44, 1), (53, 1), (55, 1), (70, 1), (76, 1), (80, 2), (81, 1), (88, 4), (109, 1), (185, 1), (297, 1), (314, 1), (324, 1), (404, 1), (476, 1), (556, 1), (628, 1), (658, 1), (808, 1), (881, 1), (1044, 1), (1516, 1), (1909, 1), (1910, 1), (1911, 1), (1912, 1)], [(26, 1), (32, 1), (38, 1), (39, 2), (51, 1), (70, 2), (71, 1), (88, 4), (101, 1), (134, 1), (142, 1), (147, 1), (149, 2), (164, 1), (174, 1), (185, 1), (225, 2), (229, 1), (254, 1), (304, 1), (316, 1), (333, 1), (368, 2), (410, 1), (457, 1), (527, 1), (662, 1), (763, 1), (874, 1), (970, 1), (987, 1), (5407, 1)], [(26, 1), (28, 1), (39, 1), (44, 1), (55, 1), (80, 1), (81, 1), (86, 1), (88, 4), (93, 1), (111, 1), (121, 1), (135, 1), (142, 2), (147, 2), (149, 1), (154, 1), (185, 1), (198, 1), (204, 1), (224, 1), (226, 1), (235, 1), (246, 1), (287, 1), (303, 1), (314, 1), (318, 1), (330, 1), (331, 1), (334, 1), (360, 1), (373, 1), (380, 1), (430, 1), (784, 1), (895, 1), (976, 1), (1115, 1), (1256, 1), (1292, 1), (2678, 1), (7135, 1)], [(6, 1), (14, 1), (19, 1), (26, 2), (39, 4), (55, 2), (61, 1), (80, 2), (88, 1), (134, 1), (149, 1), (174, 1), (192, 2), (253, 1), (300, 1), (305, 1), (318, 
(465, 1), (734, 1), (739, 1), (4510, 1), (7380, 1)], [(39, 1), (55, 1), (64, 1), (81, 2), (131, 1), (149, 1), (318, 1), (680, 1), (1179, 1), (1181, 1), (1431, 1)], [(14, 1), (42, 1), (44, 1), (147, 1), (174, 1), (192, 1), (322, 1), (375, 1), (457, 1), (506, 1), (1532, 1)], [(39, 1), (185, 1), (235, 1), (339, 1), (1159, 1), (7711, 1), (7712, 1)], [(26, 2), (101 ...

# %%
# TF-IDF一下
from gensim import corpora, models, similarities
tfidf0 = models.TfidfModel(corpus0)
tfidf1 = models.TfidfModel(corpus1)
tfidf2 = models.TfidfModel(corpus2)
tfidf3 = models.TfidfModel(corpus3)
tfidf4 = models.TfidfModel(corpus4)
tfidf5 = models.TfidfModel(corpus5)
tfidf6 = models.TfidfModel(corpus6)

corpus_tfidf0 = tfidf0[corpus0]
corpus_tfidf1 = tfidf1[corpus1]
corpus_tfidf2 = tfidf2[corpus2]
corpus_tfidf3 = tfidf3[corpus3]
corpus_tfidf4 = tfidf4[corpus4]
corpus_tfidf5 = tfidf5[corpus5]
corpus_tfidf6 = tfidf6[corpus6]

# %%
# 第0個群組有1564篇文章
print(tfidf0)
# Out:
# TfidfModel(num_docs=838, num_nnz=4795)

# %%
# 第0個群組每篇文章出現的字的ID與TF-IDF值
for doc in corpus_tfidf0:
    print(doc)
# Out:
# [(26, 0.1451522066522173), (29, 0.1266039513433135), (39, 0.1050863147189037), (44, 0.0928867090119253), (53, 0.21000643692961443), (55, 0.11467580544502594), (70, 0.13557164430982171), (76, 0.11357153688767754), (80, 0.20658967426980632), (81, 0.11250125127198199), (88, 0.2876543112344899), (109, 0.1507126763537977), (185, 0.090010563953751), (297, 0.1717950118477987), (314, 0.09804898506210055), (324, 0.17813643600634171), (404, 0.23411516194009865), (476, 0.23411516194009865), (556, 0.1858977119191302), (628, 0.23411516194009865), (658, 0.23411516194009865), (808, 0.23411516194009865), (881, 0.1959037368582829), (1044, 0.15769231177646717), (1516, 0.21000643692961443), (1909, 0.23411516194009865), (1910, 0.23411516194009865), (1911, 0.1858977119191302), (1912, 0.23411516194009865)]
# [(26, 0.06591857567851515), (32, 0.17793315860140763), (38, 0.2126393855907733), (39, 0.0954465708698683), (51, 0.11095197850388017), (70, 0.24627086012436325), (71, 0.2126393855907733), (88, 0.2612672989504596), (101, 0.03625132559392714), (134, 0.13413877611781652), (142, 0.07934104757859052), (147, 0.05211289673299076), (149, 0.20247647764077217), (164, 0.08842920307281595), (174, 0.0719222372866511), (185, 0.08175374400015056), (225, 0.22448316975204197), (229, 0.19074219434897774), (254, 0.2126393855907733), (304, 0.2126393855907733), (316, 0.12926900673708636), (333, 0.1560359673596121), (368, 0.3120719347192242), (410, 0.16884500310718217), (457, 0.057212419629786244), (527, 0.2126393855907733), (662, 0.2126393855907733), (763, 0.1560359673596121), (874, 0.2126393855907733), (970, 0.19074219434897774), (987, 0.2126393855907733), (5407, 0.2126393855907733)]
# [(235, 0.7537243978636026), (457, 0.6571906360145051)]
# [(170, 0.9425398160935591), (350, 0.33409384172462653)]
# [(460, 1.0)]
# [(11, 0.940482729282255), (101, 0.33984148646361667)]
# [(457, 0.398671113733461), (594, 0.9170939663276177)]
# [(39, 0.37492849685014024), (246, 0.9270537321265119)]
# [(39, 0.5663377487243602), (747, 0.8241732550682674)]
# [(8489, 1.0)]
# [(681, 1.0)]
# [(2101, 1.0)]
# [(2746, 1.0)]
# [(39, 0.25905322153451454), (1814, 0.9658630484766407)]
# [(94, 0.943436600145378), (101, 0.3315529844627103)]
# [(39, 0.2427162572084153), (1168, 0.9700973242343978)]
# [(39, 0.5663377487243602), (747, 0.8241732550682674)]
# [(8490, 1.0)]
# [(235, 0.7537243978636026), (457, 0.6571906360145051)]
# [(235, 0.5046857539904945), (375, 0.8633031273654961)]
# [(1756, 1.0)]
# [(457, 0.398671113733461), (594, 0.9170939663276177)]
# [(746, 1.0)]
# [(318, 1.0)]
# [(8491, 1.0)]
# [(235, 0.7537243978636026), (457, 0.6571906360145051)]
# [(101, 1.0)]
# [(88, 0.5385901863740392), (204, 0.842567867380176)]
# [(39, 0.5663377487243602), (747, 0.8241732550682674)]
# [(457, 0.398671113733461), (594, 0.9170939663276177)]
# [(39, 0.5663377487243602), (747, 0.8241732550682674)]
# [(39, 0.2427162572084153), (1168, 0.9700973242343978)]
# [(8226, 1.0)]
# [(39, 0.5663377487243602), (747, 0.8241732550682674)]
# [(225, 0.8909343470862001), (457, 0.45413212744980536)]
# [(39, 0.5663377487243602), (747, 0.8241732550682674)]
# [(39, 0.5663377487243602), (747, 0.8241732550682674)]
# [(2690, 1.0)]
# [(39, 0.5663377487243602), (747, 0.8241732550682674)]
# [(39, 0.37492849685014024), (246, 0.9270537321265119)]
# [(39, 0.2427162572084153), (8382, 0.9700973242343978)]
# [(393, 1.0)]
# [(39, 0.5663377487243602), (747, 0.8241732550682674)]
# [(39, 0.5663377487243602), (747, 0.8241732550682674)]
# [(393, 1.0)]
# [(39, 0.5663377487243602), (747, 0.8241732550682674)]
# [(8493, 1.0)]
# [(39, 0.5663377487243602), (747, 0.8241732550682674)]
# [(350, 1.0)]
# [(39, 0.37492849685014024), (246, 0.9270537321265119)]
# [(39, 0.5663377487243602), (747, 0.8241732550682674)]
# [(460, 1.0)]
# [(39, 0.5663377487243602), (747, 0.8241732550682674)]
# [(39, 0.5663377487243602), (747, 0.8241732550682674)]
# [(44, 0.3503211184591047), (174, 0.29864948022104026), (425, 0.48998791068833597), (457, 0.23756851885077523), (2080, 0.7011110098661926)]
# [(101, 1.0)]
# [(350, 1.0)]
# [(101, 1.0)]
# [(101, 1.0)]
# [(101, 1.0)]
# [(39, 0.2427162572084153), (8382, 0.9700973242343978)]
# [(101, 1.0)]
# [(363, 0.7259122858247569), (1308, 0.6877872878213704)]
# [(101, 1.0)]
# [(272, 1.0)]
# [(101, 1.0)]
# [(101, 1.0)]
# [(101, 1.0)]
# [(101, 1.0)]
# [(81, 0.5215018448619783), (185, 0.4172458050752243), (457, 0.2919944814843925), (1115, 0.6846027948638115)]
# [(44, 0.5178402862879034), (215, 0.7800772412627072), (457, 0.3511708068180304)]
# [(44, 0.6008422869192867), (393, 0.7993675914431366)]
# [(94, 0.8295133079777639), (318, 0.5584869487175036)]
# [(101, 0.16805789524670461), (1566, 0.9857771268624808)]
# [(101, 0.3770270068054403), (126, 0.9262022652419559)]
# [(235, 0.3252954042791735), (1060, 0.9456124470177245)]
# [(101, 0.581112772828903), (350, 0.813823042961493)]
# [(457, 0.3923219334540287), (1115, 0.919827973335717)]
# [(457, 0.25981829879549945), (723, 0.9656575229402051)]
# [(457, 0.36281005401856437), (812, 0.9318631147883505)]
# [(101, 0.581112772828903), (350, 0.813823042961493)]
# [(170, 0.9425398160935591), (350, 0.33409384172462653)]
# [(39, 0.5663377487243602), (747, 0.8241732550682674)]
# [(1444, 1.0)]
# [(235, 0.5046857539904945), (375, 0.8633031273654961)]
# [(230, 0.6019768016863337), (3300, 0.7985135754835307)]
# [(39, 0.37492849685014024), (246, 0.9270537321265119)]
# [(230, 0.6019768016863337), (3300, 0.7985135754835307)]
# [(39, 0.6849175672006891), (350, 0.7286205639013281)]
# [(681, 1.0)]
# [(8491, 1.0)]
# [(2690, 1.0)]
# [(101, 1.0)]
# [(246, 1.0)]
# [(457, 1.0)]
# [(747, 1.0)]
# [(81, 0.24570796250032795), (92, 0.3444073393894049), (406, 0.40600924445449244), (649, 0.2667981174100572), (1304, 0.33640368093227485), (1382, 0.5113183967320202), (1838, 0.45866382059325633)]
# [(41, 0.3243193889925543), (235, 0.3272925923814952), (457, 0.285374372329865), (594, 0.6564687181806325), (681, 0.5246968482498344)]
# [(272, 0.49315217978222936), (375, 0.536600504467478), (1044, 0.6847341280973833)]
# [(235, 0.7537243978636026), (457, 0.6571906360145051)]
# [(101, 1.0)]
# [(784, 1.0)]
# [(101, 1.0)]
# [(457, 1.0)]
# []
# [(88, 0.2728613311406721), (164, 0.36941339630464193), (1712, 0.8883019962821259)]
# [(26, 0.21780298319646196), (39, 0.15768353349073844), (114, 0.5879127750265849), (149, 0.33450344158183487), (185, 0.2701243033155558), (1746, 0.6302353854436694)]
# [(213, 0.5586562327725749), (1406, 0.8293993088882787)]
# []
# [(126, 0.37205763147078863), (142, 0.33147507448001673), (185, 0.341554960622711), (1421, 0.7968924662316946)]

# %%
# 看一下各群組前100個TF-IDF值較高的字
from collections import Counter

def get_top100_word(corpus_tfidf):
    d = {}
    for doc in corpus_tfidf:
        for id, value in doc:
            word = dictionary.get(id)
            d[word] = value
    d_val = Counter(d)
    return d_val.most_common(100)

# %%
# 第0群
get_top100_word(corpus_tfidf0)
# Out:
# [('okie', 1.0),
#  ('wonderful', 1.0),
#  ('sucks', 1.0),
#  ('terrific', 1.0),
#  ('great', 1.0),
#  ('love', 1.0),
#  ('good', 1.0),
#  ('cool', 1.0),
#  ('goooooood', 1.0),
#  ('horrible', 1.0),
#  ('like', 1.0),
#  ('magnifica', 1.0),
#  ('aaa', 1.0),
#  ('beautiful', 1.0),
#  ('name', 1.0),
#  ('functional', 1.0),
#  ('excelent', 1.0),
#  ('satisfied', 1.0),
#  ('flawless', 1.0),
#  ('loooooove', 1.0),
#  ('fab', 1.0),
#  ('powerfull', 0.9857771268624808),
#  ('products', 0.9857771268624808),
#  ('prod', 0.9857771268624808),
#  ('worked', 0.9857771268624808),
#  ('absolutely', 0.9857771268624808),
#  ('cleaner', 0.9724289811193982),
#  ('work', 0.9724289811193982),
#  ('loved', 0.9700973242343978),
#  ('luv', 0.9700973242343978),
#  ('handheld', 0.96943031376534),
#  ('item', 0.9666765971741552),
#  ('okay', 0.9658630484766407),
#  ('stuff', 0.9656575229402051),
#  ('value', 0.9519979768679041),
#  ('surprisingly', 0.9505831539740577),
#  ('convenience', 0.9456124470177245),
#  ('helpful', 0.9456124470177245),
#  ('thanks', 0.9436829429599554),
#  ('fine', 0.9425398160935591),
#  ('pets', 0.9351645633876717),
#  ('pretty', 0.9318631147883505),
#  ('simply', 0.9296618358225747),
#  ('quality', 0.9286517681596606),
#  ('now', 0.9281526097961736),
#  ('sleek', 0.925792347357959),
#  ('compact', 0.9199482939025201),
#  ('working', 0.919827973335717),
#  ('weak', 0.9186278799771412),
#  ('ergonomic', 0.9101382669153677),
#  ('vaccumn', 0.9072210866146735),
#  ('wl', 0.9036961141150637),
#  ('wireless', 0.8894284625335158),
#  ('efficient', 0.8893021393021645),
#  ('lost', 0.8883019962821259),
#  ('experience', 0.8860352874094858),
#  ('adore', 0.8819214628663129),
#  ('adverdised', 0.8764752643733118),
#  ('charm', 0.8764752643733118),
#  ('reliable', 0.8737717394336341),
#  ('lil', 0.8727874542062988),
#  ('looks', 0.8715898123207375),
#  ('suck', 0.8703182287012978),
#  ('nicely', 0.8673504778564665),
#  ('soooo', 0.8583717588849188),
#  ('portable', 0.8551351605129558),
#  ('vehicles', 0.8465953068932188),
#  ('enough', 0.8441967124170318),
#  ('so', 0.8295133079777639),
#  ('bulky', 0.8293993088882787),
#  ('performance', 0.8265351915491672),
#  ('spills', 0.8257180946803452),
#  ('beast', 0.823954462293),
#  ('xmas', 0.8211018176069506),
#  ('friend', 0.8156335194460205),
#  ('guy', 0.813504750557142),
#  ('vacum', 0.8094883324640046),
#  ('useful', 0.8071093485287815),
#  ('awesome', 0.7993675914431366),
#  ('thank', 0.7985135754835307),
#  ('everyday', 0.7982951635890202),
#  ('terrible', 0.7968924662316946),
#  ('excellentgreat', 0.7958199556593055),
#  ('kind', 0.7912753083217404),
#  ('rechargeable', 0.7911167539516512),
#  ('mini', 0.7906007151280551),
#  ('runtime', 0.7905814968772553),
#  ('yes', 0.7887484587131423),
#  ('we', 0.7861795641822646),
#  ('lot', 0.7859378163031324),
#  ('vacume', 0.785778700112983),
#  ('fantastic', 0.7851908474670675),
#  ('by', 0.781391113784975),
#  ('pick', 0.7807288859646101),
#  ('care', 0.7804788605544065),
#  ('loud', 0.7800772412627072),
#  ('seller', 0.7762640922523335),
#  ('shark', 0.7751728352139222),
#  ('delivery', 0.7702269343865435),
#  ('bathroom', 0.768107066025965)]

# %%
# 第1群
get_top100_word(corpus_tfidf1)
# Out:
# [('units', 0.685567811018989),
#  ('rarely', 0.6789245846715205),
#  ('recharger', 0.6671123798704861),
#  ('unplugged', 0.6457825018992069),
#  ('lear', 0.6437777581700289),
#  ('promising', 0.6423393057519056),
#  ('expensive', 0.6274670906408097),
#  ('sue', 0.6203969808425336),
#  ('minivan', 0.6192272344284491),
#  ('fathers', 0.6012512423063152),
#  ('gadget', 0.5951981821971336),
#  ('thank', 0.594955869963961),
#  ('liter', 0.5863187971665441),
#  ('ease', 0.5834572495297763),
#  ('device', 0.5806580987526649),
#  ('shop', 0.568315773198723),
#  ('cooler', 0.5658238699755499),
#  ('lower', 0.5655014971029219),
#  ('banister', 0.5568334569439122),
#  ('totally', 0.5548171270553434),
#  ('heard', 0.5546811365821203),
#  ('held', 0.5521448991970239),
#  ('cobwebs', 0.5509028115803579),
#  ('reattach', 0.5499210255457946),
#  ('gifts', 0.5448369621228709),
#  ('homes', 0.5430132072792752),
#  ('kid', 0.5401250039722817),
#  ('rabbit', 0.5369642818912941),
#  ('delighted', 0.5362350250034739),
#  ('bust', 0.5231930898050932),
#  ('beet', 0.5197258852396511),
#  ('mount', 0.5133101706041818),
#  ('ex', 0.5088457070941225),
#  ('fed', 0.5088457070941225),
#  ('degradation', 0.5025102174640698),
#  ('lived', 0.4990816888857423),
#  ('boys', 0.499019313188404),
#  ('choices', 0.494698324197183),
#  ('stays', 0.49383859090995114),
#  ('thin', 0.4881203408675704),
#  ('preformed', 0.48729395715597873),
#  ('ont', 0.48729395715597873),
#  ('container', 0.4872504419965239),
#  ('lot', 0.48344876776049683),
#  ('level', 0.48203001790690825),
#  ('interiors', 0.4811298585904745),
#  ('offer', 0.4782771487239402),
#  ('highly', 0.47130270712345335),
#  ('indoor', 0.46566432953573245),
#  ('busters', 0.4618589077718028),
#  ('predecessor', 0.4613243979286919),
#  ('durability', 0.4613243979286919),
#  ('speak', 0.4613243979286919),
#  ('dad', 0.4601224649850503),
#  ('boat', 0.4590416470442498),
#  ('goes', 0.4590416470442498),
#  ('dogs', 0.4575043444667715),
#  ('real', 0.4557182180795472),
#  ('flies', 0.45435226123467976),
#  ('handful', 0.45355353803429543),
#  ('dont', 0.4521107956394799),
#  ('resting', 0.4516051083126316),
#  ('protectors', 0.45124614498428534),
#  ('plunging', 0.4501084334299491),
#  ('fir', 0.4483552023377454),
#  ('ups', 0.44802121566954306),
#  ('excellent', 0.442617149014318),
#  ('including', 0.44256390406373963),
#  ('nd', 0.44220490253231637),
#  ('agar', 0.4395913498018704),
#  ('hal', 0.4395913498018704),
#  ('voltage', 0.43934193667236326),
#  ('previous', 0.4390851508827546),
#  ('extensive', 0.4383210787054084),
#  ('four', 0.43781120355918857),
#  ('gotten', 0.43734247476223714),
#  ('money', 0.43632776749393826),
#  ('electricity', 0.43582117341628196),
#  ('re', 0.4297686020845402),
#  ('cone', 0.4294997136177011),
#  ('vertical', 0.42357745625458315),
#  ('nice', 0.4213936719070072),
#  ('sailboat', 0.420854645018983),
#  ('aboard', 0.420854645018983),
#  ('fritz', 0.4201976376567553),
#  ('bough', 0.4201976376567553),
#  ('compact', 0.41942889773410447),
#  ('wonderfully', 0.41824270746352804),
#  ('th', 0.4169433417619233),
#  ('fond', 0.4155320880379906),
#  ('why', 0.41475205208463545),
#  ('grown', 0.4131846357408884),
#  ('yr', 0.41259588167793365),
#  ('outdoor', 0.41259588167793365),
#  ('drawers', 0.410929852038132),
#  ('falls', 0.41080220134561746),
#  ('compacts', 0.4088297587482329),
#  ('knew', 0.40833082691754674),
#  ('delayed', 0.40833082691754674),
#  ('smaller', 0.40724913520685935)]

# %%
# 第2群
get_top100_word(corpus_tfidf2)
# Out:
# [('value', 0.8346208912748677),
#  ('vacume', 0.7316251607327761),
#  ('type', 0.6446479206789933),
#  ('sears', 0.632797606146837),
#  ('version', 0.6016493035964722),
#  ('market', 0.5958965201323219),
#  ('refreshinig', 0.5781894806842379),
#  ('okay', 0.5765441338162045),
#  ('diminishing', 0.5714139967305767),
#  ('nosle', 0.5617464510604265),
#  ('thinner', 0.5596928924632877),
#  ('jury', 0.5579429148509577),
#  ('costly', 0.5547510490342431),
#  ('snorkel', 0.5436300839051376),
#  ('sun', 0.5203359587182717),
#  ('saver', 0.5110696651299343),
#  ('shock', 0.5068060862886188),
#  ('tiring', 0.5048508235093695),
#  ('intertwined', 0.5044900120825452),
#  ('eaten', 0.5042714389253192),
#  ('quicker', 0.5042714389253192),
#  ('lighter', 0.5014081442427689),
#  ('spout', 0.4985018664744567),
#  ('champ', 0.49678031461006433),
#  ('waited', 0.4954484776102656),
#  ('price', 0.4953013332497273),
#  ('nowhere', 0.49481054805693403),
#  ('dwindled', 0.4936836393147584),
#  ('pants', 0.4851961183852254),
#  ('gone', 0.48388869736615825),
#  ('net', 0.48275593242509757),
#  ('nightly', 0.481604709036671),
#  ('mommy', 0.47850233577008816),
#  ('hearth', 0.47668490404865244),
#  ('downer', 0.4741944150195453),
#  ('lite', 0.4741944150195453),
#  ('timr', 0.4741944150195453),
#  ('spots', 0.4698451837006004),
#  ('stayed', 0.4681397531603825),
#  ('mounts', 0.4639110163979864),
#  ('wireless', 0.4612373633895786),
#  ('blows', 0.46095355458861603),
#  ('suuuuuper', 0.4599004378708257),
#  ('hanger', 0.4594220994531124),
#  ('ease', 0.45719524633981634),
#  ('seems', 0.45574215090199904),
#  ('scared', 0.4508144645423178),
#  ('folding', 0.4500477658211257),
#  ('equals', 0.44629177037666395),
#  ('local', 0.4428632474815773),
#  ('swallow', 0.44139000198200645),
#  ('hesitated', 0.4397524600179312),
#  ('inconvenient', 0.43257996326832193),
#  ('dedicated', 0.42956762396410664),
#  ('toddlers', 0.4268004601723708),
#  ('pregnant', 0.42612708168042296),
#  ('dinning', 0.42612708168042296),
#  ('birthday', 0.4251358284699337),
#  ('ensure', 0.42467792501960433),
#  ('turned', 0.423729468443995),
#  ('screeching', 0.42360148958247523),
#  ('compressor', 0.4213089703598166),
#  ('surprisingly', 0.41938706010271937),
#  ('hot', 0.4191755843050242),
#  ('curvature', 0.4189372136759616),
#  ('school', 0.417316404571754),
#  ('yore', 0.417316404571754),
#  ('implement', 0.4167905269979221),
#  ('generations', 0.4164117951375956),
#  ('mom', 0.41415263531260493),
#  ('unplug', 0.4138842941120524),
#  ('timei', 0.4120677993584556),
#  ('choices', 0.41197562330766874),
#  ('questions', 0.4117045999525101),
#  ('scatter', 0.41139429576431197),
#  ('bd', 0.4107538728869197),
#  ('pulls', 0.41039781568461536),
#  ('haul', 0.4090485790136041),
#  ('comb', 0.40777740645516863),
#  ('dull', 0.40670941220744394),
#  ('chargeable', 0.4062791563230261),
#  ('string', 0.4060362984323366),
#  ('checkstands', 0.403417370286477),
#  ('medium', 0.40306417653890986),
#  ('preschooler', 0.39956262224207056),
#  ('commented', 0.3982013361076016),
#  ('cute', 0.3974272089812227),
#  ('crummy', 0.39655680173075586),
#  ('seating', 0.39579003498427323),
#  ('applying', 0.39469134301659886),
#  ('fabrics', 0.3942142506155535),
#  ('dock', 0.3940345263617292),
#  ('chose', 0.3938791978213308),
#  ('boxes', 0.3937485629097978),
#  ('terrific', 0.3937485629097978),
#  ('allows', 0.3933900001787083),
#  ('beware', 0.39230895496736673),
#  ('expecting', 0.3917142416763917),
#  ('multiple', 0.3914352693467462),
#  ('blue', 0.39039441006955955)]

# %%
# 第3群
get_top100_word(corpus_tfidf3)
# Out:
# [('terrific', 1.0),
#  ('sweet', 1.0),
#  ('excellent', 1.0),
#  ('thanks', 1.0),
#  ('outstanding', 1.0),
#  ('like', 1.0),
#  ('fine', 1.0),
#  ('nice', 1.0),
#  ('fantastic', 1.0),
#  ('perfect', 1.0),
#  ('amazing', 1.0),
#  ('vacc', 0.9872071758096075),
#  ('vacume', 0.9846405686725631),
#  ('stuff', 0.9775733825750403),
#  ('pickup', 0.9775733825750403),
#  ('performance', 0.9721611104953328),
#  ('wonderfully', 0.9680330804010474),
#  ('wonders', 0.9680330804010474),
#  ('scam', 0.9596244206630317),
#  ('soo', 0.958550487389006),
#  ('low', 0.9528448679241986),
#  ('mild', 0.9492459649204018),
#  ('suctions', 0.9486201727137978),
#  ('deal', 0.9430685880796237),
#  ('reliable', 0.9321521735441144),
#  ('absolutely', 0.9300481668889337),
#  ('handling', 0.9290320284184058),
#  ('substantial', 0.9258415906799033),
#  ('medium', 0.9258365945038114),
#  ('useful', 0.9256196339683916),
#  ('mini', 0.9188951777909024),
#  ('bad', 0.918774052623176),
#  ('extremely', 0.9187354632234482),
#  ('daily', 0.9143785402911384),
#  ('dependable', 0.9002979882635925),
#  ('practical', 0.8955863069754133),
#  ('greatvsuction', 0.8948175016468076),
#  ('ship', 0.8941932786089426),
#  ('love', 0.8837097390558695),
#  ('everyone', 0.8826445483409368),
#  ('charm', 0.8790091774438175),
#  ('design', 0.8782494412843173),
#  ('vaccuum', 0.8781135924951757),
#  ('advertised', 0.8733973214458699),
#  ('champ', 0.87289129086184),
#  ('quality', 0.8724902545107445),
#  ('fast', 0.8690824520190841),
#  ('service', 0.8644925882147021),
#  ('pricy', 0.8633134384887899),
#  ('likea', 0.8627799792669777),
#  ('ver', 0.862028521805371),
#  ('amazingly', 0.8602986087423276),
#  ('investment', 0.8502079741724198),
#  ('mobile', 0.8427027962189589),
#  ('batterie', 0.8417587900135266),
#  ('lovely', 0.8390892675169659),
#  ('lots', 0.837314054133397),
#  ('maintain', 0.836738610609039),
#  ('tool', 0.8365982839545603),
#  ('wonderful', 0.8362194530830482),
#  ('powerhouse', 0.8336157655922217),
#  ('size', 0.833236816122938),
#  ('complaints', 0.832326238532003),
#  ('saved', 0.8289642352217739),
#  ('isn', 0.8216614266867192),
#  ('terrible', 0.8196066591116978),
#  ('solid', 0.816868122337448),
#  ('promised', 0.8146084708617723),
#  ('travel', 0.8134809858301995),
#  ('enjoy', 0.8116776346768116),
#  ('handel', 0.8115277356927778),
#  ('excepted', 0.8105327654953332),
#  ('slick', 0.8085266201466477),
#  ('efficiently', 0.8082785584487604),
#  ('product', 0.8065908096527166),
#  ('sized', 0.8060680738383431),
#  ('look', 0.8053369780536318),
#  ('vaccum', 0.8052088951825179),
#  ('delivery', 0.8033610634302852),
#  ('looove', 0.8020126021602618),
#  ('weaker', 0.8009036478749494),
#  ('forever', 0.7998347647294214),
#  ('me', 0.7963766807204273),
#  ('packaged', 0.7955051463050267),
#  ('spot', 0.7951261609849317),
#  ('sucked', 0.7943696929516523),
#  ('husband', 0.7939388659338372),
#  ('sufficiently', 0.7933097592525509),
#  ('impossible', 0.7913873139753536),
#  ('nothing', 0.7884192209639448),
#  ('pos', 0.7865830658944524),
#  ('term', 0.7857949302818825),
#  ('rather', 0.7850742809281095),
#  ('doing', 0.7843545001433685),
#  ('fan', 0.7842499162941409),
#  ('powerful', 0.7840665417536947),
#  ('gadget', 0.7810954769808652),
#  ('beast', 0.7798625096401266),
#  ('simple', 0.7795985044028397),
#  ('function', 0.7773581032043266)]

# %%
# 第4群
get_top100_word(corpus_tfidf4)
# Out:
# [('win', 0.8543330144397026),
#  ('dont', 0.807738174543703),
#  ('reasonable', 0.7759143300926981),
#  ('complaints', 0.7718141612380178),
#  ('wicked', 0.7663174915040077),
#  ('stayed', 0.7618982144039957),
#  ('tad', 0.7599390706268272),
#  ('clog', 0.7432931156667428),
#  ('dad', 0.7428137782802501),
#  ('sh', 0.7407214574832928),
#  ('strongest', 0.7265570421312121),
#  ('likes', 0.720094431553784),
#  ('moths', 0.7169311572384105),
#  ('supposedly', 0.7146719722327157),
#  ('effective', 0.7146331328940123),
#  ('input', 0.7105801780264135),
#  ('frustrating', 0.6986161739696377),
#  ('overcharging', 0.6926032404234269),
#  ('rave', 0.6898949577553914),
#  ('looking', 0.6896939192658461),
#  ('unavoidable', 0.6889326948111658),
#  ('weird', 0.6758232145251766),
#  ('goodi', 0.6722263607162777),
#  ('mounting', 0.6708494194248165),
#  ('collected', 0.670708983984788),
#  ('worries', 0.6672522057532239),
#  ('grabbing', 0.6586049950731803),
#  ('sale', 0.6576955103433022),
#  ('decent', 0.6570063528267011),
#  ('tools', 0.6567365166473522),
#  ('usefulness', 0.6565917488196247),
#  ('keeps', 0.6466878439414495),
#  ('ncaid', 0.6402039180993638),
#  ('neck', 0.6386796115456841),
#  ('operate', 0.6364821284681392),
#  ('fabric', 0.6362636971017106),
#  ('glad', 0.635769061992055),
#  ('considerable', 0.6356330626538189),
#  ('wearing', 0.6350999001704986),
#  ('sturdy', 0.6343698330531037),
#  ('thumbs', 0.6294230922623467),
#  ('uper', 0.628608224241829),
#  ('chance', 0.6264883479373345),
#  ('dissapointed', 0.6240806816077402),
#  ('solves', 0.6230269107213098),
#  ('duster', 0.6224411059325708),
#  ('stronger', 0.620795362898605),
#  ('gifts', 0.6173824897773749),
#  ('wound', 0.6171168192945693),
#  ('ruining', 0.6167125087125251),
#  ('home', 0.6151878409481544),
#  ('blinds', 0.6151188187960621),
#  ('handvacs', 0.6120622966571614),
#  ('enjoying', 0.6098539433790373),
#  ('forever', 0.6098196369431103),
#  ('greatest', 0.6097169850416062),
#  ('expect', 0.6092343022581062),
#  ('wonderful', 0.6088122513164882),
#  ('broke', 0.6085401966361773),
#  ('mother', 0.6074661423814879),
#  ('gem', 0.6068923838371554),
#  ('hope', 0.6068483871182131),
#  ('maneuver', 0.6064529462494866),
#  ('holster', 0.6063403027212456),
#  ('version', 0.6014040442068465),
#  ('serves', 0.5995628239075569),
#  ('promised', 0.5978015815907921),
#  ('lite', 0.5953548362858206),
#  ('puppy', 0.5952400828982964),
#  ('habe', 0.5946828135266841),
#  ('portion', 0.5945275938618004),
#  ('stair', 0.5938882377333495),
#  ('adapter', 0.5933493205245048),
#  ('quiet', 0.592970231108967),
#  ('filters', 0.5923258261651784),
#  ('rocks', 0.5905579936960509),
#  ('provide', 0.5902396944839154),
#  ('expecting', 0.5896800596568029),
#  ('warned', 0.587684160065581),
#  ('mostly', 0.5871670476284198),
#  ('qualm', 0.5864035592716549),
#  ('often', 0.5863535950760163),
#  ('built', 0.584689759271033),
#  ('hang', 0.5844929227640638),
#  ('mechanism', 0.5828199219435171),
#  ('fairly', 0.5825571129920014),
#  ('operating', 0.582424941196383),
#  ('abused', 0.5816652508011679),
#  ('unbelievable', 0.5812781938877113),
#  ('weren', 0.5802482355078479),
#  ('dirts', 0.5799268660782326),
#  ('somehow', 0.5797774530002481),
#  ('kick', 0.577980394325945),
#  ('nose', 0.5766321709346383),
#  ('cheaply', 0.576236131368962),
#  ('carpets', 0.5753171505454668),
#  ('bracket', 0.5750077650426937),
#  ('ut', 0.5749354732531238),
#  ('source', 0.5746747140553796),
#  ('wish', 0.5711271688179841)]

# %%
# 第5群
get_top100_word(corpus_tfidf5)
# Out:
# [('outstanding', 0.9229908642392328),
#  ('experience', 0.9122564097309335),
#  ('neded', 0.9032716967471295),
#  ('advertized', 0.8933532480352355),
#  ('van', 0.877507154842853),
#  ('described', 0.8545361363480172),
#  ('powerfull', 0.8411997179897919),
#  ('hr', 0.836660439436862),
#  ('gud', 0.8366107017404749),
#  ('neat', 0.835097442026527),
#  ('suv', 0.8293099538424115),
#  ('powerhouse', 0.8275445828149594),
#  ('awhile', 0.8214528499619163),
#  ('loses', 0.8092932712456169),
#  ('excellent', 0.8073958658178326),
#  ('poor', 0.8072414177705178),
#  ('imo', 0.7994586382940285),
#  ('transaction', 0.7976188909529914),
#  ('deliver', 0.7959148399427705),
#  ('wanted', 0.7910717156118758),
#  ('dispensing', 0.7903393785426276),
#  ('effecient', 0.7873344371917465),
#  ('news', 0.7868323592579363),
#  ('drain', 0.7833984072071166),
#  ('tho', 0.7817739710965269),
#  ('garbage', 0.7807587752924132),
#  ('workshop', 0.7785667258345405),
#  ('convient', 0.7710762957247763),
#  ('piercingly', 0.7701851260584716),
#  ('stove', 0.7684212134830204),
#  ('truck', 0.7679790085327562),
#  ('amount', 0.766741803036449),
#  ('usability', 0.7654008873248384),
#  ('boats', 0.7631919263047738),
#  ('meh', 0.7621014013197689),
#  ('replicable', 0.761349911112228),
#  ('cottage', 0.7587362943403501),
#  ('heaven', 0.7586458938538603),
#  ('promised', 0.757365172218435),
#  ('comes', 0.7565029029365515),
#  ('retuned', 0.7564621970816313),
#  ('grit', 0.7538409723519033),
#  ('clumsy', 0.752826165363133),
#  ('thinks', 0.7526667474983777),
#  ('parakeet', 0.7513866648025512),
#  ('date', 0.7484364454803338),
#  ('extremely', 0.7471217769833255),
#  ('aftwr', 0.7465663589281722),
#  ('nice', 0.743940292389296),
#  ('stronger', 0.7428133817025708),
#  ('complaints', 0.7419449406459535),
#  ('surpass', 0.7387198768565212),
#  ('job', 0.7371726216447598),
#  ('needed', 0.7357893544256655),
#  ('wath', 0.7354172342866105),
#  ('third', 0.73149439742463),
#  ('assembly', 0.7281016169850208),
#  ('cleanups', 0.7252148204872327),
#  ('single', 0.7236924956923193),
#  ('seven', 0.721353526388088),
#  ('board', 0.7186297016871573),
#  ('getter', 0.7164701985527929),
#  ('bursts', 0.7163737989737241),
#  ('badass', 0.7156847515004698),
#  ('inadequately', 0.7149075447148889),
#  ('holding', 0.7143687316422959),
#  ('features', 0.7117675324681287),
#  ('propertly', 0.7064888594767297),
#  ('clever', 0.7054023820657748),
#  ('joke', 0.704628826229154),
#  ('color', 0.7032900294870033),
#  ('keeps', 0.701507916292704),
#  ('below', 0.7005432111086405),
#  ('helper', 0.6981222000235288),
#  ('grandma', 0.6975468850560554),
#  ('cradle', 0.6965274829995494),
#  ('vacumming', 0.6948707638704119),
#  ('nifty', 0.693263039367047),
#  ('whorthless', 0.6924837063051428),
#  ('housework', 0.690785430743804),
#  ('kid', 0.6906344815379487),
#  ('esy', 0.6878317212068259),
#  ('fantastic', 0.6874510937587485),
#  ('missing', 0.6858951398120806),
#  ('guy', 0.6831568961843953),
#  ('provides', 0.6825051031180536),
#  ('motor', 0.6820100440095984),
#  ('mike', 0.6811148029909138),
#  ('exceeded', 0.6808396944000237),
#  ('wireless', 0.6768386116414394),
#  ('pickups', 0.6758661875594908),
#  ('dandy', 0.6754156806194633),
#  ('yo', 0.675214052237125),
#  ('didnt', 0.6746419724323559),
#  ('whaaa', 0.6743306084956512),
#  ('match', 0.6735768012556427),
#  ('much', 0.6734429291753221),
#  ('caps', 0.6729960593540848),
#  ('usual', 0.6700051664189949),
#  ('solidly', 0.6696876544724726)]

# %%
# 第6群
get_top100_word(corpus_tfidf6)
# Out:
# [('repeat', 0.6521550107610949),
#  ('doesnt', 0.6445329065898524),
#  ('god', 0.6097580503035002),
#  ('depleted', 0.5900148929828237),
#  ('remains', 0.5819648736715688),
#  ('van', 0.5807018888293853),
#  ('attachmt', 0.5765513171118385),
#  ('buddy', 0.5756031402948714),
#  ('ch', 0.5594293306986394),
#  ('chord', 0.5435930066408104),
#  ('shop', 0.5415824958514153),
#  ('shape', 0.5343063430445164),
#  ('placing', 0.5316893884075758),
#  ('sweeper', 0.5252766547817657),
#  ('sweeps', 0.5252766547817657),
#  ('champ', 0.5252766547817657),
#  ('happened', 0.5224059357022494),
#  ('slowing', 0.5194940526126444),
#  ('family', 0.5152054685436476),
#  ('soda', 0.5030481199431515),
#  ('lid', 0.502402949325884),
#  ('reasonable', 0.5013338652502458),
#  ('adjustable', 0.49832307261414105),
#  ('upper', 0.4924153483020839),
#  ('wonder', 0.48717269840374355),
#  ('feb', 0.48569333851265306),
#  ('noisey', 0.48402728407082146),
#  ('collapses', 0.48402728407082146),
#  ('version', 0.4807715085092224),
#  ('relatively', 0.47649363249965626),
#  ('gathers', 0.47416378859232444),
#  ('portable', 0.4728936815984886),
#  ('rowenta', 0.4692482327094628),
#  ('greatly', 0.46820346988677053),
#  ('operates', 0.46820346988677053),
#  ('cannister', 0.46606939272614667),
#  ('aspiration', 0.46510913666352843),
#  ('paws', 0.463657156263211),
#  ('suit', 0.4632252541529036),
#  ('ago', 0.46210325709114514),
#  ('falls', 0.4563243588495441),
#  ('excellent', 0.45387506426323304),
#  ('baking', 0.4482641387088193),
#  ('correctly', 0.4461429706842134),
#  ('phv', 0.4458306893565143),
#  ('incident', 0.4452060055219134),
#  ('suck', 0.4448701259785237),
#  ('prime', 0.4434239645086894),
#  ('tippy', 0.4432002272007745),
#  ('inlet', 0.4432002272007745),
#  ('cleverly', 0.4431229437438217),
#  ('thorough', 0.4431229437438217),
#  ('ceased', 0.44133970468220285),
#  ('im', 0.441147673374645),
#  ('styles', 0.44036514490454465),
#  ('amount', 0.4396707958346751),
#  ('handful', 0.4393335100293476),
#  ('sizing', 0.4388100426350756),
#  ('recommende', 0.43875849917875687),
#  ('ancestor', 0.43875849917875687),
#  ('phones', 0.43744234727080017),
#  ('judge', 0.43355334766840486),
#  ('vacumn', 0.42821398297604296),
#  ('opens', 0.42820489839857206),
#  ('truly', 0.4269550797117896),
#  ('hampers', 0.4250496225400558),
#  ('airplane', 0.41701185527801254),
#  ('foggy', 0.41701185527801254),
#  ('received', 0.4163992112505633),
#  ('dark', 0.41621451749724037),
#  ('orient', 0.416173077462232),
#  ('socket', 0.415197650881791),
#  ('cleanings', 0.41479920487937827),
#  ('second', 0.41419028292007715),
#  ('everyday', 0.4135634286800122),
#  ('rabbit', 0.4133363388606304),
#  ('pedestal', 0.4132820219352698),
#  ('represented', 0.4124264836297683),
#  ('xmas', 0.41063003729178893),
#  ('air', 0.4069009386451805),
#  ('spots', 0.40638841529041647),
#  ('gap', 0.4061053586839458),
#  ('stinkbug', 0.4060908827117031),
#  ('catching', 0.4033867876280787),
#  ('smart', 0.40143578869407315),
#  ('cage', 0.40143578869407315),
#  ('fair', 0.4010764997823944),
#  ('nicd', 0.4008020168296036),
#  ('obscure', 0.39938971858577976),
#  ('clogged', 0.39897597229302817),
#  ('night', 0.3987316440284179),
#  ('beautifully', 0.3982944430841758),
#  ('rv', 0.39721838318657143),
#  ('odd', 0.39474323027103975),
#  ('busy', 0.3940887776208694),
#  ('vet', 0.3940887776208694),
#  ('clinic', 0.3940887776208694),
#  ('abut', 0.39400215081071027),
#  ('loads', 0.39324265247424606),
#  ('amounts', 0.391797947304951)]

# %%
# 試一下NLTK
import nltk
from nltk.corpus import treebank

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
print(corpus_clu0_wordlist[1])
# Out:
# ['power', 'is', 'great', 'holds', 'good', 'charge', 'my', 'previous', 'one', 'had', 'fixture', 'to', 'hold', 'it', 'on', 'the', 'wall', 'for', 'this', 'one', 'the', 'recharging', 'base', 'sits', 'on', 'the', 'floor', 'and', 'if', 'knocked', 'over', 'or', 'set', 'slightly', 'off', 'the', 'base', 'it', 'doesn', 'charge']

# %%
# 標籤詞性
tagged = nltk.pos_tag(corpus_clu0_wordlist[1])

# %%
tagged[0:]
# Out:
# [('power', 'NN'),
#  ('is', 'VBZ'),
#  ('great', 'JJ'),
#  ('holds', 'VBZ'),
#  ('good', 'JJ'),
#  ('charge', 'NN'),
#  ('my', 'PRP$'),
#  ('previous', 'JJ'),
#  ('one', 'CD'),
#  ('had', 'VBD'),
#  ('fixture', 'NN'),
#  ('to', 'TO'),
#  ('hold', 'VB'),
#  ('it', 'PRP'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('wall', 'NN'),
#  ('for', 'IN'),
#  ('this', 'DT'),
#  ('one', 'CD'),
#  ('the', 'DT'),
#  ('recharging', 'NN'),
#  ('base', 'NN'),
#  ('sits', 'VBZ'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('floor', 'NN'),
#  ('and', 'CC'),
#  ('if', 'IN'),
#  ('knocked', 'VBN'),
#  ('over', 'IN'),
#  ('or', 'CC'),
#  ('set', 'VBN'),
#  ('slightly', 'RB'),
#  ('off', 'IN'),
#  ('the', 'DT'),
#  ('base', 'NN'),
#  ('it', 'PRP'),
#  ('doesn', 'VBZ'),
#  ('charge', 'NN')]

# %%
entities = nltk.chunk.ne_chunk(tagged)

# %%
print(entities)
# Out:
# (S
#   power/NN
#   is/VBZ
#   great/JJ
#   holds/VBZ
#   good/JJ
#   charge/NN
#   my/PRP$
#   previous/JJ
#   one/CD
#   had/VBD
#   fixture/NN
#   to/TO
#   hold/VB
#   it/PRP
#   on/IN
#   the/DT
#   wall/NN
#   for/IN
#   this/DT
#   one/CD
#   the/DT
#   recharging/NN
#   base/NN
#   sits/VBZ
#   on/IN
#   the/DT
#   floor/NN
#   and/CC
#   if/IN
#   knocked/VBN
#   over/IN
#   or/CC
#   set/VBN
#   slightly/RB
#   off/IN
#   the/DT
#   base/NN
#   it/PRP
#   doesn/VBZ
#   charge/NN)

# %%
# 試一下StanfordDependencyParser
from nltk.parse.stanford import StanfordDependencyParser
import os

# %%
# 載入環境變數
os.environ["JAVA_HOME"] = "C:/Program Files/Java/jdk1.8.0_111" 
os.environ["CLASSPATH"] = "C:/Users/lisrba/Documents/StanfordNLP/StanfordNLP/jars"
os.environ["STANFORD_MODELS"] = "C:/Users/lisrba/Documents/StanfordNLP/StanfordNLP/models"

# %%
# 簡單測試
eng_parser = StanfordDependencyParser()
res = list(eng_parser.parse("the quick brown fox jumps over the lazy dog".split()))
for row in res[0].triples():
    print(row)
# Out:
# (('fox', 'NN'), 'det', ('the', 'DT'))
# (('fox', 'NN'), 'amod', ('quick', 'JJ'))
# (('fox', 'NN'), 'amod', ('brown', 'JJ'))
# (('fox', 'NN'), 'dep', ('jumps', 'NNS'))
# (('jumps', 'NNS'), 'nmod', ('dog', 'NN'))
# (('dog', 'NN'), 'case', ('over', 'IN'))
# (('dog', 'NN'), 'det', ('the', 'DT'))
# (('dog', 'NN'), 'amod', ('lazy', 'JJ'))

# %%
# 拿評論測試
abc = list(eng_parser.parse(corpus_clu0_wordlist[111]))

# %%
for row in abc[0].triples():
    print(row)
# Out:
# (('light', 'JJ'), 'dep', ('motor', 'NN'))
# (('motor', 'NN'), 'amod', ('great', 'JJ'))
# (('motor', 'NN'), 'amod', ('powerful', 'JJ'))
# (('motor', 'NN'), 'cc', ('and', 'CC'))
# (('motor', 'NN'), 'conj', ('suction', 'NN'))
# (('suction', 'NN'), 'amod', ('great', 'JJ'))
# (('light', 'JJ'), 'advmod', ('very', 'RB'))
# (('light', 'JJ'), 'cc', ('and', 'CC'))
# (('light', 'JJ'), 'conj', ('great', 'JJ'))
# (('great', 'JJ'), 'advmod', ('works', 'RB'))

# %%
#python2
#filetest = open("C:"+os.sep+"temp"+os.sep+"file.txt", "w",encoding='utf-8')
#filetest.write(str(corpus_clu0[0].words))
#filetest.close()

# %%
# python3 I/O
with open("C:"+os.sep+"temp"+os.sep+"file.txt", "a",encoding='utf-8') as filetest:
    filetest.write(str(corpus_clu0[0].words))

# %% [markdown]
# ##### NLTK 7. Extracting Information from Text
# http://www.nltk.org/book/ch07.html
#
# ##### 4.2. Feature extraction
# http://scikit-learn.org/stable/modules/feature_extraction.html
#
# #####  sklearn.feature_extraction.text.TfidfVectorizer
# http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html
#
# ##### python之最強王者（10）———文件(File)、輸入輸出的基本操作
# http://www.zendei.com/article/17118.html
#
# ##### Clustering text documents using k-means
# http://scikit-learn.org/stable/auto_examples/text/document_clustering.html#sphx-glr-auto-examples-text-document-clustering-py
#
# ##### 自然語言處理 -- TF-IDF
# http://cpmarkchang.logdown.com/posts/193915-natural-language-processing-tf-idf
#
# ##### Python TF-IDF计算100份文档关键词权重
# http://www.cnblogs.com/chenbjin/p/3851165.html
