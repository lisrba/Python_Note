# %%
import os
import gensim
from gensim import corpora, models
import smart_open 
import numpy as np
from numpy import random
random.seed(555)
from scipy.cluster.vq import vq, kmeans, whiten
from sklearn.decomposition import TruncatedSVD
from collections import defaultdict
# Out:
# C:\Users\lisrba\Anaconda3\lib\site-packages\gensim\utils.py:855: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# 檔案路徑
amazon_corpus_path = "C:" + os.sep + "temp" + os.sep + "BLACK-DECKER.csv"

# %%
# 斷詞 & 標籤
def read_corpus(fname, tokens_only=False):
    with smart_open.smart_open(fname, encoding="iso-8859-1") as f:
        for i, line in enumerate(f):
            if tokens_only:
                yield gensim.utils.simple_preprocess(line)
            else:
                # For training data, add tags
                yield gensim.models.doc2vec.LabeledSentence(gensim.utils.simple_preprocess(line), ['SENT_%s' % i])

# %%
# 訓練組與測試組
train_corpus = list(read_corpus(amazon_corpus_path))
test_corpus = list(read_corpus(amazon_corpus_path, tokens_only=True))

# %%
train_corpus[:2]
# Out:
# [LabeledSentence(words=['ve', 'owned', 'some', 'type', 'of', 'dustbuster', 'handvac', 'for', 'the', 'last', 'twenty', 'years', 'and', 'don', 'think', 've', 'ever', 'ever', 'had', 'one', 'that', 'didn', 'hate', 'too', 'little', 'suction', 'power', 'not', 'enough', 'charge', 'time', 'the', 'suction', 'nozzle', 'is', 'awkward', 'to', 'use', 'and', 'the', 'batteries', 'are', 'always', 'dead', 'after', 'couple', 'minutes', 'can', 'keep', 'them', 'plugged', 'into', 'the', 'wall', 'all', 'the', 'time', 'but', 'that', 'kills', 'the', 'battery', 'and', 'wastes', 'electricity', 'have', 'found', 'it', 'much', 'more', 'effective', 'to', 'just', 'use', 'the', 'suction', 'hose', 'on', 'my', 'upright', 'even', 'though', 'that', 'means', 'lugging', 'my', 'vacuum', 'around', 'so', 'decided', 'to', 'see', 'what', 'is', 'new', 'in', 'handvac', 'technology', 'and', 'if', 'they', 'have', 'improved', 'at', 'all', 'over', 'the', 'last', 'ten', 'years', 'fortunately', 'can', 'say', 'that', 'they', 'have', 'the', 'black', 'and', 'decker', 'lithium', 'ion', 'dustbuster', 'is', 'the', 'same', 'handvac', 'as', 'the', 'black', 'decker', 'chv', 'dustbuster', 'volt', 'cordless', 'cyclonic', 'hand', 'vac', 'except', 'it', 'contains', 'lithium', 'ion', 'lib', 'battery', 'whereas', 'the', 'standard', 'chv', 'contains', 'nickel', 'cadmium', 'ni', 'cd', 'battery', 'if', 'you', 're', 'trying', 'to', 'decide', 'between', 'the', 'two', 'devices', 'would', 'recommend', 'this', 'lithium', 'ion', 'model', 'due', 'to', 'the', 'advantages', 'of', 'the', 'battery', 'higher', 'energy', 'density', 'this', 'means', 'that', 'the', 'lib', 'battery', 'can', 'hold', 'more', 'energy', 'per', 'volume', 'in', 'this', 'case', 'the', 'chv', 'holds', 'about', 'twice', 'the', 'amount', 'of', 'energy', 'as', 'the', 'chv', 'greater', 'power', 'density', 'this', 'refers', 'to', 'bursts', 'of', 'power', 'the', 'battery', 'is', 'capable', 'it', 'works', 'well', 'when', 'combined', 'with', 'the', 'higher', 'energy', 'density', 'mentioned', 'above', 'no', 'memory', 'effect', 'this', 'is', 'something', 'you', 'might', 'have', 'noticed', 'with', 'ni', 'cd', 'battery', 'these', 'batteries', 'work', 'best', 'when', 'you', 'fully', 'discharge', 'the', 'battery', 'and', 'then', 'recharge', 'it', 'with', 'dustbuster', 'you', 're', 'almost', 'never', 'going', 'to', 'do', 'this', 'you', 'll', 'use', 'it', 'for', 'few', 'minutes', 'then', 'put', 'it', 'back', 'on', 'the', 'mount', 'to', 'charge', 'this', 'can', 'sometimes', 'product', 'memory', 'effect', 'where', 'the', 'cadmium', 'inside', 'the', 'battery', 'forms', 'crystals', 'and', 'the', 'battery', 'will', 'hold', 'less', 'of', 'charge', 'lib', 'battery', 'does', 'not', 'experience', 'memory', 'effect', 'non', 'toxic', 'ni', 'cd', 'batteries', 'are', 'toxic', 'and', 'classified', 'as', 'hazardous', 'lib', 'aren', 'so', 'disposal', 'is', 'much', 'better', 'for', 'the', 'environment', 'lib', 'do', 'have', 'couple', 'small', 'disadvantages', 'but', 'in', 'this', 'application', 'and', 'with', 'the', 'frequent', 'recharging', 'the', 'dustbuster', 'will', 'see', 'feel', 'that', 'it', 'is', 'definitely', 'the', 'right', 'choice', 'not', 'to', 'mention', 'the', 'toxicity', 'factor', 'alone', 'makes', 'me', 'feel', 'better', 'about', 'using', 'this', 'type', 'of', 'battery', 'use', 'and', 'operation', 'evaluated', 'both', 'the', 'chv', 'and', 'the', 'standard', 'chv', 'at', 'the', 'same', 'time', 'to', 'see', 'what', 'the', 'real', 'difference', 'was', 'between', 'the', 'devices', 'and', 'how', 'the', 'battery', 'affected', 'them', 'the', 'main', 'thing', 'like', 'about', 'the', 'chv', 'does', 'have', 'to', 'do', 'with', 'the', 'battery', 'it', 'will', 'supposedly', 'hold', 'charge', 'for', 'up', 'to', 'months', 'can', 'confirm', 'if', 'this', 'is', 'true', 'but', 'the', 'first', 'time', 'had', 'it', 'gave', 'it', 'full', 'charge', 'and', 'then', 'removed', 'it', 'from', 'the', 'power', 'source', 'and', 'let', 'it', 'sit', 'uncharged', 'for', 'days', 'whe ...
#  LabeledSentence(words=['awesome', 'power', 'at', 'first', 'did', 'not', 'like', 'the', 'fact', 'that', 'it', 'could', 'not', 'be', 'hung', 'up', 'on', 'the', 'wall', 'with', 'the', 'charger', 'plugging', 'into', 'it', 'like', 'my', 'previous', 'dustbusters', 'didn', 'have', 'extra', 'tabletop', 'space', 'to', 'store', 'it', 'flat', 'but', 'once', 'found', 'spot', 'for', 'it', 'it', 'is', 'nice', 'to', 'just', 'rest', 'it', 'on', 'its', 'base', 'and', 'not', 'deal', 'with', 'wires', 'and', 'decisions', 'to', 'connect', 'to', 'charger', 'or', 'not', 'it', 'just', 'is', 'always', 'fully', 'charged', 'have', 'not', 'yet', 'experienced', 'it', 'running', 'out', 'of', 'power', 'during', 'pickup', 'session', 'altho', 'do', 'tend', 'to', 'just', 'use', 'it', 'for', 'quickie', 'pickups', 'plan', 'to', 'push', 'its', 'limits', 'in', 'the', 'future', 'to', 'see', 'just', 'how', 'long', 'it', 'can', 'run', 'on', 'full', 'charge', 'the', 'fact', 'that', 'it', 'is', 'lithium', 'ion', 'is', 'great', 'that', 'it', 'should', 'last', 'longer', 'and', 'perform', 'better', 'than', 'previous', 'nicad', 'batteries', 'after', 'few', 'years', 'the', 'old', 'style', 'dustbusters', 'just', 'don', 'take', 'charge', 'well', 'fyi', 'used', 'two', 'fat', 'shaped', 'hooks', 'mounted', 'few', 'inches', 'apart', 'on', 'the', 'wall', 'to', 'create', 'platform', 'for', 'the', 'vac', 'll', 'post', 'picture', 'if', 'don', 'see', 'similar', 'pic'], tags=['SENT_1'])]

# %%
# 建模
model = models.Doc2Vec(alpha=0.025, min_alpha=0.025)  # use fixed learning rate
model.build_vocab(train_corpus)

# %%
# 學習（學習速率遞減）
epoch = 10
for _ in range(epoch):
    model.train(train_corpus)
    model.alpha -= 0.002  # decrease the learning rate
    model.min_alpha = model.alpha  # fix the learning rate, no decay
print ('done training')
# Out:
# done training

# %%
# 儲存模型
model.save("C:" + os.sep + "temp" + os.sep +"try.d2v")

# %%
# 載入模型
model = gensim.models.Doc2Vec.load("C:" + os.sep + "temp" + os.sep +"try.d2v")

# %%
# 把每篇文章的向量塞進矩陣裡面
lenx=len(train_corpus)
leny=len(model.infer_vector(train_corpus[0].words))
print(lenx,leny)
a = np.zeros((lenx,leny))
for i_sent in range(len(train_corpus)):
    a[i_sent,:] = model.infer_vector(test_corpus[i_sent])
print(a[:2])
# Out:
# 9362 100
# [[ 0.91893691 -0.25788108  1.84998441  0.11234858 -2.46256018 -0.49450001
#    0.14411953 -0.5181275   0.27060199  0.22007766 -0.90371591 -0.42633575
#   -1.03870964 -0.90186334  0.76243496 -1.53511012 -0.0610662  -1.20328557
#   -0.59060353  1.63943064 -0.74973261  0.97232139  0.61992282 -0.95465875
#    1.57215083 -0.81540394  2.1525743   1.29551339 -1.51895964  0.07195573
#    0.50540882 -0.33654842 -1.16719294 -0.58698267  0.38133293 -0.58228415
#    0.11161171  0.5160718  -0.54661995 -0.56649339 -0.04003856  0.79407054
#    1.61801136  0.39664221  0.56881511  0.29280883  0.1439618   1.09199226
#   -1.74520838 -0.37423113  1.63765132 -0.9377467  -0.86362076 -1.78516603
#   -1.48999083 -0.31300369 -0.51769322 -0.28051028 -0.93538976  0.95480072
#    0.10389411 -1.4914149   0.39116448 -0.52631855  0.70351726  1.34742332
#    0.01329369  0.34379762 -0.09115305  1.05434239 -1.30771983 -0.06083123
#    0.3133426   0.92537606  0.80035371  0.17099653  1.33099747 -0.21025081
#   -0.40435165 -1.55230629  0.12696768  1.63029182  1.25792599 -1.26723027
#   -1.24832296  0.15741383  0.01347363  0.49229953 -0.32722875  1.09511685
#   -0.38700864 -0.0502823  -1.04424584 -0.36357167  0.82045013  0.77440453
#   -0.17094162  0.90590072 -0.68532109  1.3609978 ]
#  [ 0.19552229  0.28443378 -0.34926325 -0.34200546 -0.74305105 -0.40683833
#    0.61816126 -0.032386    0.1039675   0.63680506 -0.88725311  0.16937502
#   -0.14933802 -1.19610417  0.61271077  0.1570932   0.25879481 -0.79597729
#   -0.07596328  0.47256178 -0.24662098  0.29070613  0.26270434 -0.17144851
#    0.64756    -0.48593989 -0.44061708 -0.01258899  0.07550164 -0.52673346
#   -0.03698645 -0.46291819 -0.31559858 -0.04498021 -0.07550742 -0.19990043
#   -0.60550714 -0.40948346  0.68619233  0.96022683 -0.03559751  0.46715078
#    0.57723296 -0.69963616  0.61006826  0.13369597 -0.9012422  -0.50912625
#    0.3586663  -0.99166864  0.14760487  0.18375511 -0.88861489  0.67186338
#   -0.68705589 -0.04274802  0.58226389 -0.09454425 -0.11505003 -0.47228074
#    0.42702848 -0.05909895  0.2585853  -0.15505686 -0.03644018  0.03664482
#   -0.26564267  0.35194421  0.23383227 -0.46705544 -0.34511802 -0.24963005
#   -0.34080046  0.22943196 -0.14087379 -0.25433859  0.85831308  0.10805832
#   -0.0399389  -0.58955234 -0.48506197  0.32645357  0.5938186   0.19810326
#   -0.694493    0.11086463 -0.24037369  1.08337164  0.06236674  0.58975208
#   -0.15691188  0.032611   -0.22543691  0.06053812  0.26502687  0.20471513
#    0.55204833 -0.11846983  0.72865456 -0.19622862]]

# %%
# 正規化（？）
sim_matrix = whiten(a)

# %%
# Kmeans分7群（7是隨便挑的，之後要用elbow method或輪廓係數找最佳群組數）
centroid, destortion = kmeans(sim_matrix, 7, iter=100, thresh=1e-05)
labels, dist = vq(sim_matrix, centroid)
print(labels[0])
# Out:
# 5

# %%
# 按標籤將屬於該群的文章INDEX存起來

cluster0 = []
cluster1 = []
cluster2 = []
cluster3 = []
cluster4 = []
cluster5 = []
cluster6 = []

for i in range(len(labels)):
    if (labels[i] == 0):
        cluster0.append(i);
    elif (labels[i] == 1):
        cluster1.append(i);
    elif (labels[i] == 2):
        cluster2.append(i);
    elif (labels[i] == 3):
        cluster3.append(i);
    elif (labels[i] == 4):
        cluster4.append(i);
    elif (labels[i] == 5):
        cluster5.append(i);
    elif (labels[i] == 6):
        cluster6.append(i);

# %%
# 標籤為0的群組文章INDEX
print(cluster0)
# Out:
# [240, 554, 732, 812, 829, 850, 923, 1465, 1814, 2176, 2195, 2208, 2282, 2588, 2685, 2702, 2714, 2761, 2870, 2894, 2931, 2990, 3055, 3098, 3164, 3193, 3198, 3201, 3212, 3252, 3259, 3260, 3279, 3303, 3304, 3306, 3334, 3336, 3346, 3350, 3356, 3362, 3372, 3383, 3396, 3400, 3402, 3404, 3412, 3418, 3419, 3420, 3425, 3437, 3440, 3458, 3459, 3461, 3462, 3463, 3469, 3473, 3478, 3480, 3483, 3484, 3486, 3488, 3497, 3504, 3507, 3508, 3514, 3520, 3521, 3527, 3528, 3542, 3543, 3544, 3547, 3551, 3556, 3557, 3561, 3562, 3564, 3566, 3567, 3568, 3570, 3583, 3585, 3587, 3595, 3597, 3600, 3601, 3604, 3605, 3666, 3742, 3767, 3794, 3795, 3829, 3855, 3904, 3923, 3963, 3970, 4030, 4033, 4101, 4171, 4196, 4197, 4198, 4211
, 7167, 7177, 7179, 7181, 7187, 7189, 7192, 7193, 7199, 7203, 7204, 7206, 7207, 7208, 7210, 7212, 7213, 7215, 7216, 7219, 7222, 7224, 7225, 7230, 7234, 7235, 7236, 7237, 7243, 7251, 7255, 7257, 7261, 7267, 7268, 7270, 7272, 7275, 7276, 7278, 7283, 7286, 7288, 7289, 7291, 7293, 7294, 7298, 7303, 7304, 7306, 7309, 7314, 7315, 7322, 7327, 7328, 7332, 7336, 7339, 7340, 7341, 7344, 7348, 7349, 7350, 7351, 7352, 7356, 7358, 7359, 7361, 7364, 7368, 7369, 7370, 7371, 7373, 7375, 7377, 7379, 7382, 7383, 7384, 7388, 7389, 7393, 7394, 7397, 7399, 7400, 7402, 7403, 7413, 7416, 7417, 7419, 7421, 7422, 7426, 7427, 7432, 7433, 7434, 7435, 7439, 7440, 7454, 7459, 7460, 7461, 7462, 7467, 7468, 7469, 7472, 7473, 7474, 7476, 7479, 7480, 7482, 7483, 7487, 7491, 7494, 7496, 7500, 7501, 7506, 7510, 7514, 7515, 7516, 7517, 7521, 7522, 7529, 7530, 7535, 7540, 7544, 7549, 7552, 7553, 7554, 7555, 7556, 7558, 7561, 7567, 7570, 7572, 7576, 7578, 7579, 7583, 7588, 7589, 7590, 7591, 7592, 7596, 7600, 7606 ...

# %%
# 按文章INDEX將文章分群

corpus_clu0 = []
corpus_clu1 = []
corpus_clu2 = []
corpus_clu3 = []
corpus_clu4 = []
corpus_clu5 = []
corpus_clu6 = []

for j in range(len(cluster0)):
    corpus_clu0.append(train_corpus[cluster0[j]]);
for j in range(len(cluster1)):
    corpus_clu1.append(train_corpus[cluster1[j]]);    
for j in range(len(cluster2)):
    corpus_clu2.append(train_corpus[cluster2[j]]);
for j in range(len(cluster3)):
    corpus_clu3.append(train_corpus[cluster3[j]]); 
for j in range(len(cluster4)):
    corpus_clu4.append(train_corpus[cluster4[j]]);     
for j in range(len(cluster5)):
    corpus_clu5.append(train_corpus[cluster5[j]]);
for j in range(len(cluster6)):
    corpus_clu6.append(train_corpus[cluster6[j]]);

# %%
# 看看第0群的第0篇文章內容與標籤
print(corpus_clu0[0])
# Out:
# LabeledSentence(['went', 'from', 'dyson', 'to', 'this', 'black', 'and', 'decker', 'unit', 'looks', 'nice', 'and', 'holds', 'charge', 'well', 'the', 'whole', 'point', 'is', 'to', 'pick', 'stuff', 'up', 'and', 'this', 'unit', 'did', 'not', 'way', 'underpowered'], ['SENT_240'])

# %%
# 看看第0群的第0篇文章標籤
print(corpus_clu0[0].tags)
# Out:
# ['SENT_240']

# %%
# 看看第0群的第0篇文章內容
print(corpus_clu0[0].words)
# Out:
# ['went', 'from', 'dyson', 'to', 'this', 'black', 'and', 'decker', 'unit', 'looks', 'nice', 'and', 'holds', 'charge', 'well', 'the', 'whole', 'point', 'is', 'to', 'pick', 'stuff', 'up', 'and', 'this', 'unit', 'did', 'not', 'way', 'underpowered']

# %%
# 只挑文章內容存進去各個群組
corpus_clu0_wordlist = []
corpus_clu1_wordlist = []
corpus_clu2_wordlist = []
corpus_clu3_wordlist = []
corpus_clu4_wordlist = []
corpus_clu5_wordlist = []
corpus_clu6_wordlist = []

for i in range(len(corpus_clu0)):
    corpus_clu0_wordlist.append(corpus_clu0[i].words)
for i in range(len(corpus_clu1)):
    corpus_clu1_wordlist.append(corpus_clu1[i].words)
for i in range(len(corpus_clu2)):
    corpus_clu2_wordlist.append(corpus_clu2[i].words)
for i in range(len(corpus_clu3)):
    corpus_clu3_wordlist.append(corpus_clu3[i].words)
for i in range(len(corpus_clu4)):
    corpus_clu4_wordlist.append(corpus_clu4[i].words)
for i in range(len(corpus_clu5)):
    corpus_clu5_wordlist.append(corpus_clu5[i].words)
for i in range(len(corpus_clu6)):
    corpus_clu6_wordlist.append(corpus_clu6[i].words)

# %%
# 看看第0個群組的前2篇文章
corpus_clu0_wordlist[:2]
# Out:
# [['went',
#   'from',
#   'dyson',
#   'to',
#   'this',
#   'black',
#   'and',
#   'decker',
#   'unit',
#   'looks',
#   'nice',
#   'and',
#   'holds',
#   'charge',
#   'well',
#   'the',
#   'whole',
#   'point',
#   'is',
#   'to',
#   'pick',
#   'stuff',
#   'up',
#   'and',
#   'this',
#   'unit',
#   'did',
#   'not',
#   'way',
#   'underpowered'],
#  ['worked',
#   'great',
#   'until',
#   'last',
#   'month',
#   'but',
#   'doesn',
#   'charge',
#   'or',
#   'turn',
#   'on',
#   'now']]

# %%
# 把只出現一次的字移除
from collections import defaultdict
from pprint import pprint  # pretty-printer

def remove_less_than_one(corpus_clu_wordlist):
    frequency = defaultdict(int)
    for text in corpus_clu_wordlist:
         for token in text:
            frequency[token] += 1

    corpus_clu_wordlist = [[token for token in text if frequency[token] > 1]
                             for text in corpus_clu_wordlist]
    return corpus_clu_wordlist;

# %%
remove_less_than_one(corpus_clu0_wordlist)
remove_less_than_one(corpus_clu1_wordlist)
remove_less_than_one(corpus_clu2_wordlist)
remove_less_than_one(corpus_clu3_wordlist)
remove_less_than_one(corpus_clu4_wordlist)
remove_less_than_one(corpus_clu5_wordlist)
remove_less_than_one(corpus_clu6_wordlist)
# Out:
# [['this',
#   'dustbuster',
#   'replaced',
#   'an',
#   'older',
#   'one',
#   'that',
#   'used',
#   'nicad',
#   'batteries',
#   'and',
#   'was',
#   'about',
#   'to',
#   'the',
#   'end',
#   'of',
#   'its',
#   'useful',
#   'life',
#   'the',
#   'old',
#   'one',
#   'hung',
#   'on',
#   'the',
#   'wall',
#   'on',
#   'charger',
#   'bracket',
#   'that',
#   'was',
#   'mounted',
#   'on',
#   'our',
#   'laundry',
#   'room',
#   'wall',
#   'that',
#   'was',
#   'very',
#   'handy',
#   'to',
#   'get',
#   'to',
#   'and',
#   'had',
#   'been',
#   'located',
#   'there',
#   'for',
#   'over',
#   'ten',
#   'years',
#   'we',
#   'were',
#   'reluctant',
#   'to',
#   'clear',
#   'off',
#   'shelf',
#   'in',
#   'different',
#   'location',
#   'so',
#   'came',
#   'up',
#   'with',
#   'mount',
#   'that',
#   'attached',
#   'to',
#   'one',
#   'of',
#   'the',
#   'shelves',
#   'that',
#   'put',
#   'it',
#   'back',
#   'in',
#   'the',
#   'old',
#   'location',
#   'it',
#   'may',
#   'even',
#   'be',
#   'better',
#   'now',
#   'since',
#   'it',
#   'simply',
#   'sits',
#   'on',
#   'the',
#   'shelf',
#   'rather',
#   'than',
#   'having',
#   'to',
#   'hang',
#   'it',
#   'on',
#   'the',
#   'bracket',
#   'we',
#   'have',
#   'only',
#   'had',
#   'this',
#   'vacuum',
#   'for',
#   'few',
#   'days',
#   'but',
#   'it',
#   'beats',
#   'the',
#   'old',
#   'one',
#   'hands',
#   'down',
#   'so',
#   'far',
#   'pros',
#   'excellent',
#   'power',
#   'has',
#   'not',
#   'faded',
#   'yet',
#   'easy',
#   'to',
#   'empty',
#   'clean',
#   'all',
#   'accessories',
#   'are',
#   'built',
#   'in',
#   'provides',
#   'night',
#   'light',
#   'in',
#   'the',
#   'laundry',
#   'roomcons',
#   'easy',
#   'to',
#   'press',
#   'the',
#   'release',
#   'button',
#   'instead',
#   'of',
#   'the',
#   'switch',
#   'this',
#   'has',
#   'only',
#   'happened',
#   'once',
#   'edit',
#   'after',
#   'month',
#   'or',
#   'so',
#   'of',
#   'use',
#   'will',
#   'have',
#   'to',
#   'say',
#   'that',
#   'this',
#   'is',
#   'absolutely',
#   'the',
#   'best',
#   'dustbuster',
#   'that',
#   'we',
#   'have',
#   'ever',
#   'owned',
#   'the',
#   'battery',
#   'seems',
#   'to',
#   'last',
#   'forever',
#   'have',
#   'used',
#   'it',
#   'to',
#   'vacuum',
#   'out',
#   'the',
#   'car',
#   'and',
#   'around',
#   'our',
#   'very',
#   'messy',
#   'and',
#   'it',
#   'has',
#   'never',
#   'shown',
#   'any',
#   'of',
#   'losing',
#   'power',
#   'not',
#   'really',
#   'con',
#   'but',
#   'would',
#   'like',
#   'wider',
#   'nozzle',
#   'attachment',
#   'for',
#   'picking',
#   'up',
#   'dust',
#   'cat',
#   'litter',
#   'etc'],
#  ['this',
#   'is',
#   'pretty',
#   'powerful',
#   'for',
#   'such',
#   'an',
#   'inexpensive',
#   'product',
#   'which',
#   'happened',
#   'to',
#   'be',
#   'on',
#   'deal',
#   'the',
#   'day',
#   'decided',
#   'to',
#   'purchase',
#   'it',
#   'after',
#   'having',
#   'it',
#   'sit',
#   'in',
#   'my',
#   'for',
#   'few',
#   'weeks',
#   'the',
#   'filter',
#   'has',
#   'up',
#   'pretty',
#   'quickly',
#   'and',
#   'the',
#   'nozzle',
#   'portion',
#   'is',
#   'some',
#   'pretty',
#   'nasty',
#   'looking',
#   'residue',
#   'even',
#   'after',
#   'cleaning',
#   'it',
#   'the',
#   'bristles',
#   'on',
#   'the',
#   'brush',
#   'have',
#   'also',
#   'quite',
#   'quickly',
#   'but',
#   'the',
#   'brush',
#   'is',
#   'still',
#   'great',
#   'for',
#   'cleaning',
#   'baseboards',
#   'of',
#   'dust',
#   'quickly',
#   'if',
#   'you',
#   'choose',
#   'to',
#   'rinse',
#   'out',
#   'the',
#   'components',
#   'but',
#   'sure',
#   'it',
#   'is',
#   'dry',
#   'before',
#   'using',
#   'again',
#   'or',
#   'else',
#   'you',
#   'll',
#   'have',
#   'gunk',
#   'canister',
#   'as',
#   'for',
#   'the',
#   'charge',
#   'it',
#   'holds',
#   'for',
#   'quite',
#   'while',
#   'and',
#   'doesn',
#   'take',
#   'long',
#   'to',
#   'charge',
#   'we',
#   'took',
#   'it',
#   'on',
#   'road',
#   'trip',
#   'to',
#   'keep',
#   'our',
#   'new',
#   'car',
#   'clean',
#   'along',
#   'the',
#   'way',
#   'with',
#   'dog',
#   'and',
#   'it',
#   'held',
#   'up',
#   'pretty',
#   'well',
#   'never',
#   'ran',
#   'out',
#   'of',
#   'charge',
#   'the',
#   'charging',
#   'light',
#   'is',
#   'extremely',
#   'bright',
#   'though',
#   'enough',
#   'to',
#   'as',
#   'night',
#   'light'],
#  ['can',
#   'my',
#   'love',
#   'for',
#   'vacuum',
#   'this',
#   'vacuum',
#   'is',
#   'top',
#   'use',
#   'it',
#   'daily',
#   'and',
#   'by',
#   'using',
#   'it',
#   'daily',
#   'mean',
#   'carry',
#   'it',
#   'around',
#   'when',
#   'and',
#   'suck',
#   'dust',
#   'off',
#   'of',
#   'random',
#   'crap',
#   'was',
#   'child',
#   'we',
#   'didn',
#   'have',
#   'portable',
#   'vacuums',
#   'we',
#   'had',
#   'big',
#   'clunky',
#   'hoover',
#   'vacuums',
#   'it',
#   'also',
#   'scares',
#   'the',
#   'out',
#   'of',
#   'my',
#   'dog',
#   'so',
#   'there',
#   'that',
#   'it',
#   'like',
#   'your',
#   'worst',
#   'fear',
#   'but',
#   'leave',
#   'all',
#   'the',
#   'like',
#   'with',
#   'the',
#   'of',
#   'think',
#   'that',
#   'how',
#   'my',
#   'dog',
#   'feels',
#   've',
#   'attached',
#   'photo',
#   'of',
#   'my',
#   'dog',
#   'so',
#   'you',
#   'know',
#   'which',
#   'one',
#   'to',
#   'for',
#   'in',
#   'my'],
#  ['bought',
#   'this',
#   'item',
#   'when',
#   'there',
#   'was',
#   'off',
#   'discount',
#   'on',
#   'black',
#   'decker',
#   'purchase',
#   'am',
#   'so',
#   'glad',
#   'did',
#   'because',
#   'this',
#   'product',
#   'is',
#   'better',
#   'than',
#   'my',
#   'old',
#   'dustbuster',
#   'that',
#   'worked',
#   'for',
#   'over',
#   'years',
#   'this',
#   'new',
#   'black',
#   'and',
#   'decker',
#   'handheld',
#   'vacuum',
#   'is',
#   'truly',
#   'amazing',
#   'it',
#   'has',
#   'even',
#   'taken',
#   'the',
#   'place',
#   'of',
#   'my',
#   'dustpan',
#   'sweep',
#   'into',
#   'small',
#   'pile',
#   'and',
#   'use',
#   'this',
#   'product',
#   'to',
#   'suck',
#   'up',
#   'every',
#   'of',
#   'dust',
#   'like',
#   'that',
#   'it',
#   'is',
#   'powerful',
#   'and',
#   'that',
#   'the',
#   'small',
#   'brush',
#   'attachment',
#   'that',
#   'flips',
#   'into',
#   'place',
#   'at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'unit',
#   'this',
#   'way',
#   'll',
#   'never',
#   'lose',
#   'the',
#   'attachment',
#   'also',
#   'like',
#   'that',
#   'it',
#   'charges',
#   'standing',
#   'up',
#   'on',
#   'its',
#   'end',
#   'so',
#   'it',
#   'takes',
#   'up',
#   'less',
#   'space',
#   'than',
#   'my',
#   'previous',
#   'model',
#   'all',
#   'in',
#   'all',
#   'couldn',
#   'be',
#   'happier'],
#  ['purchased',
#   'chv',
#   'volt',
#   'lithium',
#   'ion',
#   'cordless',
#   'dust',
#   'buster',
#   'as',
#   'christmas',
#   'gift',
#   'for',
#   'my',
#   'mother',
#   'when',
#   'she',
#   'opened',
#   'it',
#   'it',
#   'appeared',
#   'to',
#   'work',
#   'but',
#   'on',
#   'the',
#   'same',
#   'evening',
#   'that',
#   'we',
#   'opened',
#   'it',
#   'seemed',
#   'to',
#   'be',
#   'having',
#   'trouble',
#   'taking',
#   'full',
#   'charge',
#   'she',
#   'around',
#   'with',
#   'it',
#   'for',
#   'all',
#   'of',
#   'and',
#   'it',
#   'seemed',
#   'to',
#   'work',
#   'little',
#   'finally',
#   'in',
#   'early',
#   'february',
#   'she',
#   'told',
#   'me',
#   'that',
#   'it',
#   'just',
#   'wasn',
#   'working',
#   'at',
#   'all',
#   'brought',
#   'it',
#   'home',
#   'and',
#   'the',
#   'led',
#   'blinks',
#   'rapidly',
#   'when',
#   'placed',
#   'on',
#   'the',
#   'charging',
#   'cradle',
#   'from',
#   'the',
#   'manual',
#   'this',
#   'means',
#   'that',
#   'the',
#   'battery',
#   'is',
#   'defective',
#   'it',
#   'is',
#   'past',
#   'the',
#   'day',
#   'return',
#   'for',
#   'the',
#   'and',
#   'am',
#   'left',
#   'holding',
#   'the',
#   'bag',
#   'can',
#   'send',
#   'it',
#   'back',
#   'to',
#   'with',
#   'shipping',
#   'this',
#   'is',
#   'just',
#   'disappointing',
#   'big',
#   'hassle',
#   'also',
#   'bought',
#   'second',
#   'one',
#   'as',
#   'christmas',
#   'gift',
#   'for',
#   'someone',
#   'else',
#   'and',
#   'that',
#   'one',
#   'appears',
#   'to',
#   'be',
#   'working',
#   'ok',
#   'so',
#   'learn',
#   'from',
#   'my',
#   'mistake',
#   'if',
#   'you',
#   'do',
#   'buy',
#   'one',
#   'of',
#   'these',
#   'and',
#   'notice',
#   'any',
#   'charging',
#   'issues',
#   'send',
#   'it',
#   'back',
#   'immediately',
#   'it',
#   'not',
#   'going',
#   'to',
#   'get',
#   'well',
#   'on',
#   'it',
#   'own'],
#  ['never',
#   'write',
#   'reviews',
#   'but',
#   'thought',
#   'that',
#   'it',
#   'might',
#   'be',
#   'good',
#   'idea',
#   'to',
#   'start',
#   'since',
#   'have',
#   'been',
#   'using',
#   'so',
#   'many',
#   'reviews',
#   'to',
#   'help',
#   'make',
#   'my',
#   'household',
#   'purchases',
#   'looked',
#   'at',
#   'several',
#   'different',
#   'dust',
#   'busters',
#   'and',
#   'read',
#   'tons',
#   'of',
#   'reviews',
#   'before',
#   'purchasing',
#   'this',
#   'one',
#   've',
#   'had',
#   'it',
#   'about',
#   'month',
#   'now',
#   'and',
#   'absolutely',
#   'love',
#   'it',
#   'it',
#   'holds',
#   'charge',
#   'for',
#   'very',
#   'long',
#   'time',
#   'is',
#   'powerful',
#   'enough',
#   'to',
#   'suction',
#   'up',
#   'all',
#   'the',
#   'messes',
#   'my',
#   'kids',
#   'make',
#   'and',
#   'like',
#   'that',
#   'can',
#   'just',
#   'empty',
#   'it',
#   'and',
#   'not',
#   'worry',
#   'about',
#   'buying',
#   'replacement',
#   'anything',
#   'have',
#   'toddlers',
#   'and',
#   'they',
#   'are',
#   'quite',
#   'possibly',
#   'the',
#   'kids',
#   'on',
#   'the',
#   'use',
#   'my',
#   'dust',
#   'buster',
#   'million',
#   'times',
#   'day',
#   'for',
#   'little',
#   'messes',
#   'and',
#   'about',
#   'times',
#   'day',
#   'for',
#   'good',
#   'once',
#   'over',
#   'of',
#   'the',
#   'high',
#   'traffic',
#   'areas',
#   'of',
#   'the',
#   'house',
#   'it',
#   'picks',
#   'up',
#   'whole',
#   'pieces',
#   'of',
#   'cereal',
#   'with',
#   'no',
#   'problem',
#   'and',
#   'don',
#   'even',
#   'get',
#   'stuck',
#   'in',
#   'the',
#   'nozzle',
#   'area',
#   'it',
#   'even',
#   'to',
#   'suck',
#   'up',
#   'dum',
#   'dum',
#   'the',
#   'other',
#   'day',
#   'we',
#   'visit',
#   'my',
#   'parents',
#   'each',
#   'sunday',
#   'and',
#   'the',
#   'kids',
#   'were',
#   'always',
#   'making',
#   'messes',
#   'with',
#   'snacks',
#   'all',
#   'over',
#   'their',
#   'house',
#   'so',
#   'now',
#   'we',
#   'just',
#   'grab',
#   'the',
#   'dust',
#   'buster',
#   'on',
#   'our',
#   'way',
#   'out',
#   'the',
#   'door',
#   'and',
#   'take',
#   'it',
#   'with',
#   'us',
#   'it',
#   'keeps',
#   'its',
#   'charge',
#   'while',
#   'we',
#   're',
#   'there',
#   'all',
#   'day',
#   'and',
#   'makes',
#   'cleaning',
#   'up',
#   'after',
#   'them',
#   'so',
#   'much',
#   'easier',
#   'some',
#   'reviews',
#   'read',
#   'complained',
#   'about',
#   'the',
#   'noise',
#   'level',
#   'but',
#   'it',
#   'doesn',
#   'bother',
#   'me',
#   'guess',
#   'if',
#   'you',
#   'were',
#   'gonna',
#   'vacuum',
#   'the',
#   'crumbs',
#   'out',
#   'of',
#   'your',
#   'bed',
#   'while',
#   'your',
#   'husband',
#   'wife',
#   'it',
#   'wouldn',
#   'be',
#   'ideal',
#   'but',
#   'seriously',
#   'don',
#   'have',
#   'problem',
#   'with',
#   'the',
#   'noise',
#   'it',
#   'vacuum',
#   'one',
#   'wouldn',
#   'expect',
#   'it',
#   'to',
#   'be',
#   'quiet',
#   'another',
#   'complaint',
#   'was',
#   'about',
#   'the',
#   'charging',
#   'light',
#   'on',
#   'it',
#   'being',
#   'so',
#   'bright',
#   'it',
#   'is',
#   'very',
#   'bright',
#   'but',
#   'my',
#   'base',
#   'is',
#   'plugged',
#   'in',
#   'just',
#   'inside',
#   'my',
#   'kitchen',
#   'pantry',
#   'so',
#   'it',
#   'not',
#   'an',
#   'issue',
#   'for',
#   'me',
#   'wouldn',
#   'recommend',
#   'putting',
#   'it',
#   'in',
#   'bedroom',
#   'or',
#   'anything',
#   'as',
#   'it',
#   'is',
#   'rather',
#   'bright',
#   'and',
#   'while',
#   'recharging',
#   'to',
#   'me',
#   'neither',
#   'the',
#   'noise',
#   'or',
#   'charge',
#   'light',
#   'present',
#   'even',
#   'the',
#   'problem',
#   'very',
#   'glad',
#   'decided',
#   'to',
#   'go',
#   'with',
#   'this',
#   'dust',
#   'buster',
#   'it',
#   'has',
#   'definitely',
#   'made',
#   'keeping',
#   'my',
#   'house',
#   'clean',
#   'with',
#   'messy',
#   'toddlers',
#   'much',
#   'much',
#   'easier'],
#  ['it',
#   'true',
#   'really',
#   'wanted',
#   'this',
#   'vacuum',
#   'to',
#   'my',
#   'mind',
#   'but',
#   'it',
#   'was',
#   'of',
#   'me',
#   'to',
#   'set',
#   'my',
#   'expectations',
#   'that',
#   'high',
#   'had',
#   'read',
#   'so',
#   'many',
#   'positive',
#   'reviews',
#   'on',
#   'amazon',
#   'and',
#   'the',
#   'purchase',
#   'based',
#   'off',
#   'of',
#   'just',
#   'that',
#   'let',
#   'me',
#   'break',
#   'it',
#   'down',
#   'pros',
#   'lightweight',
#   'and',
#   'compact',
#   'battery',
#   'holds',
#   'really',
#   'long',
#   'charge',
#   'narrow',
#   'nose',
#   'is',
#   'super',
#   'useful',
#   'for',
#   'the',
#   'hard',
#   'to',
#   'reach',
#   'spots',
#   'nice',
#   'overall',
#   'design',
#   'right',
#   'down',
#   'to',
#   'the',
#   'colors',
#   'cons',
#   'it',
#   'is',
#   'loud',
#   'as',
#   'hell',
#   'mean',
#   'seriously',
#   'it',
#   'louder',
#   'than',
#   'my',
#   'floor',
#   'vacuum',
#   'that',
#   'kinda',
#   'crazy',
#   'suction',
#   'power',
#   'is',
#   'bit',
#   'mediocre',
#   'was',
#   'expecting',
#   'more',
#   'the',
#   'brush',
#   'tip',
#   'extension',
#   'is',
#   'absolutely',
#   'useless',
#   'honestly',
#   'it',
#   'makes',
#   'things',
#   'even',
#   'more',
#   'difficult',
#   'to',
#   'vacuum',
#   'it',
#   'does',
#   'nothing',
#   'so',
#   'bottom',
#   'line',
#   'is',
#   'if',
#   'you',
#   're',
#   'on',
#   'budget',
#   'and',
#   'aren',
#   'about',
#   'cleaning',
#   'then',
#   'this',
#   'is',
#   'the',
#   'vacuum',
#   'for',
#   'you',
#   'otherwise',
#   'pay',
#   'bit',
#   'more',
#   'and',
#   'get',
#   'something',
#   'little',
#   'more',
#   'advanced'],
#  ['it',
#   'is',
#   'hard',
#   'to',
#   'write',
#   'review',
#   'for',
#   'this',
#   'because',
#   'received',
#   'one',
#   'that',
#   'was',
#   'really',
#   'good',
#   'and',
#   'going',
#   'strong',
#   'for',
#   'about',
#   'months',
#   'now',
#   'and',
#   'another',
#   'that',
#   'bought',
#   'for',
#   'my',
#   'dad',
#   'that',
#   'died',
#   'after',
#   'one',
#   'use',
#   'the',
#   'one',
#   'bought',
#   'myself',
#   'was',
#   'the',
#   'previous',
#   'model',
#   'the',
#   'one',
#   'with',
#   'and',
#   'was',
#   'green',
#   'instead',
#   'of',
#   'blue',
#   'suction',
#   'is',
#   'great',
#   'lasts',
#   'forever',
#   'on',
#   'one',
#   'charge',
#   'and',
#   'have',
#   'yet',
#   'to',
#   'experience',
#   'it',
#   'lose',
#   'power',
#   'use',
#   'it',
#   'in',
#   'my',
#   'small',
#   'hardwood',
#   'apartment',
#   'to',
#   'pick',
#   'up',
#   'little',
#   'bits',
#   'of',
#   'things',
#   'here',
#   'and',
#   'there',
#   'and',
#   'has',
#   'done',
#   'its',
#   'job',
#   'perfectly',
#   'based',
#   'on',
#   'that',
#   'experience',
#   'bought',
#   'one',
#   'for',
#   'my',
#   'dad',
#   'this',
#   'time',
#   'it',
#   'is',
#   'this',
#   'newer',
#   'model',
#   'and',
#   'blue',
#   'when',
#   'we',
#   'first',
#   'turned',
#   'it',
#   'on',
#   'it',
#   'was',
#   'just',
#   'like',
#   'mine',
#   'massive',
#   'power',
#   'but',
#   'after',
#   'using',
#   'it',
#   'for',
#   'few',
#   'minutes',
#   'and',
#   'then',
#   'turning',
#   'it',
#   'off',
#   'we',
#   'couldn',
#   'turn',
#   'it',
#   'on',
#   'second',
#   'time',
#   'plugging',
#   'it',
#   'in',
#   'gave',
#   'us',
#   'the',
#   'solid',
#   'light',
#   'which',
#   'means',
#   'fully',
#   'charged',
#   'there',
#   'isn',
#   'much',
#   'we',
#   'could',
#   'do',
#   'to',
#   'trouble',
#   'it',
#   'because',
#   'it',
#   'is',
#   'body',
#   'removing',
#   'the',
#   'front',
#   'does',
#   'nothing',
#   'in',
#   'terms',
#   'of',
#   'electrical',
#   'function',
#   'so',
#   'returned',
#   'it',
#   'so',
#   'yeah',
#   'torn',
#   'about',
#   'how',
#   'to',
#   'rate',
#   'this',
#   'product',
#   'when',
#   'it',
#   'works',
#   'it',
#   'works',
#   'fantastically',
#   'but',
#   'when',
#   'it',
#   'fails',
#   'man',
#   'does',
#   'it',
#   'fail'],
#  ['vacuum',
#   'worked',
#   'as',
#   'expected',
#   'for',
#   'almost',
#   'year',
#   'then',
#   'quit',
#   'this',
#   'was',
#   'not',
#   'cheap',
#   'bought',
#   'it',
#   'because',
#   'of',
#   'my',
#   'to',
#   'ni',
#   'cad',
#   'batteries',
#   'and',
#   'was',
#   'willing',
#   'to',
#   'pay',
#   'more',
#   'for',
#   'battery',
#   'that',
#   'would',
#   'better',
#   'do',
#   'not',
#   'think',
#   'the',
#   'battery',
#   'is',
#   'bad',
#   'it',
#   'sounds',
#   'more',
#   'like',
#   'the',
#   'motor',
#   'we',
#   'use',
#   'it',
#   'few',
#   'minutes',
#   'every',
#   'day',
#   'to',
#   'clean',
#   'up',
#   'after',
#   'litter',
#   'boxes',
#   'then',
#   'return',
#   'it',
#   'to',
#   'the',
#   'charger',
#   'it',
#   'was',
#   'never',
#   'or',
#   'run',
#   'flat',
#   'have',
#   'cheap',
#   'red',
#   'one',
#   'ni',
#   'cad',
#   'from',
#   'target',
#   'that',
#   'bought',
#   'as',
#   'since',
#   'this',
#   'one',
#   'took',
#   'weeks',
#   'to',
#   'get',
#   'still',
#   'use',
#   'it',
#   'when',
#   'scoop',
#   'the',
#   'upstairs',
#   'litter',
#   'box',
#   'the',
#   'cheap',
#   'red',
#   'one',
#   'still',
#   'works',
#   'this',
#   'expensive',
#   'li',
#   'ion',
#   'one',
#   'does',
#   'not',
#   'looking',
#   'into',
#   'warranty',
#   'have',
#   'to',
#   'find',
#   'and',
#   'if',
#   'they',
#   'fix',
#   'it',
#   'will',
#   'revise',
#   'this',
#   'review',
#   'in',
#   'the',
#   'll',
#   'kick',
#   'myself',
#   'for',
#   'thinking',
#   'that',
#   'paying',
#   'lot',
#   'more',
#   'for',
#   'new',
#   'technology',
#   'was',
#   'in',
#   'any',
#   'way',
#   'wise',
#   'update',
#   'my',
#   'wife',
#   'called',
#   'black',
#   'and',
#   'decker',
#   'for',
#   'about',
#   'warranty',
#   'repair',
#   'and',
#   'the',
#   'there',
#   'told',
#   'her',
#   'to',
#   'forget',
#   'sending',
#   'it',
#   'in',
#   'for',
#   'repair',
#   'she',
#   'would',
#   'send',
#   'new',
#   'one',
#   'she',
#   'did',
#   'it',
#   'works',
#   'so',
#   'black',
#   'and',
#   'decker',
#   'gets',
#   'stars',
#   'for',
#   'customer',
#   'service',
#   'up',
#   'rated',
#   'the',
#   'vacuum',
#   'to',
#   'three',
#   'stars',
#   'from',
#   'one',
#   'because',
#   'the',
#   'manufacturer',
#   'behind',
#   'it',
#   'but',
#   'can',
#   'honestly',
#   'give',
#   'the',
#   'vacuum',
#   'itself',
#   'stars',
#   'because',
#   'it',
#   'did',
#   'quit',
#   'after',
#   'less',
#   'than',
#   'year',
#   'since',
#   'it',
#   'was',
#   'already',
#   'broken',
#   'had',
#   'nothing',
#   'to',
#   'loose',
#   'by',
#   'taking',
#   'it',
#   'apart',
#   'think',
#   'the',
#   'battery',
#   'and',
#   'motor',
#   'are',
#   'good',
#   'problem',
#   'seems',
#   'to',
#   'be',
#   'in',
#   'the',
#   'switch',
#   'with',
#   'it',
#   'was',
#   'able',
#   'to',
#   'make',
#   'it',
#   'run',
#   'it',
#   'is',
#   'not',
#   'fixed',
#   'but',
#   'sometimes',
#   'if',
#   'wiggle',
#   'the',
#   'switch',
#   'just',
#   'right',
#   'it',
#   'runs',
#   'in',
#   'the',
#   'old',
#   'days',
#   'things',
#   'like',
#   'this',
#   'had',
#   'manuals',
#   'with',
#   'and',
#   'parts',
#   'and',
#   'one',
#   'could',
#   'order',
#   'replacement',
#   'parts',
#   'but',
#   'nobody',
#   'anything',
#   'these',
#   'days',
#   'it',
#   'is',
#   'cheaper',
#   'to',
#   'it',
#   'out',
#   'for',
#   'new',
#   'one',
#   'sorry',
#   'just',
#   'being',
#   'old',
#   'and',
#   'the',
#   'good',
#   'old',
#   'days',
#   'probably',
#   'weren',
#   'really'],
#  ['was',
#   'so',
#   'disappointed',
#   'with',
#   'the',
#   'suction',
#   'that',
#   'had',
#   'to',
#   'return',
#   'it',
#   'it',
#   'slick',
#   'beautiful',
#   'and',
#   'has',
#   'the',
#   'world',
#   'charger',
#   'considering',
#   'that',
#   'everyone',
#   'else',
#   'seems',
#   'to',
#   'love',
#   'it',
#   'maybe',
#   'my',
#   'expectations',
#   'were',
#   'tried',
#   'so',
#   'hard',
#   'to',
#   'love',
#   'it',
#   'even',
#   'said',
#   'well',
#   'it',
#   'not',
#   'any',
#   'good',
#   'for',
#   'the',
#   'office',
#   'but',
#   'if',
#   'it',
#   'will',
#   'just',
#   'clean',
#   'the',
#   'car',
#   'it',
#   'will',
#   'be',
#   'worth',
#   'keeping',
#   'it',
#   'sucked',
#   'up',
#   'hair',
#   'nicely',
#   'but',
#   'left',
#   'in',
#   'it',
#   'wake',
#   'loose',
#   'pebbles',
#   'large',
#   'pieces',
#   'of',
#   'sand',
#   'sprinkles',
#   'and',
#   'things',
#   'so',
#   'tiny',
#   'not',
#   'sure',
#   'what',
#   'they',
#   'were',
#   'it',
#   'also',
#   'uncomfortably',
#   'loud'],
#  ['don',
#   'know',
#   'if',
#   'everyone',
#   'else',
#   'had',
#   'low',
#   'expectations',
#   'or',
#   'what',
#   'the',
#   'battery',
#   'life',
#   'is',
#   'nothing',
#   'to',
#   'write',
#   'home',
#   'about',
#   'this',
#   'was',
#   'as',
#   'top',
#   'for',
#   'back',
#   'to',
#   'school',
#   'maybe',
#   'college',
#   'kids',
#   'are',
#   'buying',
#   'or',
#   'receiving',
#   'these',
#   'and',
#   'for',
#   'all',
#   'they',
#   'know',
#   'it',
#   'is',
#   'good',
#   'vac',
#   'college',
#   'kids',
#   'aren',
#   'cleaning',
#   'let',
#   'be',
#   'real',
#   'charged',
#   'it',
#   'the',
#   'first',
#   'time',
#   'overnight',
#   'and',
#   'was',
#   'lucky',
#   'to',
#   'get',
#   'mins',
#   'of',
#   'use',
#   'time',
#   'out',
#   'of',
#   'that',
#   'charge',
#   'it',
#   'was',
#   'terrible',
#   'not',
#   'to',
#   'mention',
#   'if',
#   'you',
#   'leave',
#   'it',
#   'off',
#   'the',
#   'charger',
#   'for',
#   'day',
#   'again',
#   'you',
#   'will',
#   'maybe',
#   'get',
#   'minutes',
#   'if',
#   'you',
#   're',
#   'lucky',
#   'find',
#   'this',
#   'ridiculous',
#   'and',
#   'totally',
#   'for',
#   'what',
#   'the',
#   'ion',
#   'battery',
#   'doing',
#   'this',
#   'thing',
#   'was',
#   'such',
#   'pain',
#   'corded',
#   'vac',
#   'would',
#   'have',
#   'been',
#   'better',
#   'as',
#   'stated',
#   'in',
#   'my',
#   'video',
#   'wanted',
#   'one',
#   'could',
#   'clean',
#   'the',
#   'filter',
#   'myself',
#   'this',
#   'was',
#   'hassle',
#   'to',
#   'get',
#   'the',
#   'filter',
#   'in',
#   'and',
#   'out',
#   'the',
#   'cleaning',
#   'aspect',
#   'was',
#   'pain',
#   'because',
#   'there',
#   'is',
#   'two',
#   'pieces',
#   'and',
#   'you',
#   'have',
#   'to',
#   'get',
#   'them',
#   'back',
#   'in',
#   'just',
#   'right',
#   'lastly',
#   'the',
#   'design',
#   'of',
#   'the',
#   'vac',
#   'was',
#   'not',
#   'thought',
#   'out',
#   'very',
#   'well',
#   'there',
#   'is',
#   'smaller',
#   'hole',
#   'in',
#   'the',
#   'top',
#   'which',
#   'is',
#   'stupid',
#   'because',
#   'inevitably',
#   'there',
#   'will',
#   'be',
#   'something',
#   'you',
#   'vacuumed',
#   'up',
#   'and',
#   'you',
#   'need',
#   'to',
#   'wipe',
#   'off',
#   'the',
#   'inside',
#   'so',
#   'its',
#   'not',
#   'all',
#   'around',
#   'if',
#   'this',
#   'happens',
#   'you',
#   'better',
#   'have',
#   'baby',
#   'hands',
#   'or',
#   'baby',
#   'bottle',
#   'brush',
#   'to',
#   'get',
#   'in',
#   'there',
#   'the',
#   'suction',
#   'power',
#   'is',
#   'it',
#   'was',
#   'to',
#   'get',
#   'up',
#   'cat',
#   'food',
#   'crumbs',
#   'and',
#   'litter',
#   'had',
#   'to',
#   'it',
#   'and',
#   'scoop',
#   'it',
#   'in',
#   'to',
#   'get',
#   'it',
#   'to',
#   'suck',
#   'it',
#   'up',
#   'what',
#   'waste',
#   'of',
#   'time',
#   'and',
#   'money',
#   'can',
#   'stand',
#   'this',
#   'thing',
#   'will',
#   'say',
#   'too',
#   'its',
#   'loud',
#   'decided',
#   'to',
#   'step',
#   'up',
#   'and',
#   'get',
#   'the',
#   'black',
#   'decker',
#   'bdh',
#   'pl',
#   'max',
#   'lithium',
#   'pivot',
#   'vacuum',
#   'volt',
#   'do',
#   'yourself',
#   'favor',
#   'and',
#   'spend',
#   'the',
#   'extra',
#   'money',
#   'you',
#   'will',
#   'be',
#   'happy',
#   'you',
#   'did',
#   'gave',
#   'it',
#   'two',
#   'stars',
#   'because',
#   'have',
#   'worse',
#   'if',
#   'that',
#   'makes',
#   'this',
#   'thing',
#   'any',
#   'more'],
#  ['purchased',
#   'this',
#   'same',
#   'thing',
#   'last',
#   'year',
#   'for',
#   'around',
#   'this',
#   'time',
#   'have',
#   'only',
#   'used',
#   'it',
#   'of',
#   'times',
#   'and',
#   'it',
#   'will',
#   'not',
#   'hold',
#   'charge',
#   'called',
#   'amazon',
#   'about',
#   'it',
#   'because',
#   'it',
#   'was',
#   'not',
#   'even',
#   'year',
#   'old',
#   'they',
#   'will',
#   'not',
#   'do',
#   'anything',
#   'about',
#   'it',
#   'since',
#   'it',
#   'has',
#   'been',
#   'over',
#   'days'],
#  ['must',
#   'say',
#   'on',
#   'my',
#   'second',
#   'dust',
#   'buster',
#   'of',
#   'black',
#   'and',
#   'decker',
#   'and',
#   'what',
#   'can',
#   'say',
#   'is',
#   'that',
#   'live',
#   'within',
#   'miles',
#   'of',
#   'the',
#   'so',
#   'it',
#   'was',
#   'easy',
#   'to',
#   'take',
#   'the',
#   'original',
#   'back',
#   'and',
#   'get',
#   'replacement',
#   'sent',
#   'through',
#   'the',
#   'mail',
#   'here',
#   'what',
#   'find',
#   'acceptable',
#   'about',
#   'these',
#   'units',
#   'at',
#   'least',
#   'my',
#   'particular',
#   'unit',
#   'leave',
#   'mine',
#   'constantly',
#   'on',
#   'the',
#   'charger',
#   'so',
#   'it',
#   'will',
#   'have',
#   'fresh',
#   'charge',
#   'every',
#   'time',
#   'ready',
#   'to',
#   'use',
#   'it',
#   'don',
#   'even',
#   'use',
#   'it',
#   'that',
#   'much',
#   'just',
#   'to',
#   'supplement',
#   'the',
#   'cleaning',
#   'of',
#   'my',
#   'vehicle',
#   'out',
#   'of',
#   'the',
#   'box',
#   'it',
#   'seems',
#   'to',
#   'work',
#   'fine',
#   'enough',
#   'and',
#   'hold',
#   'charge',
#   'long',
#   'enough',
#   'but',
#   'the',
#   'problem',
#   'for',
#   'me',
#   'has',
#   'been',
#   'how',
#   'rapidly',
#   'the',
#   'battery',
#   'had',
#   'such',
#   'that',
#   'on',
#   'my',
#   'replacement',
#   'unit',
#   'just',
#   'months',
#   'into',
#   'brand',
#   'new',
#   'unit',
#   'same',
#   'thing',
#   'battery',
#   'won',
#   'hold',
#   'charge',
#   'and',
#   'it',
#   'only',
#   'last',
#   'for',
#   'about',
#   'seconds',
#   'now',
#   'going',
#   'to',
#   'try',
#   'and',
#   'take',
#   'it',
#   'back',
#   'one',
#   'more',
#   'time',
#   'and',
#   'was',
#   'if',
#   'read',
#   'on',
#   'this',
#   'review',
#   'board',
#   'if',
#   'this',
#   'is',
#   'common',
#   'problem',
#   'or',
#   'just',
#   'my',
#   'back',
#   'luck',
#   'can',
#   'imagine',
#   'that',
#   'it',
#   'this',
#   'wouldn',
#   'have',
#   'any',
#   'or',
#   'stars',
#   'if',
#   'that',
#   'the',
#   'case',
#   'it',
#   'must',
#   'be',
#   'dud',
#   'units',
#   'battery',
#   've',
#   'gotten',
#   'honestly',
#   'they',
#   'have',
#   'lost',
#   'power',
#   'so',
#   'fast',
#   'that',
#   'there',
#   'not',
#   'way',
#   'could',
#   'put',
#   'their',
#   'name',
#   'on',
#   'such',
#   'performance',
#   'else',
#   'have',
#   'this',
#   'problem'],
#  ['can',
#   'live',
#   'with',
#   'the',
#   'wonky',
#   'stand',
#   'maybe',
#   'but',
#   'my',
#   'main',
#   'issue',
#   'is',
#   'that',
#   'this',
#   'dustbuster',
#   'is',
#   'very',
#   'weak',
#   'doesn',
#   'really',
#   'suck',
#   'up',
#   'anything',
#   'unless',
#   'you',
#   'go',
#   'over',
#   'the',
#   'area',
#   'multiple',
#   'times',
#   'and',
#   'the',
#   'brush',
#   'keeps',
#   'on',
#   'back',
#   'and',
#   'you',
#   'really',
#   'need',
#   'to',
#   'hold',
#   'the',
#   'brush',
#   'in',
#   'place',
#   'with',
#   'one',
#   'hand',
#   'while',
#   'you',
#   'use',
#   'it',
#   'same',
#   'with',
#   'the',
#   'extension',
#   'which',
#   'just',
#   'gets',
#   'pushed',
#   'back',
#   'in',
#   'when',
#   'you',
#   'touch',
#   'something',
#   'with',
#   'it',
#   'unless',
#   'you',
#   'hold',
#   'it',
#   'meh',
#   'had',
#   'high',
#   'hopes',
#   'for',
#   'this',
#   'vacuum',
#   'but',
#   'it',
#   'is',
#   'rather',
#   'useless',
#   'in',
#   'my',
#   'car',
#   'for',
#   'which',
#   'bought',
#   'it'],
#  ['this',
#   'thing',
#   'is',
#   'amazing',
#   'the',
#   'suction',
#   'is',
#   'strong',
#   'it',
#   'little',
#   'on',
#   'the',
#   'heavy',
#   'side',
#   'but',
#   'works',
#   'so',
#   'well',
#   'it',
#   'doesn',
#   'matter',
#   'my',
#   'only',
#   'complaint',
#   'is',
#   'the',
#   'way',
#   'it',
#   'empties',
#   'you',
#   'can',
#   'either',
#   'remove',
#   'the',
#   'white',
#   'bit',
#   'and',
#   'try',
#   'to',
#   'get',
#   'everything',
#   'out',
#   'through',
#   'small',
#   'hole',
#   'or',
#   'take',
#   'off',
#   'the',
#   'handle',
#   'remove',
#   'the',
#   'filter',
#   'and',
#   'dump',
#   'it',
#   'that',
#   'way',
#   'either',
#   'way',
#   'you',
#   'end',
#   'up',
#   'having',
#   'to',
#   'get',
#   'your',
#   'hands',
#   'dirty',
#   'but',
#   'that',
#   'such',
#   'minor',
#   'thing'],
#  ['died',
#   'on',
#   'me',
#   'in',
#   'only',
#   'months',
#   'just',
#   'would',
#   'not',
#   'turn',
#   'on',
#   'at',
#   'all',
#   'contacted',
#   'black',
#   'decker',
#   'and',
#   'they',
#   'sent',
#   'me',
#   'another',
#   'one',
#   'now',
#   'this',
#   'replacement',
#   'just',
#   'died',
#   'on',
#   'me',
#   'as',
#   'well',
#   'in',
#   'just',
#   'months',
#   'same',
#   'problem',
#   'don',
#   'buy',
#   'this',
#   'expensive',
#   'piece',
#   'of',
#   'junk',
#   'that',
#   'will',
#   'just',
#   'die',
#   'on',
#   'you',
#   'now',
#   'they',
#   'expect',
#   'me',
#   'to',
#   'drive',
#   'and',
#   'take',
#   'it',
#   'to',
#   'get',
#   'ridiculous'],
#  ['one',
#   'of',
#   'the',
#   'most',
#   'difficult',
#   'items',
#   'to',
#   'make',
#   'decision',
#   'on',
#   'purchasing',
#   'across',
#   'the',
#   'board',
#   'looked',
#   'at',
#   'reviews',
#   'on',
#   'many',
#   'different',
#   'models',
#   'and',
#   'they',
#   'were',
#   'all',
#   'over',
#   'the',
#   'place',
#   'good',
#   'to',
#   'bad',
#   'for',
#   'every',
#   'one',
#   'of',
#   'them',
#   'so',
#   'far',
#   'am',
#   'pleased',
#   'with',
#   'the',
#   'performance',
#   'of',
#   'this',
#   'model',
#   'but',
#   'not',
#   'big',
#   'fan',
#   'of',
#   'the',
#   'noise',
#   'level',
#   'have',
#   'only',
#   'used',
#   'couple',
#   'hand',
#   'vacs',
#   'over',
#   'the',
#   'years',
#   'and',
#   'this',
#   'one',
#   'is',
#   'quieter',
#   'than',
#   'those',
#   'were',
#   'maybe',
#   'they',
#   'are',
#   'all',
#   'this',
#   'loud',
#   'because',
#   'there',
#   'is',
#   'really',
#   'no',
#   'way',
#   'to',
#   'the',
#   'noise',
#   'like',
#   'in',
#   'full',
#   'size',
#   'vac',
#   'like',
#   'the',
#   'base',
#   'charger',
#   'it',
#   'sits',
#   'in',
#   'instead',
#   'of',
#   'hanging',
#   'on',
#   'the',
#   'wall',
#   'like',
#   'lot',
#   'of',
#   'them',
#   'this',
#   'way',
#   'you',
#   'can',
#   'just',
#   'it',
#   'away',
#   'in',
#   'corner',
#   'until',
#   'your',
#   'ready',
#   'to',
#   'use',
#   'it',
#   'it',
#   'is',
#   'well',
#   'and',
#   'light',
#   'weight',
#   'so',
#   'it',
#   'does',
#   'not',
#   'put',
#   'strain',
#   'on',
#   'your',
#   'wrist',
#   'if',
#   'your',
#   'using',
#   'it',
#   'for',
#   'long',
#   'period',
#   'of',
#   'time',
#   'also',
#   'didn',
#   'notice',
#   'any',
#   'loss',
#   'of',
#   'power',
#   'when',
#   'used',
#   'it',
#   'for',
#   'little',
#   'over',
#   'five',
#   'minutes',
#   'in',
#   'single',
#   'use',
#   'probably',
#   'due',
#   'to',
#   'the',
#   'lithium',
#   'ion',
#   'battery',
#   'it',
#   'seems',
#   'to',
#   'be',
#   'very',
#   'well',
#   'so',
#   'hopefully',
#   'it',
#   'will',
#   'last',
#   'many',
#   'years'],
#  ['bought',
#   'this',
#   'guy',
#   'about',
#   'year',
#   'ago',
#   'still',
#   'works',
#   'fine',
#   'use',
#   'it',
#   'mostly',
#   'for',
#   'small',
#   'jobs',
#   'on',
#   'hard',
#   'wood',
#   'floors',
#   'my',
#   'biggest',
#   'complaint',
#   'is',
#   'the',
#   'noise',
#   'read',
#   'reviews',
#   'that',
#   'commented',
#   'about',
#   'how',
#   'loud',
#   'it',
#   'was',
#   'and',
#   'thought',
#   'big',
#   'deal',
#   'its',
#   'vacuum',
#   'cleaner',
#   'but',
#   'can',
#   'now',
#   'say',
#   'that',
#   'would',
#   'not',
#   'buy',
#   'this',
#   'product',
#   'again',
#   'based',
#   'on',
#   'how',
#   'loud',
#   'it',
#   'is',
#   'surely',
#   'there',
#   'are',
#   'hand',
#   'vacuums',
#   'that',
#   'are',
#   'just',
#   'as',
#   'effective',
#   'without',
#   'the',
#   'shrill',
#   'piercing',
#   'noise',
#   'this',
#   'thing',
#   'makes'],
#  ['did',
#   'lot',
#   'of',
#   'research',
#   'and',
#   'reading',
#   'of',
#   'reviews',
#   'before',
#   'purchasing',
#   'this',
#   'vacuum',
#   'and',
#   'so',
#   'far',
#   'am',
#   'very',
#   'pleased',
#   'wanted',
#   'hand',
#   'vacuum',
#   'to',
#   'clean',
#   'up',
#   'stray',
#   'cat',
#   'litter',
#   'that',
#   'got',
#   'tracked',
#   'out',
#   'of',
#   'the',
#   'box',
#   'and',
#   'it',
#   'perfect',
#   'this',
#   'vacuum',
#   'is',
#   'compact',
#   'light',
#   'easy',
#   'to',
#   'hold',
#   'and',
#   'powerful',
#   'the',
#   'narrow',
#   'neck',
#   'makes',
#   'it',
#   'easy',
#   'to',
#   'get',
#   'into',
#   'narrow',
#   'spaces',
#   'to',
#   'clean',
#   'and',
#   'you',
#   'can',
#   'rotate',
#   'the',
#   'head',
#   'degrees',
#   'in',
#   'each',
#   'direction',
#   'my',
#   'old',
#   'dirt',
#   'devil',
#   'probably',
#   'twice',
#   'as',
#   'much',
#   'as',
#   'this',
#   'vacuum',
#   'and',
#   'after',
#   'few',
#   'years',
#   'only',
#   'held',
#   'charge',
#   'for',
#   'seconds',
#   'at',
#   'time',
#   'have',
#   'had',
#   'no',
#   'issues',
#   'with',
#   'power',
#   'after',
#   'extended',
#   'use',
#   'and',
#   'it',
#   'is',
#   'also',
#   'easy',
#   'to',
#   'empty',
#   'and',
#   'clean',
#   'the',
#   'only',
#   'negative',
#   'is',
#   'that',
#   'wish',
#   'it',
#   'could',
#   'charge',
#   'on',
#   'it',
#   'side',
#   'rather',
#   'than',
#   'sitting',
#   'straight',
#   'up',
#   'on',
#   'the',
#   'end',
#   'so',
#   'that',
#   'could',
#   'it',
#   'on',
#   'shelf',
#   'but',
#   'otherwise',
#   'the',
#   'charging',
#   'pad',
#   'works',
#   'well',
#   'and',
#   'it',
#   'easy',
#   'to',
#   'see',
#   'if',
#   'it',
#   'seated',
#   'properly',
#   'with',
#   'the',
#   'blue',
#   'light',
#   'this',
#   'vacuum',
#   'is',
#   'tad',
#   'on',
#   'the',
#   'noisy',
#   'side',
#   'if',
#   'that',
#   'is',
#   'an',
#   'issue',
#   'for',
#   'you',
#   'otherwise',
#   'love',
#   'it'],
#  ['in',
#   'the',
#   'middle',
#   'of',
#   'the',
#   'road',
#   'on',
#   'this',
#   'don',
#   'have',
#   'another',
#   'portable',
#   'vac',
#   'to',
#   'compare',
#   'it',
#   'with',
#   'it',
#   'has',
#   'decent',
#   'suction',
#   'but',
#   'nothing',
#   'the',
#   'nozzle',
#   'is',
#   'small',
#   'and',
#   'long',
#   'enough',
#   'to',
#   'reach',
#   'few',
#   'narrow',
#   'spaces',
#   'but',
#   'again',
#   'nothing',
#   'special',
#   'there',
#   'are',
#   'still',
#   'more',
#   'nooks',
#   'and',
#   'crannies',
#   'like',
#   'to',
#   'reach',
#   'and',
#   'it',
#   'just',
#   'can',
#   'do',
#   'it',
#   'would',
#   'like',
#   'the',
#   'option',
#   'of',
#   'wall',
#   'mounting',
#   'or',
#   'table',
#   'top',
#   'this',
#   'can',
#   'only',
#   'rest',
#   'on',
#   'it',
#   'stand',
#   'on',
#   'flat',
#   'surface',
#   'and',
#   'if',
#   'you',
#   'nudge',
#   'it',
#   'you',
#   'knock',
#   'it',
#   'out',
#   'of',
#   'it',
#   'there',
#   'no',
#   'lock',
#   'in',
#   'mechanism',
#   'that',
#   'has',
#   'one',
#   'advantage',
#   'you',
#   'can',
#   'grab',
#   'it',
#   'easily',
#   'with',
#   'one',
#   'hand',
#   'and',
#   'that',
#   'good',
#   'but',
#   'tiny',
#   'design',
#   'change',
#   'and',
#   'they',
#   'could',
#   'have',
#   'made',
#   'it',
#   'bit',
#   'more',
#   'secure',
#   'when',
#   'it',
#   'into',
#   'it',
#   'stand',
#   'don',
#   'know',
#   'if',
#   'it',
#   'just',
#   'me',
#   'find',
#   'that',
#   'snapping',
#   'the',
#   'two',
#   'pieces',
#   'together',
#   'after',
#   'emptying',
#   'the',
#   'dust',
#   'bin',
#   'is',
#   'hit',
#   'or',
#   'miss',
#   'it',
#   'usually',
#   'takes',
#   'me',
#   'several',
#   'tries',
#   'to',
#   'get',
#   'it',
#   'to',
#   'snap',
#   'on',
#   'securely',
#   'pretty',
#   'so',
#   'being',
#   'by',
#   'vacuum',
#   'well',
#   'that',
#   'just',
#   'doesn',
#   'happen',
#   'but',
#   'this',
#   'one',
#   'does',
#   'the',
#   'dust',
#   'receptacle',
#   'does',
#   'require',
#   'getting',
#   'your',
#   'hand',
#   'or',
#   'something',
#   'else',
#   'in',
#   'there',
#   'to',
#   'free',
#   'up',
#   'dust',
#   'bunnies',
#   'and',
#   'pet',
#   'hair',
#   'that',
#   'really',
#   'poor',
#   'design',
#   'in',
#   'my',
#   'opinion',
#   'in',
#   'the',
#   'end',
#   'it',
#   'does',
#   'what',
#   'it',
#   'says',
#   'so',
#   'stars',
#   'but',
#   'for',
#   'me',
#   'wouldn',
#   'purchase',
#   'again',
#   'take',
#   'what',
#   'don',
#   'like',
#   'about',
#   'this',
#   'one',
#   'and',
#   'use',
#   'it',
#   'to',
#   'comparison',
#   'shop'],
#  ['works',
#   'as',
#   'one',
#   'would',
#   'hope',
#   'for',
#   'the',
#   'price',
#   'and',
#   'size',
#   'well',
#   'designed',
#   'neck',
#   'extension',
#   'very',
#   'useful',
#   'but',
#   'in',
#   'use',
#   'will',
#   'and',
#   'unlock',
#   'if',
#   'used',
#   'too',
#   'into',
#   'things',
#   'others',
#   'have',
#   'noted',
#   'this',
#   'the',
#   'base',
#   'charger',
#   'is',
#   'also',
#   'getting',
#   'the',
#   'unit',
#   'to',
#   'seat',
#   'for',
#   'charging',
#   'is',
#   'surprisingly',
#   'awkward',
#   'both',
#   'those',
#   'flaws',
#   'completely',
#   'and',
#   'for',
#   'me',
#   'the',
#   'noise',
#   'however',
#   'wow',
#   'more',
#   'it',
#   'the',
#   'pitch',
#   'of',
#   'the',
#   'noise',
#   'extremely',
#   'high',
#   'pitched',
#   'and',
#   'piercing',
#   'the',
#   'noise',
#   'cone',
#   'that',
#   'the',
#   'engine',
#   'is',
#   'but',
#   'you',
#   'really',
#   'get',
#   'the',
#   'full',
#   'of',
#   'it',
#   'at',
#   'certain',
#   'find',
#   'myself',
#   'trying',
#   'to',
#   'position',
#   'my',
#   'head',
#   'away',
#   'from',
#   'this',
#   'cone',
#   'though',
#   'hardly',
#   'an',
#   'despite',
#   'the',
#   'high',
#   'rating',
#   'of',
#   'this',
#   'unit',
#   'click',
#   'over',
#   'to',
#   'the',
#   'land',
#   'of',
#   'three',
#   'stars',
#   'and',
#   'behold',
#   'the',
#   'wish',
#   'would',
#   'have',
#   'little',
#   'deeper',
#   'before',
#   'purchased',
#   'will',
#   'probably',
#   'keep',
#   'bc',
#   'don',
#   'look',
#   'so',
#   'great',
#   'but',
#   'the',
#   'noise',
#   'is',
#   'real',
#   'and',
#   'will',
#   'honestly',
#   'be',
#   'to',
#   'ear',
#   'protection',
#   'while',
#   'use',
#   'this',
#   'thing',
#   'to',
#   'vacuum',
#   'up',
#   'the',
#   'cheerios',
#   'my',
#   'pet',
#   'keeps',
#   'all',
#   'over',
#   'the',
#   'damn',
#   'place'],
#  ['am',
#   'and',
#   'am',
#   'always',
#   'using',
#   'cordless',
#   'tools',
#   'and',
#   'various',
#   'vacuums',
#   'have',
#   'complaints',
#   'about',
#   'this',
#   'little',
#   'gem',
#   'would',
#   'highly',
#   'recommend',
#   'this',
#   'one',
#   'due',
#   'to',
#   'the',
#   'lithium',
#   'ion',
#   'battery',
#   'because',
#   'you',
#   'need',
#   'not',
#   'worry',
#   'about',
#   'it',
#   'sitting',
#   'on',
#   'the',
#   'charger',
#   'all',
#   'the',
#   'time',
#   'its',
#   'ok',
#   'to',
#   'do',
#   'that',
#   'where',
#   'as',
#   'nicad',
#   'or',
#   'nimh',
#   'will',
#   'fail',
#   'due',
#   'to',
#   'overcharging',
#   'easy',
#   'easy',
#   'powerful',
#   'for',
#   'its',
#   'size',
#   'quiet',
#   'looks',
#   'nice',
#   'does',
#   'its',
#   'job',
#   'that',
#   'it',
#   'was',
#   'designed',
#   'for',
#   'do',
#   'own',
#   'the',
#   'dyson',
#   'cordless',
#   'too',
#   'for',
#   'work',
#   'and',
#   'honestly',
#   'would',
#   'recommend',
#   'this',
#   'one',
#   'over',
#   'it',
#   'the',
#   'dyson',
#   'would',
#   'if',
#   'it',
#   'was',
#   'built',
#   'like',
#   'as',
#   'the',
#   'cost',
#   'would',
#   'suggest',
#   'but',
#   'its',
#   'not',
#   'at',
#   'all',
#   'buy',
#   'this',
#   'again',
#   'in',
#   'heartbeat'],
#  ['excellent',
#   'dustbuster',
#   'does',
#   'wonders',
#   'on',
#   'doing',
#   'stairs',
#   'it',
#   'not',
#   'too',
#   'loud',
#   'that',
#   'it',
#   'scares',
#   'the',
#   'dogs',
#   'attractive',
#   'with',
#   'high',
#   'build',
#   'quality',
#   'note',
#   'there',
#   'bright',
#   'blue',
#   'light',
#   'on',
#   'the',
#   'charging',
#   'stand',
#   'that',
#   'can',
#   'really',
#   'up',
#   'dark',
#   'room',
#   'at',
#   'night',
#   'don',
#   'know',
#   'why',
#   'but',
#   'this',
#   'might',
#   'be',
#   'an',
#   'issue',
#   'for',
#   'someone',
#   'out',
#   'there',
#   'maybe',
#   'if',
#   'you',
#   'had',
#   'apartment'],
#  ['super',
#   'strong',
#   'the',
#   'suction',
#   'is',
#   'so',
#   'good',
#   'often',
#   'have',
#   'to',
#   'flip',
#   'the',
#   'brush',
#   'over',
#   'the',
#   'tip',
#   'just',
#   'to',
#   'break',
#   'up',
#   'the',
#   'seal',
#   'bit',
#   'planned',
#   'on',
#   'just',
#   'using',
#   'it',
#   'to',
#   'go',
#   'around',
#   'the',
#   'baseboards',
#   'every',
#   'now',
#   'and',
#   'then',
#   'but',
#   'when',
#   'found',
#   'how',
#   'strong',
#   'it',
#   'was',
#   'began',
#   'using',
#   'it',
#   'to',
#   'tidy',
#   'up',
#   'nearly',
#   'everything',
#   'part',
#   'of',
#   'what',
#   'me',
#   'to',
#   'leave',
#   'review',
#   'was',
#   'my',
#   'about',
#   'completely',
#   'cleaning',
#   'my',
#   'the',
#   'fan',
#   'vent',
#   'and',
#   'haven',
#   'looked',
#   'this',
#   'good',
#   'since',
#   'bought',
#   'it',
#   'nor',
#   'has',
#   'it',
#   'ran',
#   'so',
#   'not',
#   'even',
#   'going',
#   'to',
#   'get',
#   'into',
#   'how',
#   'much',
#   'it',
#   'helped',
#   'me',
#   'detail',
#   'my',
#   'car',
#   'it',
#   'true',
#   'it',
#   'doesn',
#   'have',
#   'wall',
#   'hanging',
#   'charger',
#   'and',
#   'it',
#   'does',
#   'bit',
#   'on',
#   'the',
#   'stand',
#   'if',
#   'so',
#   'it',
#   'probably',
#   'not',
#   'best',
#   'in',
#   'high',
#   'traffic',
#   'area',
#   'or',
#   'on',
#   'an',
#   'unstable',
#   'surface',
#   'store',
#   'it',
#   'under',
#   'corner',
#   'table',
#   'in',
#   'the',
#   'utility',
#   'room',
#   'and',
#   'it',
#   'been',
#   'perfect',
#   'there',
#   'haven',
#   'had',
#   'it',
#   'for',
#   'very',
#   'long',
#   'so',
#   'not',
#   'sure',
#   'about',
#   'overall',
#   'longevity',
#   'but',
#   'it',
#   'seems',
#   'to',
#   'be',
#   'of',
#   'incredible',
#   'and',
#   'quality',
#   'so',
#   'doubt',
#   'it',
#   'll',
#   'have',
#   'any',
#   'issues',
#   'with',
#   'charging',
#   'or',
#   'staying',
#   'charged',
#   'any',
#   'time',
#   'soon'],
#  ['my',
#   'husband',
#   'loves',
#   'his',
#   'new',
#   'black',
#   'decker',
#   'chv',
#   'the',
#   'day',
#   'it',
#   'arrived',
#   'he',
#   'me',
#   'how',
#   'the',
#   'nozzle',
#   'extended',
#   'that',
#   'the',
#   'nozzle',
#   'rotated',
#   'so',
#   'that',
#   'he',
#   'could',
#   'reach',
#   'more',
#   'places',
#   'with',
#   'the',
#   'vacuum',
#   'he',
#   'was',
#   'also',
#   'happy',
#   'that',
#   'it',
#   'had',
#   'brush',
#   'to',
#   'use',
#   'when',
#   'he',
#   'vacuumed',
#   'the',
#   'car',
#   'seat',
#   'it',
#   'is',
#   'light',
#   'weight',
#   'has',
#   'good',
#   'suction',
#   'and',
#   'is',
#   'easy',
#   'to',
#   'clean',
#   'the',
#   'vacuum',
#   'is',
#   'so',
#   'easy',
#   'for',
#   'him',
#   'to',
#   'use',
#   'and',
#   'is',
#   'always',
#   'charged',
#   'that',
#   'he',
#   'has',
#   'found',
#   'many',
#   'occasions',
#   'to',
#   'use',
#   'it',
#   'this',
#   'is',
#   'lot',
#   'easier',
#   'than',
#   'broom',
#   'and',
#   'dustpan',
#   'and',
#   'the',
#   'extending',
#   'nozzle',
#   'is',
#   'so',
#   'useful',
#   'when',
#   'he',
#   'cleans',
#   'the',
#   'car',
#   'he',
#   'is',
#   'super',
#   'happy',
#   'with',
#   'his',
#   'new',
#   'cleaner',
#   'and',
#   'he',
#   'loves',
#   'the',
#   'fact',
#   'that',
#   'it',
#   'has',
#   'battery',
#   'and',
#   'that',
#   'he',
#   'doesn',
#   'have',
#   'cord',
#   'that',
#   'gets',
#   'in',
#   'his',
#   'way'],
#  ['have',
#   'read',
#   'other',
#   'reviews',
#   'of',
#   'this',
#   'product',
#   'that',
#   'the',
#   'charging',
#   'light',
#   'was',
#   'too',
#   'bright',
#   'for',
#   'them',
#   'but',
#   'like',
#   'it',
#   'as',
#   'sort',
#   'of',
#   'side',
#   'light',
#   'while',
#   'my',
#   'is',
#   'on',
#   'and',
#   'as',
#   'night',
#   'light',
#   'when',
#   'the',
#   'is',
#   'off',
#   'it',
#   'is',
#   'very',
#   'powerful',
#   'and',
#   'charges',
#   'quickly',
#   'leave',
#   'mine',
#   'on',
#   'the',
#   'charger',
#   'all',
#   'of',
#   'the',
#   'time',
#   'the',
#   'only',
#   'negative',
#   'things',
#   'can',
#   'think',
#   'of',
#   'is',
#   'maybe',
#   'the',
#   'is',
#   'too',
#   'small',
#   'for',
#   'some',
#   'people',
#   'think',
#   'that',
#   'is',
#   'why',
#   'it',
#   'is',
#   'so',
#   'powerful',
#   'also',
#   'the',
#   'price',
#   'when',
#   'first',
#   'bought',
#   'it',
#   'as',
#   'gift',
#   'was',
#   'super',
#   'high',
#   'then',
#   'bought',
#   'second',
#   'one',
#   'for',
#   'myself',
#   'for',
#   'quite',
#   'bit',
#   'less',
#   'and',
#   'now',
#   'see',
#   'it',
#   'selling',
#   'for',
#   'even',
#   'less',
#   'would',
#   'advise',
#   'people',
#   'to',
#   'purchase',
#   'it',
#   'at',
#   'the',
#   'price',
#   'it',
#   'is',
#   'now'],
#  ['it',
#   'got',
#   'lot',
#   'of',
#   'suction',
#   'and',
#   'the',
#   'battery',
#   'has',
#   'enough',
#   'power',
#   'that',
#   've',
#   'never',
#   'noticed',
#   'it',
#   'down',
#   'or',
#   'dying',
#   'during',
#   'use',
#   'it',
#   'also',
#   'looks',
#   'cool',
#   'and',
#   'is',
#   'easy',
#   'to',
#   'charge',
#   'by',
#   'sitting',
#   'on',
#   'its',
#   'charger',
#   'base',
#   'but',
#   'there',
#   'are',
#   'few',
#   'annoying',
#   'things',
#   'about',
#   'it',
#   'too',
#   'the',
#   'nozzle',
#   'is',
#   'small',
#   'about',
#   'the',
#   'size',
#   'of',
#   'regular',
#   'vac',
#   'crevice',
#   'tool',
#   'so',
#   'you',
#   'have',
#   'to',
#   'move',
#   'it',
#   'around',
#   'lot',
#   'the',
#   'flip',
#   'down',
#   'brush',
#   'adds',
#   'so',
#   'much',
#   'space',
#   'between',
#   'the',
#   'nozzle',
#   'and',
#   'the',
#   'surface',
#   'you',
#   'want',
#   'to',
#   'clean',
#   'that',
#   'suction',
#   'is',
#   'reduced',
#   'the',
#   'little',
#   'flap',
#   'inside',
#   'that',
#   'keeps',
#   'dirt',
#   'from',
#   'falling',
#   'out',
#   'swings',
#   'open',
#   'when',
#   'the',
#   'vac',
#   'is',
#   'on',
#   'the',
#   'stand',
#   'so',
#   'any',
#   'bugs',
#   'you',
#   'sucked',
#   'up',
#   'can',
#   'get',
#   'out',
#   'if',
#   'you',
#   'suck',
#   'up',
#   'dust',
#   'bunnies',
#   'or',
#   'pet',
#   'hair',
#   'the',
#   'dirt',
#   'cup',
#   'won',
#   'empty',
#   'unless',
#   'you',
#   'use',
#   'something',
#   'thin',
#   'and',
#   'to',
#   'it',
#   'out',
#   'gross'],
#  ['this',
#   'is',
#   'probably',
#   'the',
#   'best',
#   'vacuum',
#   'of',
#   'this',
#   'type',
#   've',
#   'ever',
#   'purchased',
#   'sounds',
#   'like',
#   'and',
#   'that',
#   'high',
#   'really',
#   'makes',
#   'for',
#   'powerful',
#   'vacuum',
#   'it',
#   'almost',
#   'completely',
#   'disassembles',
#   'to',
#   'about',
#   'parts',
#   'for',
#   'cleaning',
#   'nothing',
#   'can',
#   'get',
#   'nasty',
#   'because',
#   'you',
#   'can',
#   'wash',
#   'it',
#   'out',
#   'with',
#   'soap',
#   'and',
#   'warm',
#   'water',
#   'except',
#   'for',
#   'the',
#   'filter',
#   'which',
#   'you',
#   'can',
#   'just',
#   'vacuum',
#   'stores',
#   'and',
#   'recharges',
#   'in',
#   'an',
#   'upright',
#   'plus',
#   'it',
#   'is',
#   'lithium',
#   'ion',
#   'battery',
#   'so',
#   'very',
#   'nice',
#   'discharge',
#   'love',
#   'this',
#   'thing'],
#  ['this',
#   'may',
#   'be',
#   'my',
#   'favorite',
#   'purchase',
#   've',
#   'made',
#   'all',
#   'year',
#   'this',
#   'is',
#   'light',
#   'weight',
#   'handheld',
#   'vacuum',
#   'with',
#   'impressive',
#   'suctioning',
#   'power',
#   'up',
#   'using',
#   'it',
#   'so',
#   'much',
#   'more',
#   'than',
#   'my',
#   'large',
#   'floor',
#   'vacuum',
#   'because',
#   'it',
#   'does',
#   'just',
#   'as',
#   'good',
#   'of',
#   'job',
#   'cleaning',
#   'things',
#   'up',
#   'but',
#   'is',
#   'so',
#   'much',
#   'less',
#   'of',
#   'hassle',
#   'and',
#   'can',
#   'really',
#   'fit',
#   'into',
#   'the',
#   'nooks',
#   'and',
#   'crannies',
#   'around',
#   'my',
#   'apartment',
#   'in',
#   'ways',
#   'the',
#   'floor',
#   'vacuum',
#   'just',
#   'can',
#   'it',
#   'seems',
#   'to',
#   'hold',
#   'charge',
#   'for',
#   'very',
#   'long',
#   'time',
#   've',
#   'had',
#   'it',
#   'for',
#   'few',
#   'months',
#   'and',
#   'have',
#   'used',
#   'it',
#   'extensively',
#   'and',
#   'it',
#   'still',
#   'going',
#   'on',
#   'its',
#   'first',
#   'charge',
#   'it',
#   'highly',
#   'portable',
#   'too',
#   'known',
#   'to',
#   'drag',
#   'it',
#   'outside',
#   'to',
#   'my',
#   'apartment',
#   'lot',
#   'and',
#   'vacuum',
#   'up',
#   'my',
#   'cars',
#   'on',
#   'the',
#   'weekends',
#   'can',
#   'recommend',
#   'this',
#   'enough'],
#  ['ve',
#   'read',
#   'several',
#   'of',
#   'the',
#   'other',
#   'reviews',
#   'and',
#   'feel',
#   'it',
#   'necessary',
#   'to',
#   'leave',
#   'some',
#   've',
#   'had',
#   'this',
#   'new',
#   'dust',
#   'buster',
#   'for',
#   'few',
#   'weeks',
#   'now',
#   'and',
#   'have',
#   'no',
#   'of',
#   'it',
#   'don',
#   'have',
#   'any',
#   'problem',
#   'with',
#   'the',
#   'extension',
#   'tube',
#   'retracting',
#   'by',
#   'itself',
#   'in',
#   'fact',
#   'it',
#   'takes',
#   'some',
#   'effort',
#   'to',
#   'retract',
#   'it',
#   'nor',
#   'have',
#   'had',
#   'the',
#   'front',
#   'end',
#   'of',
#   'the',
#   'unit',
#   'fall',
#   'off',
#   'or',
#   'any',
#   'part',
#   'fall',
#   'off',
#   'for',
#   'that',
#   'matter',
#   'the',
#   'battery',
#   'life',
#   'has',
#   'been',
#   'all',
#   'could',
#   'ask',
#   'haven',
#   'been',
#   'able',
#   'to',
#   'run',
#   'it',
#   'down',
#   'yet',
#   'the',
#   'stand',
#   'vs',
#   'hanging',
#   'on',
#   'the',
#   'wall',
#   'took',
#   'some',
#   'getting',
#   'used',
#   'to',
#   'however',
#   'now',
#   'that',
#   'am',
#   'used',
#   'to',
#   'it',
#   'like',
#   'it',
#   'lot',
#   'it',
#   'easier',
#   'to',
#   'deal',
#   'with',
#   'to',
#   'pick',
#   'up',
#   'the',
#   'unit',
#   'and',
#   'put',
#   'it',
#   'down',
#   'have',
#   'had',
#   'no',
#   'problems',
#   'with',
#   'the',
#   'amount',
#   'of',
#   'suction',
#   'it',
#   'has',
#   'picked',
#   'up',
#   'everything',
#   'have',
#   'thrown',
#   'at',
#   'it',
#   'have',
#   'noticed',
#   'comments',
#   'about',
#   'how',
#   'bright',
#   'the',
#   'indicator',
#   'light',
#   'is',
#   'this',
#   'is',
#   'the',
#   'case',
#   'it',
#   'is',
#   'quite',
#   'bright',
#   'it',
#   'probably',
#   'not',
#   'good',
#   'idea',
#   'to',
#   'put',
#   'it',
#   'in',
#   'your',
#   'bedroom',
#   'in',
#   'plain',
#   'sight',
#   'think',
#   'of',
#   'putting',
#   'it',
#   'in',
#   'closet',
#   'instead',
#   'keep',
#   'mine',
#   'in',
#   'the',
#   'kitchen',
#   'so',
#   'there',
#   'is',
#   'absolutely',
#   'no',
#   'problem',
#   'at',
#   'all',
#   'so',
#   'what',
#   'is',
#   'wrong',
#   'with',
#   'it',
#   'let',
#   'me',
#   'think',
#   'about',
#   'that',
#   'and',
#   'get',
#   'back',
#   'to',
#   'you',
#   'right',
#   'now',
#   'in',
#   'other',
#   'words',
#   'really',
#   'like',
#   'this',
#   'machine',
#   'particularly',
#   'when',
#   'compared',
#   'to',
#   'its',
#   'ni',
#   'cad',
#   'half',
#   'brother',
#   'had',
#   'before',
#   'it',
#   'and',
#   'is',
#   'now',
#   'gone',
#   'to',
#   'this',
#   'is',
#   'big',
#   'improvement',
#   'highly',
#   'recommended'],
#  ['here',
#   'what',
#   'love',
#   'about',
#   'this',
#   'vac',
#   'you',
#   'can',
#   'completely',
#   'take',
#   'it',
#   'apart',
#   'we',
#   've',
#   'gone',
#   'through',
#   'don',
#   'know',
#   'how',
#   'many',
#   'dustbusters',
#   'they',
#   're',
#   'all',
#   'pretty',
#   'much',
#   'the',
#   'same',
#   'but',
#   'this',
#   'one',
#   'has',
#   'feature',
#   'that',
#   'made',
#   'difference',
#   'for',
#   'me',
#   'it',
#   'comes',
#   'apart',
#   'so',
#   'you',
#   'can',
#   'really',
#   'clean',
#   'all',
#   'the',
#   'gunk',
#   'out',
#   'of',
#   'it',
#   'previous',
#   'models',
#   'we',
#   've',
#   'had',
#   'don',
#   'let',
#   'you',
#   'do',
#   'that',
#   'so',
#   'there',
#   'always',
#   'some',
#   'dust',
#   'the',
#   'whatever',
#   'it',
#   'called',
#   'this',
#   'one',
#   'the',
#   'clear',
#   'dust',
#   'comes',
#   'out'],
#  ['this',
#   'here',
#   'black',
#   'decker',
#   'duster',
#   'really',
#   'saved',
#   'my',
#   'was',
#   'at',
#   'home',
#   'by',
#   'myself',
#   'over',
#   'weekend',
#   'while',
#   'my',
#   'wife',
#   'was',
#   'away',
#   'at',
#   'work',
#   'while',
#   'she',
#   'was',
#   'gone',
#   'thought',
#   'try',
#   'to',
#   'make',
#   'some',
#   'chocolate',
#   'from',
#   'with',
#   'bunch',
#   'of',
#   'didn',
#   'know',
#   'what',
#   'those',
#   'were',
#   'and',
#   'decided',
#   'not',
#   'to',
#   'do',
#   'that',
#   'so',
#   'decided',
#   'some',
#   'absinthe',
#   'instead',
#   'the',
#   'real',
#   'way',
#   'had',
#   'gotten',
#   'bottle',
#   'from',
#   'friend',
#   'of',
#   'mine',
#   'that',
#   'had',
#   'never',
#   'opened',
# ...
#   'actually',
#   'the',
#   'nozzle',
#   'on',
#   'it',
#   'few',
#   'times',
#   'before',
#   'it',
#   'to',
#   'pick',
#   'it',
#   'up',
#   'and',
#   'no',
#   'it',
#   'not',
#   'large',
#   'piece',
#   'trying',
#   'to',
#   'pick',
#   'up',
#   'that',
#   'my',
#   'only',
#   'gripe',
#   'with',
#   'it',
#   'otherwise',
#   'it',
#   'great'],
#  ['always',
#   'read',
#   'many',
#   'online',
#   'reviews',
#   'prior',
#   'to',
#   'making',
#   'purchase',
#   'and',
#   'my',
#   'of',
#   'this',
#   'vacuum',
#   'was',
#   'no',
#   'different',
#   'have',
#   'always',
#   'been',
#   'very',
#   'satisfied',
#   'with',
#   'my',
#   'purchases',
#   'unfortunately',
#   'this',
#   'was',
#   'not',
#   'good',
#   'purchase',
#   'wanted',
#   'hand',
#   'held',
#   'vacuum',
#   'that',
#   'had',
#   'battery',
#   'that',
#   'would',
#   'still',
#   'hold',
#   'charge',
#   'even',
#   'after',
#   'the',
#   'product',
#   'was',
#   'year',
#   'old',
#   'my',
#   'other',
#   'ones',
#   'always',
#   'died',
#   'out',
#   'after',
#   'about',
#   'year',
#   'this',
#   'vacuum',
#   'still',
#   'holds',
#   'charge',
#   'after',
#   'using',
#   'it',
#   'for',
#   'year',
#   'but',
#   'absolutely',
#   'hate',
#   'it',
#   'it',
#   'is',
#   'so',
#   'loud',
#   'that',
#   'can',
#   'stand',
#   'using',
#   'it',
#   'it',
#   'has',
#   'an',
#   'ear',
#   'piercing',
#   'sound',
#   'and',
#   'hesitant',
#   'to',
#   'use',
#   'it',
#   'when',
#   'other',
#   'people',
#   'are',
#   'nearby',
#   'the',
#   'neck',
#   'and',
#   'nozzle',
#   'is',
#   'too',
#   'narrow',
#   'the',
#   'hole',
#   'where',
#   'the',
#   'debris',
#   'is',
#   'sucked',
#   'in',
#   'is',
#   'so',
#   'small',
#   'and',
#   'narrow',
#   'that',
#   'it',
#   'takes',
#   'forever',
#   'to',
#   'clean',
#   'an',
#   'area',
#   'used',
#   'to',
#   'do',
#   'my',
#   'entire',
#   'kitchen',
#   'dining',
#   'room',
#   'with',
#   'my',
#   'old',
#   'one',
#   'when',
#   'didn',
#   'feel',
#   'like',
#   'getting',
#   'the',
#   'big',
#   'vacuum',
#   'out',
#   'it',
#   'worked',
#   'great',
#   'this',
#   'one',
#   'hardly',
#   'seems',
#   'to',
#   'pick',
#   'up',
#   'anything',
#   'because',
#   'the',
#   'opening',
#   'is',
#   'so',
#   'small'],
#  ['normally',
#   'money',
#   'is',
#   'extremely',
#   'worth',
#   'spending',
#   'with',
#   'amazon',
#   'it',
#   'was',
#   'not',
#   'with',
#   'this',
#   'worthless',
#   'product',
#   'from',
#   'the',
#   'beginning',
#   'it',
#   'was',
#   'very',
#   'hard',
#   'to',
#   'balance',
#   'and',
#   'kept',
#   'falling',
#   'over',
#   'it',
#   'was',
#   'also',
#   'totally',
#   'for',
#   'cleaning',
#   'it',
#   'had',
#   'very',
#   'small',
#   'suction',
#   'capacity',
#   'it',
#   'totally',
#   'broke',
#   'down',
#   'months',
#   'after',
#   'received',
#   'it',
#   'having',
#   'had',
#   'very',
#   'little',
#   'usage',
#   'because',
#   'it',
#   'didn',
#   'any',
#   'clean',
#   'up',
#   'worth',
#   'my',
#   'making',
#   'the',
#   'effort',
#   'will',
#   'try',
#   'again',
#   'for',
#   'different',
#   'product',
#   'because',
#   'really',
#   'need',
#   'something',
#   'small',
#   'powerful',
#   'convenient',
#   'stable',
#   'when',
#   'not',
#   'in',
#   'use',
#   'and',
#   'effective',
#   'and',
#   'this',
#   'product',
#   'had',
#   'none',
#   'of',
#   'these',
#   'oh',
#   'well',
#   'if',
#   'only',
#   'had',
#   'on',
#   'my',
#   'better',
#   'and',
#   'returned',
#   'it',
#   'when',
#   'could'],
#  ['bought',
#   'this',
#   'for',
#   'the',
#   'little',
#   'jobs',
#   'and',
#   'the',
#   'hard',
#   'to',
#   'reach',
#   'jobs',
#   'have',
#   'been',
#   'using',
#   'this',
#   'for',
#   'little',
#   'over',
#   'week',
#   'and',
#   'am',
#   'impressed',
#   'it',
#   'has',
#   'great',
#   'suction',
#   'power',
#   'picks',
#   'up',
#   'dog',
#   'food',
#   'crumbs',
#   'easily',
#   'would',
#   'say',
#   'it',
#   'will',
#   'last',
#   'about',
#   'minutes',
#   'of',
#   'constantly',
#   'being',
#   'on',
#   'it',
#   'cordless',
#   'so',
#   'it',
#   'can',
#   'be',
#   'used',
#   'for',
#   'long',
#   'jobs',
#   'it',
#   'took',
#   'about',
#   'hours',
#   'to',
#   'recharge',
#   'the',
#   'entire',
#   'battery',
#   'the',
#   'best',
#   'tool',
#   'on',
#   'it',
#   'is',
#   'the',
#   'extended',
#   'nozzle',
#   'if',
#   'you',
#   're',
#   'looking',
#   'for',
#   'something',
#   'that',
#   'you',
#   'can',
#   'use',
#   'extensively',
#   'either',
#   'use',
#   'this',
#   'and',
#   'keep',
#   'recharging',
#   'it',
#   'or',
#   'for',
#   'corded',
#   'hand',
#   'vac'],
#  ['like',
#   'to',
#   'keep',
#   'my',
#   'car',
#   'clean',
#   'and',
#   'dust',
#   'free',
#   'given',
#   'the',
#   'amount',
#   'of',
#   'time',
#   'spend',
#   'to',
#   'and',
#   'from',
#   'work',
#   'after',
#   'reading',
#   'reviews',
#   'decided',
#   'to',
#   'purchase',
#   'this',
#   'one',
#   'after',
#   'couple',
#   'months',
#   'so',
#   'far',
#   'so',
#   'good',
#   'but',
#   'definitely',
#   'remember',
#   'to',
#   'clean',
#   'out',
#   'the',
#   'replaceable',
#   'filter',
#   'every',
#   'now',
#   'and',
#   'then',
#   'since',
#   'the',
#   'suction',
#   'before',
#   'and',
#   'after',
#   'cleaning',
#   'it',
#   'is',
#   'night',
#   'and',
#   'day',
#   'took',
#   'off',
#   'the',
#   'brush',
#   'swivel',
#   'accidentally',
#   'off',
#   'while',
#   'vacuuming',
#   'under',
#   'my',
#   'car',
#   'seat',
#   'but',
#   'decided',
#   'to',
#   'leave',
#   'it',
#   'off',
#   'since',
#   'don',
#   'really',
#   'use',
#   'it',
#   'also',
#   'charges',
#   'pretty',
#   'quickly',
#   'too',
#   'thumbs',
#   'up',
#   'from',
#   'me'],
#  ['worst',
#   'product',
#   'design',
#   'ever',
#   'cleaner',
#   'must',
#   'rest',
#   'on',
#   'saucer',
#   'like',
#   'base',
#   'instead',
#   'of',
#   'hanging',
#   'next',
#   'to',
#   'the',
#   'outlet',
#   'for',
#   'charging',
#   'that',
#   'means',
#   'there',
#   'must',
#   'be',
#   'shelf',
#   'nearby',
#   'because',
#   'it',
#   'stores',
#   'vertically',
#   'and',
#   'gets',
#   'in',
#   'the',
#   'way',
#   'very',
#   'would',
#   'not',
#   'buy',
#   'again',
#   'the',
#   'cleaner',
#   'itself',
#   'works',
#   'well',
#   'but',
#   'not',
#   'worth',
#   'the',
#   'trouble',
#   'of',
#   'installation',
#   'and',
#   'storage',
#   'especially',
#   'in',
#   'very',
#   'small',
#   'room'],
#  ['this',
#   'thing',
#   'ugh',
#   'bought',
#   'it',
#   'against',
#   'my',
#   'better',
#   'thinking',
#   'that',
#   'be',
#   'able',
#   'to',
#   'return',
#   'it',
#   'if',
#   'didn',
#   'like',
#   'it',
#   'the',
#   'first',
#   'time',
#   'used',
#   'it',
#   'the',
#   'part',
#   'that',
#   'the',
#   'ground',
#   'got',
#   'all',
#   'scratched',
#   'up',
#   'but',
#   'didn',
#   'notice',
#   'until',
#   'the',
#   'third',
#   'time',
#   'used',
#   'it',
#   'and',
#   'decided',
#   'that',
#   'yep',
#   'really',
#   'do',
#   'hate',
#   'this',
#   'stupid',
#   'and',
#   'intended',
#   'to',
#   'return',
#   'it',
#   'now',
#   'stuck',
#   'with',
#   'it',
#   'ugh',
#   'because',
#   'the',
#   'suction',
#   'is',
#   'weak',
#   'it',
#   'clogs',
#   'quickly',
#   'have',
#   'long',
#   'hair',
#   'and',
#   'it',
#   'the',
#   'filter',
#   'useless',
#   'quickly',
#   'it',
#   'weird',
#   'shape',
#   'and',
#   'size',
#   'that',
#   'doesn',
#   'store',
#   'easily',
#   'under',
#   'cabinet',
#   'and',
#   'is',
#   'far',
#   'too',
#   'ugly',
#   'to',
#   'be',
#   'in',
#   'view',
#   'the',
#   'neck',
#   'is',
#   'too',
#   'large',
#   'to',
#   'the',
#   'length',
#   'guess',
#   'the',
#   'length',
#   'is',
#   'to',
#   'reach',
#   'places',
#   'that',
#   'are',
#   'hard',
#   'to',
#   'get',
#   'to',
#   'right',
#   'cool',
#   'except',
#   'that',
#   'the',
#   'size',
#   'of',
#   'the',
#   'neck',
#   'prevents',
#   'it',
#   'from',
#   'into',
#   'hard',
#   'to',
#   'reach',
#   'places',
#   'it',
#   'not',
#   'much',
#   'smaller',
#   'than',
#   'my',
#   'hand',
#   'which',
#   'yeah',
#   'is',
#   'small',
#   'for',
#   'woman',
#   'but',
#   'not',
#   'so',
#   'feel',
#   'stupid',
#   'for',
#   'buying',
#   'this',
#   'every',
#   'time',
#   'look',
#   'at',
#   'it',
#   'hate',
#   'myself',
#   'little',
#   'black',
#   'and',
#   'decker',
#   'and',
#   'amazon',
#   'with',
#   'its',
#   'less',
#   'than',
#   'awesome',
#   'return',
#   'is',
#   'selling',
#   'and',
#   'with',
#   'this',
#   'thing',
#   'note',
#   'to',
#   'self',
#   'buy',
#   'from',
#   'whenever',
#   'possible'],
#  ['really',
#   'happy',
#   'with',
#   'this',
#   'little',
#   'vac',
#   'bought',
#   'it',
#   'for',
#   'my',
#   'car',
#   'and',
#   'it',
#   'gets',
#   'in',
#   'all',
#   'the',
#   'small',
#   'crevices',
#   'cleans',
#   'really',
#   'really',
#   'well',
#   'it',
#   'light',
#   'weight',
#   'which',
#   'is',
#   'great',
#   'and',
#   'happy',
#   'with',
#   'my',
#   'purchase'],
#  ['great',
#   'for',
#   'quick',
#   'pick',
#   'me',
#   'ups',
#   'use',
#   'this',
#   'all',
#   'the',
#   'time',
#   'to',
#   'pick',
#   'up',
#   'dirt',
#   'in',
#   'between',
#   'vacuuming',
#   'hold',
#   'power',
#   'well',
#   'and',
#   'one',
#   'finished',
#   'it',
#   'goes',
#   'into',
#   'its',
#   'cradle',
#   'to',
#   'charge',
#   'and',
#   'be',
#   'ready',
#   'when',
#   'need',
#   'it'],
#  ['love',
#   'the',
#   'product',
#   'the',
#   'only',
#   'minor',
#   'complaint',
#   'have',
#   'is',
#   'that',
#   'with',
#   'the',
#   'brush',
#   'extended',
#   'you',
#   'get',
#   'slightly',
#   'less',
#   'sucking',
#   'power',
#   'because',
#   'of',
#   'the',
#   'extra',
#   'space',
#   'but',
#   'it',
#   'still',
#   'enough',
#   'to',
#   'do',
#   'every',
#   'job'],
#  ['this',
#   'one',
#   'has',
#   'very',
#   'good',
#   'design',
#   'comes',
#   'with',
#   'charging',
#   'base',
#   'you',
#   'don',
#   'have',
#   'to',
#   'look',
#   'for',
#   'the',
#   'little',
#   'power',
#   'each',
#   'time',
#   'you',
#   'use',
#   'it',
#   'just',
#   'leave',
#   'it',
#   'upright',
#   'on',
#   'the',
#   'charging',
#   'base'],
#  ['this',
#   'is',
#   'very',
#   'handy',
#   'little',
#   'vac',
#   'rechargable',
#   'lithium',
#   'battery',
#   'that',
#   'holds',
#   'its',
#   'charge',
#   'have',
#   'that',
#   'toss',
#   'their',
#   'food',
#   'everywhere',
#   'and',
#   'this',
#   'vac',
#   'picks',
#   'up',
#   'all',
#   'the',
#   'mess',
#   'with',
#   'ease'],
#  ['nice',
#   'little',
#   'of',
#   'hand',
#   'vacuum',
#   'order',
#   'this',
#   'again',
#   'good',
#   'suction',
#   'and',
#   'easy',
#   'to',
#   'use',
#   'highly',
#   'recommend',
#   'especially',
#   'if',
#   'you',
#   're',
#   'on',
#   'the',
#   'fence',
#   'about',
#   'which',
#   'model',
#   'to',
#   'purchase'],
#  ['very',
#   'happy',
#   'with',
#   'this',
#   'version',
#   'we',
#   've',
#   'use',
#   'dirt',
#   'devil',
#   'the',
#   'previous',
#   'version',
#   'of',
#   'this',
#   'one',
#   'and',
#   'all',
#   'were',
#   'not',
#   'even',
#   'close',
#   'my',
#   'wife',
#   'is',
#   'really',
#   'happy',
#   'also',
#   'which',
#   'is',
#   'great'],
#  ['ve',
#   'had',
#   'this',
#   'for',
#   'almost',
#   'month',
#   'now',
#   'my',
#   'wife',
#   'likes',
#   'to',
#   'use',
#   'it',
#   'to',
#   'get',
#   'spiders',
#   'and',
#   'bugs',
#   'also',
#   'does',
#   'good',
#   'job',
#   'with',
#   'our',
#   'dogs',
#   'hair',
#   'and',
#   'any',
#   'other',
#   'small',
#   'clean',
#   'up',
#   'jobs'],
#  ['not',
#   'nearly',
#   'as',
#   'good',
#   'as',
#   'would',
#   'have',
#   'expected',
#   'it',
#   'does',
#   'ok',
#   'its',
#   'not',
#   'super',
#   'fast',
#   'and',
#   'it',
#   'usually',
#   'takes',
#   'several',
#   'passes',
#   'to',
#   'get',
#   'everything',
#   'even',
#   'just',
#   'tiny',
#   'little',
#   'crumbs'],
#  ['got',
#   'this',
#   'for',
#   'my',
#   'daughter',
#   'in',
#   'law',
#   'she',
#   'loves',
#   'it',
#   'says',
#   'it',
#   'does',
#   'work',
#   'on',
#   'stairs',
#   'even',
#   'though',
#   'there',
#   'is',
#   'on',
#   'that',
#   'for',
#   'almost',
#   'all',
#   'hand',
#   'helds',
#   'including',
#   'this',
#   'one'],
#  ['very',
#   'powerful',
#   'only',
#   'use',
#   'it',
#   'for',
#   'very',
#   'clean',
#   'ups',
#   'and',
#   'it',
#   'does',
#   'very',
#   'job',
#   'also',
#   'like',
#   'that',
#   'the',
#   'brush',
#   'is',
#   'attached',
#   'so',
#   'can',
#   'lose',
#   'it'],
#  ['this',
#   'thing',
#   'is',
#   'amazing',
#   'and',
#   'works',
#   'really',
#   'well',
#   'hope',
#   'that',
#   'it',
#   'lasts',
#   'longer',
#   'than',
#   'the',
#   'cheaper',
#   'version',
#   'that',
#   'got'],
#  ['bought',
#   'this',
#   'for',
#   'our',
#   'family',
#   'car',
#   'its',
#   'very',
#   'convenient',
#   'maybe',
#   'because',
#   'its',
#   'wireless',
#   'and',
#   'easy',
#   'clean',
#   'up'],
#  ['this',
#   'thing',
#   'works',
#   'so',
#   'well',
#   'and',
#   'because',
#   'of',
#   'the',
#   'lithium',
#   'battery',
#   'about',
#   'loss',
#   'battery',
#   'life',
#   'are',
#   'reduced',
#   'cleans',
#   'well',
#   'and',
#   'easy',
#   'to',
#   'clean',
#   'also',
#   'has',
#   'an',
#   'extension',
#   'for',
#   'slightly',
#   'harder',
#   'to',
#   'reach',
#   'places',
#   'would',
#   'buy',
#   'again',
#   'only',
#   'downside',
#   'is',
#   'that',
#   'is',
#   'on',
#   'the',
#   'loud',
#   'side',
#   'but',
#   'for',
#   'me',
#   'that',
#   'isn',
#   'concern'],
#  ['the',
#   'rechargeable',
#   'battery',
#   'in',
#   'this',
#   'model',
#   'only',
#   'lasted',
#   'about',
#   'months',
#   'there',
#   'are',
#   'lot',
#   'of',
#   'bad',
#   'reviews',
#   'about',
#   'this',
#   'model',
#   'and',
#   'the',
#   'battery',
#   'problem',
#   'the',
#   'replacement',
#   'battery',
#   'which',
#   'is',
#   'also',
#   'costs',
#   'almost',
#   'the',
#   'same',
#   'as',
#   'the',
#   'total',
#   'unit'],
#  ['excellent',
#   'little',
#   'portable',
#   'vacuum',
#   'cleaner',
#   'which',
#   'is',
#   'well',
#   'worth',
#   'its',
#   'price'],
#  ['its',
#   'vacuum',
#   'to',
#   'have',
#   'if',
#   'you',
#   'always',
#   'clean',
#   'up',
#   'after',
#   'the',
#   'kids'],
#  ['ll',
#   'what',
#   'several',
#   'others',
#   'have',
#   'said',
#   'it',
#   'works',
#   'well',
#   'but',
#   'it',
#   'really',
#   'should',
#   'have',
#   'wall',
#   'mountable',
#   'charging',
#   'setup',
#   'instead',
#   'you',
#   'have',
#   'to',
#   'fairly',
#   'large',
#   'area',
#   'of',
#   'shelf',
#   'space',
#   'to',
#   'the',
#   'saucer',
#   'shaped',
#   'charging',
#   'base',
#   'and',
#   'then',
#   'balance',
#   'the',
#   'vacuum',
#   'on',
#   'that',
#   'to',
#   'charge',
#   'it',
#   'say',
#   'balance',
#   'because',
#   'it',
#   'doesn',
#   'snap',
#   'onto',
#   'the',
#   'base',
#   'it',
#   'just',
#   'sits',
#   'on',
#   'it',
#   'this',
#   'is',
#   'actually',
#   'another',
#   'because',
#   'can',
#   'putting',
#   'it',
#   'on',
#   'shelf',
#   'in',
#   'the',
#   'garage',
#   'because',
#   'sure',
#   'as',
#   'anything',
#   'one',
#   'of',
#   'our',
#   'cats',
#   'would',
#   'go',
#   'to',
#   'and',
#   'knock',
#   'it',
#   'off',
#   'possibly',
#   'it',
#   'so',
#   'for',
#   'now',
#   'it',
#   'taking',
#   'up',
#   'space',
#   'in',
#   'my',
#   'home',
#   'office'],
#  ['okay',
#   'know',
#   'this',
#   'is',
#   'hand',
#   'held',
#   'and',
#   'the',
#   'battery',
#   'life',
#   'isn',
#   'supposed',
#   'to',
#   'be',
#   'any',
#   'good',
#   'but',
#   'really',
#   'expect',
#   'minutes',
#   'before',
#   'the',
#   'battery',
#   'dies',
#   'we',
#   've',
#   'only',
#   'had',
#   'ours',
#   'month',
#   'or',
#   'so',
#   'and',
#   'the',
#   'battery',
#   'dies',
#   'after',
#   'about',
#   'minute',
#   'of',
#   'use',
#   'could',
#   'be',
#   'that',
#   'the',
#   'battery',
#   'is',
#   'worn',
#   'down',
#   'from',
#   'constant',
#   'recharging',
#   'but',
#   'if',
#   'so',
#   'then',
#   'very',
#   'disappointed',
#   'as',
#   'the',
#   'description',
#   'an',
#   'charging',
#   'shut',
#   'off',
#   'when',
#   'it',
#   'full',
#   'charge',
#   'just',
#   'to',
#   'avoid',
#   'that',
#   'issue',
#   'don',
#   'waste',
#   'your',
#   'money'],
#  ['love',
#   'this',
#   'little',
#   'vacuum',
#   'bought',
#   'this',
#   'for',
#   'my',
#   'car',
#   'but',
#   'found',
#   'that',
#   'its',
#   'good',
#   'for',
#   'so',
#   'much',
#   'more',
#   'its',
#   'million',
#   'times',
#   'easier',
#   'to',
#   'reach',
#   'things',
#   'than',
#   'chord',
#   'extension',
#   'on',
#   'floor',
#   'vac',
#   'can',
#   'reach',
#   'up',
#   'high',
#   'with',
#   'it',
#   'its',
#   'easy',
#   'to',
#   'disassemble',
#   'and',
#   'clean',
#   'love',
#   'that',
#   'can',
#   'rinse',
#   'out',
#   'the',
#   'filter',
#   'so',
#   'easily',
#   'the',
#   'worst',
#   'part',
#   'about',
#   'vacuuming',
#   'is',
#   'this',
#   'little',
#   'chord',
#   'free',
#   'vac',
#   'is',
#   'the',
#   'best'],
#  ['this',
#   'item',
#   'really',
#   'sucks',
#   'the',
#   'recharging',
#   'stand',
#   'requires',
#   'the',
#   'unit',
#   'stand',
#   'upright',
#   'which',
#   'can',
#   'some',
#   'when',
#   'storing',
#   'prefer',
#   'the',
#   'old',
#   'design',
#   'that',
#   'was',
#   'cradle',
#   'that',
#   'hung',
#   'on',
#   'the',
#   'wall'],
#  ['this',
#   'month',
#   'after',
#   'placing',
#   'the',
#   'order',
#   'it',
#   'charges',
#   'fast',
#   'and',
#   'is',
#   'very',
#   'light',
#   'but',
#   'just',
#   'has',
#   'no',
#   'power',
#   'it',
#   'does',
#   'not',
#   'pick',
#   'anything',
#   'up',
#   'would',
#   'the',
#   'previous',
#   'model',
#   'that',
#   'is',
#   'blue',
#   'and',
#   'that',
#   'one',
#   'is',
#   'very',
#   'powerful',
#   'but',
#   'it',
#   'is',
#   'heavy',
#   'and',
#   'takes',
#   'long',
#   'long',
#   'time',
#   'to',
#   'charge',
#   'but',
#   'it',
#   'sucks',
#   'up',
#   'all',
#   'the',
#   'dust',
#   'and',
#   'everything',
#   'returned',
#   'this',
#   'new',
#   'green',
#   'one']]

# %%
print(corpus_clu0_wordlist)
# Out:
# [['went', 'from', 'dyson', 'to', 'this', 'black', 'and', 'decker', 'unit', 'looks', 'nice', 'and', 'holds', 'charge', 'well', 'the', 'whole', 'point', 'is', 'to', 'pick', 'stuff', 'up', 'and', 'this', 'unit', 'did', 'not', 'way', 'underpowered'], ['worked', 'great', 'until', 'last', 'month', 'but', 'doesn', 'charge', 'or', 'turn', 'on', 'now'], ['pretty', 'decent', 'suction', 'strength', 'and', 'battery', 'lasts', 'after', 'solid', 'minute', 'before', 'needing', 'recharge', 'we', 'can', 'have', 'product', 'sitting', 'for', 'weeks', 'and', 'it', 'still', 'has', 'solid', 'charge', 'filter', 'is', 'easy', 'to', 'clean', 'recommend'], ['have', 'needed', 'this', 'for', 'long', 'time', 'live', 'in', 'century', 'home', 'with', 'many', 'steps', 'and', 'was', 'dragging', 'my', 'huge', 'vacuum', 'up', 'and', 'down', 'in', 'order', 'to', 'clean', 'them', 'this', 'is', 'the', 'perfect', 'answer', 'and', 'is', 'so', 'light', 'yet', 'does', 'heavy', 'job', 'well'], ['this', 'is', 'how', 'hand', 'vacuum', 'should', 'work', 'with', 'great', 'battery', 'for', 'once', 'and', 'great', 'performance', 'the', 'rechargeable', 'unit', 'has', 'charging', 'base', 'the', 'simplest', 'have', 'ever', 'seen', 'or', 'used', 'round', 'flat', 'base', 'it', 'perfectly', 'fits', 'the', 'butt', 'end', 'of', 'the', 'vac', 'so', 'much', 'that', 'when', 'you', 'set', 'it', 'standing', 'up', 'on', 'the', 'base', 'you', 'can', 'twirl', 'the', 'unit', 'around', 'like', 'figure', 'skater', 'while', 'the', 'charging', 'goes', 'on', 'merrily', 'amazing', 'easy', 'and', 'innovative', 'imo'], ['works', 'well', 'but', 'is', 'very', 'bulky', 'on', 'the', 'counter', 'don', 'purchase', 'the', 'micro', 'vacuum', 'attachment', 'kit', 'that', 'is', 'displayed', 'as', 'purchased', 'together', 'it', 'doesn', 'fit', 'the', 'hand', 'vacuum', 'now', 'have', 'to', 'return', 'the', 'attachments'], ['ve', 'wanted', 'strong', 'hand', 'vac', 'for', 'while', 'and', 'this', 'one', 'is', 'perfect', 'for', 'my', 'needs', 'it', 'extremely', 'powerful', 'and', 'as', 'long', 'as', 'you', 're', 'okay', 'that', 'it', 'isn', 'wall', 'mounted', 'than', 'you', 'should', 'happy', 'the', 'one', 'irecieved', 'did', 'have', 'large', 'crack', 'along', 'the', 'plastic', 'but', 'amazon', 'quickly', 'replaced', 'it'], ['decent', 'vacuum', 'for', 'the', 'price', 'the', 'only', 'complaint', 'and', 'from', 'what', 'can', 'see', 'this', 'complaint', 'is', 'of', 'most', 'battery', 'powered', 'vacuums', 'is', 'the', 'battery', 'life', 'could', 'be', 'longer', 'proseasy', 'to', 'use', 'chargecomes', 'apart', 'and', 'empties', 'easilygood', 'power', 'with', 'full', 'chargeconswish', 'the', 'battery', 'life', 'was', 'longer'], ['works', 'great', 'very', 'powerful', 'extender', 'for', 'crevices', 'stays', 'extended', 'even', 'when', 'poking', 'around', 'considering', 'letting', 'the', 'kids', 'back', 'in', 'the', 'house', 'to', 'eat', 'on', 'trial', 'basis', 'now', 'will', 'suck', 'up', 'all', 'but', 'the', 'very', 'biggest', 'cockroaches'], ['handy', 'good', 'sucking', 'power', 'easy', 'to', 'use', 'and', 'clean', 'tested', 'it', 'sucking', 'power', 'on', 'carpet', 'and', 'hard', 'floor', 'works', 'good', 'on', 'both', 'surfaces', 'though', 'you', 'might', 'need', 'little', 'more', 'time', 'working', 'on', 'the', 'carpet', 'use', 'it', 'everyday', 'for', 'pet', 'hair', 'shorthair', 'cat', 'fast', 'charging', 'light', 'weight'], ['this', 'product', 'has', 'great', 'suction', 'and', 'performs', 'well', 'the', 'design', 'does', 'make', 'it', 'difficult', 'in', 'working', 'in', 'smaller', 'areas', 'true', 'design', 'failure', 'is', 'the', 'lock', 'devices', 'for', 'the', 'nozzle', 'these', 'do', 'not', 'catch', 'well', 'causing', 'portion', 'of', 'the', 'vacuum', 'to', 'fall', 'and', 'potentially', 'break'], ['not', 'as', 'powerful', 'as', 'expected', 'purchased', 'this', 'to', 'keep', 'in', 'my', 'car', 'to', 'combat', 'the', 'hair', 'of', 'my', 'ever', 'shedding', 'frenchies', 'the', 'unit', 'picks', 'up', 'some', 'but' ...

# %%
# 建立字典印出，有8585個不重複的字
dictionary = corpora.Dictionary(test_corpus)
print(dictionary)
# Out:
# Dictionary(8585 unique tokens: ['pea', 'deafening', 'breath', 'results', 'unwieldy']...)

# %%
# 看看字的ID號碼
print(dictionary.token2id)
# Out:
# {'pea': 2849, 'deafening': 2452, 'breath': 7220, 'results': 874, 'unwieldy': 5627, 'uncooked': 2097, 'pitiful': 7569, 'nozzleweird': 8519, 'folds': 2945, 'cat': 655, 'connection': 2541, 'purchases': 1519, 'tho': 1272, 'thinner': 6693, 'judgement': 3488, 'beg': 5402, 'retrieval': 4459, 'match': 2426, 'fault': 2419, 'precision': 4339, 'regretted': 6803, 'stockpiled': 6746, 'sandy': 3271, 'sits': 663, 'new': 12, 'traded': 7600, 'gave': 13, 'cut': 4177, 'little': 14, 'fully': 59, 'leap': 7457, 'wrist': 2067, 'champion': 7815, 'ergonomics': 4975, 'urged': 2398, 'finish': 1926, 'switch': 673, 'day': 23, 'predicted': 6315, 'integrated': 1954, 'reusable': 731, 'broken': 1649, 'taped': 3568, 'kudos': 5572, 'trapped': 2142, 'indicator': 1401, 'careless': 7521, 'sparking': 5850, 'mind': 895, 'parrot': 5675, 'fabricated': 4248, 'aisle': 4381, 'sometime': 3022, 'primary': 5501, 'scares': 861, 'beside': 4458,
 3376, 'occassionally': 6221, 'pls': 6133, 'cleanings': 2856, 'suprised': 5366, 'greet': 7637, 'finest': 4294, 'noisey': 7489, 'windtunnel': 7132, 'woodwork': 5980, 'from': 143, 'chargecomes': 6444, 'arrive': 1325, 'drying': 3090, 'isn': 1468, 'movement': 1222, 'partially': 3805, 'moist': 2877, 'cadmium': 151, 'put': 148, 'odd': 2144, 'flashed': 6804, 'verrryyy': 8421, 'beautifully': 3857, 'db': 2687, 'yikes': 7243, 'thwarting': 7726, 'dus ...

# %%
# 顯示各篇文章出現的字的ID跟次數
corpus0 = [dictionary.doc2bow(text) for text in corpus_clu0_wordlist]
corpus1 = [dictionary.doc2bow(text) for text in corpus_clu1_wordlist]
corpus2 = [dictionary.doc2bow(text) for text in corpus_clu2_wordlist]
corpus3 = [dictionary.doc2bow(text) for text in corpus_clu3_wordlist]
corpus4 = [dictionary.doc2bow(text) for text in corpus_clu4_wordlist]
corpus5 = [dictionary.doc2bow(text) for text in corpus_clu5_wordlist]
corpus6 = [dictionary.doc2bow(text) for text in corpus_clu6_wordlist]

#corpora.MmCorpus.serialize('/tmp/deerwester.mm', corpus)  # store to disk, for later use
print(corpus0)
# Out:
# [[(30, 1), (31, 1), (55, 3), (69, 1), (80, 1), (95, 1), (124, 2), (143, 1), (186, 1), (247, 1), (252, 1), (261, 1), (320, 1), (325, 2), (333, 1), (365, 1), (477, 2), (569, 1), (717, 1), (1427, 1), (1541, 1), (1593, 1), (2000, 1), (2343, 1), (3312, 1)], [(103, 1), (210, 1), (219, 1), (251, 1), (261, 1), (271, 1), (339, 1), (393, 1), (522, 1), (669, 1), (782, 1), (1138, 1)], [(9, 1), (34, 1), (55, 2), (79, 1), (86, 1), (124, 1), (138, 1), (160, 1), (176, 1), (235, 1), (242, 1), (247, 1), (261, 1), (269, 1), (282, 1), (297, 1), (319, 1), (340, 1), (341, 1), (352, 1), (524, 1), (577, 2), (643, 1), (705, 1), (815, 1), (834, 1), (1261, 1), (1269, 1), (1422, 1), (3122, 1)], [(26, 1), (32, 1), (42, 1), (55, 3), (69, 1), (74, 2), (79, 1), (80, 1), (117, 1), (124, 1), (231, 1), (247, 2), (254, 1), (282, 1), (291, 1), (325, 2), (326, 1), (333, 1), (335, 1), (340, 1), (361, 1), (403, 1), (420, 1), (437, 1), (440, 1), (495, 1), (563, 1), (617, 1), (735, 1), (904, 1), (1029, 1), (1339, 1), (2521, 1), (2787, 1), (2927, 1), (3485, 1)], [(9, 2), (21, 1), (26, 1), (55, 2), (61, 1), (79, 1), (80, 1), (88, 1), (103, 2), (117, 1), (126, 1), (135, 1), (138, 1), (154, 1), (187, 1), (208, 1), (213, 2), (221, 1), (234, 1), (241, 1), (242, 1), (247, 1), (251, 2), (290, 1), (297, 1), (318, 1), (325, 1), (326, 1), (333, 7), (340, 1), (341, 1), (366, 1), (393, 1), (405, 1), (409, 1), (410, 3), (460, 1), (477, 2), (498, 1), (517, 1), (518, 1), (521, 2), (901, 1), (963, 1), (1081, 1), (1082, 1), (1481, 
# %%
# TF-IDF一下
from gensim import corpora, models, similarities
tfidf0 = models.TfidfModel(corpus0)
tfidf1 = models.TfidfModel(corpus1)
tfidf2 = models.TfidfModel(corpus2)
tfidf3 = models.TfidfModel(corpus3)
tfidf4 = models.TfidfModel(corpus4)
tfidf5 = models.TfidfModel(corpus5)
tfidf6 = models.TfidfModel(corpus6)

corpus_tfidf0 = tfidf0[corpus0]
corpus_tfidf1 = tfidf1[corpus1]
corpus_tfidf2 = tfidf2[corpus2]
corpus_tfidf3 = tfidf3[corpus3]
corpus_tfidf4 = tfidf4[corpus4]
corpus_tfidf5 = tfidf5[corpus5]
corpus_tfidf6 = tfidf6[corpus6]

# %%
# 第0個群組有1564篇文章
print(tfidf0)
# Out:
# TfidfModel(num_docs=1542, num_nnz=9917)

# %%
# 第0個群組每篇文章出現的字的ID與TF-IDF值
for doc in corpus_tfidf0:
    print(doc)
# Out:
# [(30, 0.21108366977943274), (31, 0.19339914748450515), (55, 0.18132449102277587), (69, 0.10295334012585879), (80, 0.11777427378532825), (95, 0.1645396026249568), (124, 0.1610151926657854), (143, 0.20585907550432664), (186, 0.21108366977943274), (247, 0.0896376379346136), (252, 0.12329416257193955), (261, 0.12702330079163307), (320, 0.22424859591875987), (325, 0.1734761288754894), (333, 0.07618711682613243), (365, 0.13415687547494834), (477, 0.3290792052499136), (569, 0.2442353314500058), (717, 0.22424859591875987), (1427, 0.21711502123544463), (1541, 0.28722000614801024), (1593, 0.17000797548963748), (2000, 0.22424859591875987), (2343, 0.26009969593344906), (3312, 0.28722000614801024)]
# [(103, 0.2118527279620139), (210, 0.3591731376119851), (219, 0.32541756318651244), (251, 0.07026995031635225), (261, 0.1958257266169068), (271, 0.3102584789166987), (339, 0.17847297528845257), (393, 0.3457132979928422), (522, 0.2794458879691016), (669, 0.3591731376119851), (782, 0.28360748251041495), (1138, 0.37652588894043937)]
# [(9, 0.051694397064411694), (34, 0.18173461113521794), (55, 0.10916050791964363), (79, 0.07379329959579814), (86, 0.20250235221410853), (124, 0.07270046691583705), (138, 0.09141282886307593), (160, 0.1442517699737305), (176, 0.20250235221410853), (235, 0.18173461113521794), (242, 0.12114717034488946), (247, 0.08094513347700893), (261, 0.11470536567205357), (269, 0.07216647025422263), (282, 0.10157724250235463), (297, 0.11080653635747012), (319, 0.19606054754127267), (340, 0.11412135061415037), (341, 0.16140578385666055), (352, 0.08738693814984483), (524, 0.150154142694339), (577, 0.4697536679853216), (643, 0.2205508975866061), (705, 0.18173461113521794), (815, 0.1746444927396724), (834, 0.2205508975866061), (1261, 0.25936718403799425), (1269, 0.25936718403799425), (1422, 0.21038648394732734), (3122, 0.25936718403799425)]
# [(1319, 1.0)]
# [(9, 0.10161505795546293), (143, 0.36541380677311486), (187, 0.27133803789454874), (231, 0.2072532687698348), (240, 0.33725348494261415), (252, 0.2188554922241882), (664, 0.5098349711851106), (683, 0.24097270866795029), (4807, 0.5098349711851106)]
# [(252, 0.2301565997430671), (341, 0.33365656251052), (403, 0.3610235006241255), (683, 0.25341588960938344), (1311, 0.3434094561456415), (1372, 0.5361614744302079), (1839, 0.48553524645028595)]
# [(269, 0.33176479152322946), (312, 0.3119130674661924), (439, 0.29551974154920824), (595, 0.6695270174641141), (649, 0.5069950854689572)]
# [(325, 0.40742726066493434), (326, 0.45884599614319), (740, 0.7895969725691907)]
# [(269, 0.2599303199731825), (312, 0.24437693661844614), (1244, 0.934192775398966)]
# [(94, 0.4629925122984989), (365, 0.48394041720079994), (1032, 0.7425897966946758)]
# [(79, 0.27769232470926325), (252, 0.41897663199236135), (311, 0.8299573511824189), (439, 0.24190152926380065)]
# [(312, 0.7259257822585933), (439, 0.6877730429816579)]
# [(251, 1.0)]
# [(420, 1.0)]
# [(740, 1.0)]
# [(251, 1.0)]
# [(439, 1.0)]
# []
# [(117, 0.3090022338565833), (230, 0.5007184465719883), (241, 0.3602872215349339), (312, 0.19452590079008325), (325, 0.22456846086877508), (347, 0.5329777190849846), (513, 0.3894293337649557)]
# [(20, 0.4795571479753109), (213, 0.33381140793528363), (237, 0.32307423375379696), (320, 0.4403131048149826), (342, 0.6002851780367701)]
# [(9, 0.5569592273034412), (801, 0.8305398359630642)]
# [(9, 0.14689617530973195), (62, 0.575436076648925), (124, 0.20658758278699932), (247, 0.2300158468410541), (261, 0.32594982167475345), (1740, 0.667432266196862)]
# []
# [(3, 0.24086105679120476), (9, 0.0846558337048851), (242, 0.19839315842596075), (325, 0.12826952400789957), (447, 0.22991140075666297), (483, 0.304427425246484), (682, 0.42474516480124935), (740, 0.24858726356266497), (1245, 0.3611787963459701), (3879, 0.42474516480124935), (8573, 0.42474516480124935)]

# %%
# 看一下各群組前100個TF-IDF值較高的字
from collections import Counter

def get_top100_word(corpus_tfidf):
    d = {}
    for doc in corpus_tfidf:
        for id, value in doc:
            word = dictionary.get(id)
            d[word] = value
    d_val = Counter(d)
    return d_val.most_common(100)

# %%
# 第0群
get_top100_word(corpus_tfidf0)
# Out:
# [('goooooood', 1.0),
#  ('outstanding', 1.0),
#  ('flawless', 1.0),
#  ('sweet', 1.0),
#  ('functional', 1.0),
#  ('thanks', 1.0),
#  ('name', 1.0),
#  ('perfect', 1.0),
#  ('satisfied', 1.0),
#  ('okie', 1.0),
#  ('cool', 1.0),
#  ('amazing', 1.0),
#  ('aaa', 1.0),
#  ('wonderful', 1.0),
#  ('ok', 1.0),
#  ('fine', 1.0),
#  ('great', 1.0),
#  ('fantastic', 1.0),
#  ('beautiful', 1.0),
#  ('terrific', 1.0),
#  ('magnifica', 1.0),
#  ('excelent', 1.0),
#  ('fab', 1.0),
#  ('horrible', 1.0),
#  ('loooooove', 1.0),
#  ('good', 1.0),
#  ('vacc', 0.987640604597916),
#  ('prod', 0.987640604597916),
#  ('powerfull', 0.987640604597916),
#  ('products', 0.9849896105616027),
#  ('pickup', 0.9813942277320086),
#  ('vacume', 0.979961356950193),
#  ('worked', 0.9774703462137233),
#  ('luv', 0.9766257090450606),
#  ('performance', 0.9752978958546612),
#  ('cleaner', 0.9724079589191468),
#  ('okay', 0.9711144737255563),
#  ('wonders', 0.9674557969527721),
#  ('wonderfully', 0.9674557969527721),
#  ('handheld', 0.9674057457774122),
#  ('helpful', 0.9607196835141572),
#  ('deal', 0.9563546458552491),
#  ('low', 0.9558971287421328),
#  ('convenience', 0.9557955136425749),
#  ('soo', 0.9548282059412497),
#  ('perfectly', 0.9542530029658938),
#  ('stuff', 0.9531298628964352),
#  ('pets', 0.9508159626444127),
#  ('yes', 0.9444855951248265),
#  ('simply', 0.9415298506574814),
#  ('value', 0.940553517171602),
#  ('mild', 0.934192775398966),
#  ('vaccumn', 0.9288155991731024),
#  ('working', 0.9273140540028632),
#  ('suctions', 0.9252087046494658),
#  ('experience', 0.919412187280947),
#  ('scam', 0.9172392443845299),
#  ('substantial', 0.9092527443529853),
#  ('wireless', 0.9081432651764105),
#  ('wl', 0.9050541950833582),
#  ('handling', 0.9041327797578148),
#  ('adverdised', 0.9021207870515847),
#  ('adore', 0.8982379298320385),
#  ('awsome', 0.897648852384033),
#  ('dependable', 0.8965904409668893),
#  ('bad', 0.8927004975723108),
#  ('practical', 0.8924478403556126),
#  ('compact', 0.8923728380810884),
#  ('lil', 0.8923697744912265),
#  ('sucking', 0.8855825343677549),
#  ('features', 0.884100245559424),
#  ('nicely', 0.8840571797851992),
#  ('soooo', 0.8827652412733464),
#  ('medium', 0.8800571403825463),
#  ('vehicles', 0.8797132161099298),
#  ('now', 0.8787216754389171),
#  ('reliable', 0.8770260263863017),
#  ('suck', 0.875032878782524),
#  ('quality', 0.8747753392656801),
#  ('vaccuum', 0.8725383849623415),
#  ('beast', 0.8695434491816539),
#  ('service', 0.8676627461018154),
#  ('portable', 0.8625677582929159),
#  ('charm', 0.8613999085127708),
#  ('mom', 0.8582300502013338),
#  ('ver', 0.857910520259328),
#  ('pricy', 0.8484420653556616),
#  ('daily', 0.8423911268000671),
#  ('tool', 0.8407203340763276),
#  ('vaccum', 0.8402602556893627),
#  ('runtime', 0.838345844343192),
#  ('operated', 0.8366079249955208),
#  ('cute', 0.832297984046032),
#  ('love', 0.8305398359630642),
#  ('me', 0.8299573511824189),
#  ('guy', 0.8259793007867825),
#  ('vacum', 0.8243203225022668),
#  ('lovely', 0.8201555368486303),
#  ('investment', 0.8192730245168459),
#  ('isn', 0.8177610332759101)]

# %%
# 第1群
get_top100_word(corpus_tfidf1)
# Out:
# [('excepted', 0.8804789858972784),
#  ('powerfull', 0.8582406068678217),
#  ('boat', 0.8394615887223588),
#  ('cars', 0.8270571700836487),
#  ('win', 0.8254004799766426),
#  ('convient', 0.7976282223110767),
#  ('reasonable', 0.7877707581729749),
#  ('heaven', 0.7482336433788526),
#  ('stayed', 0.7435831614208315),
#  ('lasting', 0.7429707988994024),
#  ('extremely', 0.7388446743940255),
#  ('related', 0.7329145963619361),
#  ('yo', 0.7277937623700327),
#  ('hoped', 0.7271941205119491),
#  ('auto', 0.724247762634741),
#  ('expected', 0.719051149216724),
#  ('certainly', 0.7178468882604375),
#  ('kid', 0.7120269057199887),
#  ('effortlessly', 0.699122763084307),
#  ('likes', 0.698618775280372),
#  ('input', 0.6955598618117359),
#  ('didnt', 0.6913923691219939),
#  ('fabric', 0.6909017999344793),
#  ('retired', 0.6908883013613264),
#  ('anticipated', 0.6907901248702439),
#  ('mounting', 0.681046935242166),
#  ('ups', 0.6803297661321536),
#  ('periods', 0.6774146864027536),
#  ('saver', 0.6705058563911201),
#  ('supposedly', 0.669167133531965),
#  ('looking', 0.6687692581986735),
#  ('tho', 0.6661546865454256),
#  ('gifts', 0.6621771080288898),
#  ('decent', 0.6601745884753105),
#  ('replaceable', 0.6598161030425473),
#  ('devil', 0.6527801896256508),
#  ('holding', 0.6496428644388028),
#  ('keeps', 0.6495055371544592),
#  ('solidly', 0.648371020553398),
#  ('favorable', 0.6444872221194218),
#  ('satisfactory', 0.643870062264471),
#  ('breaker', 0.6434074648045498),
#  ('wearing', 0.6432125473430309),
#  ('enjoying', 0.641125969543135),
#  ('them', 0.6405126987295499),
#  ('adjust', 0.6392427159678092),
#  ('clogged', 0.63910571826496),
#  ('picked', 0.6378152977547196),
#  ('stays', 0.6336189945212872),
#  ('sale', 0.6334794019389622),
#  ('balanced', 0.6334677539377921),
#  ('noisier', 0.6312855684743369),
#  ('ruining', 0.6303880721876507),
#  ('com', 0.630159885950546),
#  ('plural', 0.6299583359650959),
#  ('beyond', 0.6298197312529831),
#  ('tools', 0.6274276332294131),
#  ('mites', 0.6257520606959965),
#  ('greatest', 0.6245304028383353),
#  ('brands', 0.6210891906241683),
#  ('hopefully', 0.6208603133402264),
#  ('pulled', 0.6188676534320764),
#  ('scratch', 0.6177397977861505),
#  ('reliably', 0.6129812689944241),
#  ('method', 0.6116226018122849),
#  ('count', 0.6115579740230126),
#  ('spent', 0.6106247481373153),
#  ('upkeep', 0.6094258102196924),
#  ('snap', 0.6092645733425437),
#  ('complete', 0.6069800284515444),
#  ('fair', 0.6052009940509476),
#  ('favorite', 0.6047834077440892),
#  ('tighten', 0.6042088603131944),
#  ('cares', 0.603111130290455),
#  ('snazzy', 0.6029449924807008),
#  ('sturdy', 0.6027605987990653),
#  ('crap', 0.602599476734233),
#  ('expectation', 0.6003431087245509),
#  ('grones', 0.5980261280635113),
#  ('minus', 0.5973994007397774),
#  ('promised', 0.5965143711220207),
#  ('dumps', 0.5958160300806413),
#  ('reaches', 0.594697684523653),
#  ('expect', 0.5940779733285676),
#  ('research', 0.5935305080768079),
#  ('altho', 0.5919801955168703),
#  ('et', 0.5913423020988534),
#  ('distance', 0.5892267459501404),
#  ('batter', 0.5868784197909535),
#  ('satisfied', 0.584520573251496),
#  ('tightly', 0.5843172763899895),
#  ('operates', 0.5831854375133272),
#  ('often', 0.5825672822541846),
#  ('dos', 0.5825096053518999),
#  ('needing', 0.5821687528966345),
#  ('grandson', 0.5794300801135315),
#  ('recharging', 0.5788569762919701),
#  ('side', 0.576487483370756),
#  ('receive', 0.5762444635012354),
#  ('cheaply', 0.5762186441752879)]

# %%
# 第2群
get_top100_word(corpus_tfidf2)
# Out:
# [('surprisingly', 0.9618103486693386),
#  ('terrible', 0.961647289869093),
#  ('wonderful', 0.936000152255378),
#  ('neded', 0.89914569152472),
#  ('friend', 0.873222706915547),
#  ('stairway', 0.8607488444243313),
#  ('reassemble', 0.8423119392013964),
#  ('pos', 0.8421922644701987),
#  ('deliver', 0.840005937075474),
#  ('秋charge', 0.827987501625858),
#  ('promised', 0.8216723861798478),
#  ('stronger', 0.8167449667086971),
#  ('asked', 0.8160001216626976),
#  ('term', 0.8123391440529835),
#  ('comes', 0.8068251952392379),
#  ('garbage', 0.7905651174868441),
#  ('replicable', 0.7857492429120695),
#  ('exceeds', 0.7839577661830431),
#  ('rv', 0.7829301111013791),
#  ('waste', 0.7668956964706415),
#  ('truck', 0.7629027528048666),
#  ('shipping', 0.762585657076571),
#  ('wicked', 0.7557486069351925),
#  ('wath', 0.7521977240976199),
#  ('aftwr', 0.7507159481493757),
#  ('equipment', 0.7502293882528042),
#  ('parakeet', 0.7499497231557141),
#  ('frustrating', 0.7492508416547161),
#  ('job', 0.7467663794907666),
#  ('mess', 0.740231343269594),
#  ('preferred', 0.7370730775100423),
#  ('tad', 0.7292998340059941),
#  ('clever', 0.7291590760246968),
#  ('flimsy', 0.719369355119454),
#  ('littler', 0.7191706437778448),
#  ('described', 0.7179910834560299),
#  ('august', 0.7161135407382019),
#  ('needed', 0.7159200905861595),
#  ('moths', 0.7150331487705451),
#  ('cycle', 0.7146118912122907),
#  ('provides', 0.7114819468134018),
#  ('glad', 0.7082801314148417),
#  ('aswell', 0.7081016203644432),
#  ('appearance', 0.7073924672860135),
#  ('effective', 0.7038329449863082),
#  ('target', 0.7010372601688821),
#  ('batter', 0.7000671882341489),
#  ('third', 0.6989432054402329),
#  ('keeps', 0.696773656797783),
#  ('machine', 0.6963111400614979),
#  ('useful', 0.6934205870684931),
#  ('fantastic', 0.6929019446737494),
#  ('overly', 0.692792287443195),
#  ('balance', 0.6927790253196383),
#  ('dandy', 0.6925383373808844),
#  ('came', 0.6914555909053667),
#  ('ergonomic', 0.6868554079174978),
#  ('caps', 0.6866237784954361),
#  ('sucker', 0.6862854782350357),
#  ('steadily', 0.6856196504460639),
#  ('orked', 0.6837943255933709),
#  ('exactly', 0.6834512093423016),
#  ('pickups', 0.6803855141490558),
#  ('rug', 0.6797022889059033),
#  ('considerable', 0.676419985136901),
#  ('day', 0.6761061399576077),
#  ('lightweight', 0.6739638583980001),
#  ('initial', 0.671809923141453),
#  ('fabulous', 0.6714979430946199),
#  ('traeger', 0.6676952966686338),
#  ('arrive', 0.6664519687375497),
#  ('spot', 0.6646230858951077),
#  ('elegant', 0.6629351668057438),
#  ('color', 0.6627525575607706),
#  ('slightly', 0.6622981918605975),
#  ('singapore', 0.6600843371109295),
#  ('missing', 0.6589203627442641),
#  ('rips', 0.6557077710400535),
#  ('canister', 0.6532932979088855),
#  ('weird', 0.6532692098656885),
#  ('loft', 0.6532376290900891),
#  ('does', 0.6525715255064607),
#  ('cranny', 0.6511699255019059),
#  ('convenient', 0.6511151079842303),
#  ('accomplished', 0.6507366986596193),
#  ('receommend', 0.6483116055362198),
#  ('collected', 0.6482079660590055),
#  ('assembly', 0.6477568040060065),
#  ('useless', 0.6468202832014741),
#  ('terriffic', 0.6459875918884977),
#  ('dissapointed', 0.6452471866643179),
#  ('insane', 0.6447434571214228),
#  ('enough', 0.6429447291814365),
#  ('duster', 0.6429271748568016),
#  ('arrived', 0.6426806814083793),
#  ('chasing', 0.6424545310206545),
#  ('exceded', 0.6399704788803834),
#  ('cats', 0.6391157729945518),
#  ('stopped', 0.6380602176754046),
#  ('mostly', 0.6364495849907789)]

# %%
# 第3群
get_top100_word(corpus_tfidf3)
# Out:
# [('vaccum', 0.8604345283750235),
#  ('potent', 0.8281382404419279),
#  ('adore', 0.8104152455985515),
#  ('grit', 0.7936667135927897),
#  ('noisey', 0.7820464298075162),
#  ('thinks', 0.7808524155237481),
#  ('minuets', 0.7800858551293288),
#  ('lightweight', 0.7789424006886289),
#  ('garbage', 0.7475471483227575),
#  ('tools', 0.7415814207667214),
#  ('winner', 0.739120560603869),
#  ('helper', 0.7254736232239102),
#  ('snout', 0.720949247748061),
#  ('fuss', 0.7194313328644346),
#  ('wireless', 0.7120505448451728),
#  ('unavoidable', 0.7034641416738354),
#  ('plenty', 0.698747376804005),
#  ('nothinggood', 0.6982311889939895),
#  ('guy', 0.6935264574258817),
#  ('goodi', 0.684660561554242),
#  ('bettery', 0.6788073703987212),
#  ('day', 0.67645417952003),
#  ('every', 0.6663048985505658),
#  ('average', 0.6660018085417762),
#  ('cars', 0.664058488633396),
#  ('critique', 0.6535404377579844),
#  ('alright', 0.6507403550819609),
#  ('lil', 0.6483935283613066),
#  ('versatility', 0.645931823324942),
#  ('grabbing', 0.6447928622903728),
#  ('gives', 0.640472926853466),
#  ('shorter', 0.6399177255713838),
#  ('shmoo', 0.6375482686675682),
#  ('ability', 0.6354722062077676),
#  ('costs', 0.6309881579791242),
#  ('changed', 0.6273696626291659),
#  ('sliced', 0.6270691305367903),
#  ('outstanding', 0.6266652522225682),
#  ('sweeper', 0.624674393322972),
#  ('nossel', 0.6223596798227478),
#  ('heard', 0.6217971670230802),
#  ('condition', 0.6157173249164875),
#  ('touchups', 0.6156537183879622),
#  ('depleted', 0.6154261481260632),
#  ('feeling', 0.6142879214734192),
#  ('teenager', 0.6081988901167409),
#  ('unplugged', 0.6080654251182386),
#  ('performance', 0.6074184808535624),
#  ('handvac', 0.6064253265340883),
#  ('ain', 0.6051082360899216),
#  ('hoping', 0.6048796689427796),
#  ('gadget', 0.6037106486978205),
#  ('says', 0.6033319998619601),
#  ('lasting', 0.6032743047057494),
#  ('cheerios', 0.6028540565638079),
#  ('anybody', 0.6024900331908746),
#  ('quicket', 0.6018984615657696),
#  ('mother', 0.5982515163148163),
#  ('puppy', 0.5971722147657107),
#  ('promising', 0.596040788788179),
#  ('lower', 0.5959215896912574),
#  ('warned', 0.5952706908566051),
#  ('julyawful', 0.5944601700508453),
#  ('amazingly', 0.5931222684669519),
#  ('rapidly', 0.5874435371183574),
#  ('otherwise', 0.5867297290075084),
#  ('succioning', 0.58634588698754),
#  ('weak', 0.5857141440289783),
#  ('savor', 0.5833118265869653),
#  ('fuzz', 0.5825804202893229),
#  ('cads', 0.5823826268459441),
#  ('handvacs', 0.5823233361209975),
#  ('tuck', 0.5789816161467405),
#  ('consecutive', 0.5769807629347656),
#  ('rechargable', 0.5762144936884309),
#  ('sears', 0.576074301387921),
#  ('hairy', 0.5759406042069805),
#  ('banister', 0.5748326066670061),
#  ('min', 0.5736639358276959),
#  ('wild', 0.5724737304804891),
#  ('vacuume', 0.5694931095438308),
#  ('likes', 0.5694331952101993),
#  ('cooler', 0.5671196382353091),
#  ('jsut', 0.5634716209117457),
#  ('perform', 0.5631623302531475),
#  ('duration', 0.5618767649288763),
#  ('pet', 0.5618556318407251),
#  ('being', 0.5616992548582863),
#  ('kick', 0.5565866005020228),
#  ('tend', 0.5554781205432732),
#  ('minivan', 0.5538505843872416),
#  ('making', 0.5530472353879334),
#  ('spiders', 0.5506684933425164),
#  ('wonderful', 0.5498435094945),
#  ('couch', 0.5484439793169871),
#  ('con', 0.5475224066226043),
#  ('ears', 0.5475066670926909),
#  ('built', 0.5467130356979063),
#  ('littler', 0.5454357562882939),
#  ('able', 0.5448016245848732)]

# %%
# 第4群
get_top100_word(corpus_tfidf4)
# Out:
# [('nice', 1.0),
#  ('excellent', 1.0),
#  ('fantastic', 1.0),
#  ('loved', 0.98674171597762),
#  ('absolutely', 0.9718983713072512),
#  ('ergonomic', 0.9474798211566522),
#  ('useful', 0.9433332411048242),
#  ('satisfied', 0.9427779894443394),
#  ('sleek', 0.9284623247747702),
#  ('extremely', 0.9280694269115839),
#  ('nothing', 0.917086574626626),
#  ('love', 0.9134980587393524),
#  ('greatvsuction', 0.9063789917782651),
#  ('lost', 0.9044789239470482),
#  ('outstanding', 0.9030872440806503),
#  ('ship', 0.9017842206044019),
#  ('pretty', 0.9006076705511321),
#  ('terrible', 0.8908090356255728),
#  ('experience', 0.8844507155972754),
#  ('advertised', 0.8807923310191728),
#  ('bulky', 0.8784305721552584),
#  ('awesome', 0.8752824020122452),
#  ('detailing', 0.8745473186628706),
#  ('champ', 0.8722743672711579),
#  ('thank', 0.8678916010415612),
#  ('powerhouse', 0.8608025784250505),
#  ('complaints', 0.8606403737035164),
#  ('investment', 0.8579629048705004),
#  ('advertized', 0.8567714828573267),
#  ('van', 0.8502318776712683),
#  ('unused', 0.8406861923054734),
#  ('problems', 0.8406754000713306),
#  ('mobile', 0.8385472450659851),
#  ('well', 0.8379332610383201),
#  ('travel', 0.8375471345104584),
#  ('maintain', 0.8349165635086881),
#  ('wonderful', 0.8325664505923235),
#  ('loses', 0.8309399836641753),
#  ('delivery', 0.8289655850124412),
#  ('john', 0.8275943976618974),
#  ('enjoy', 0.827274673244282),
#  ('slick', 0.8241309492810888),
#  ('spills', 0.8231678429688524),
#  ('yes', 0.8217959845567795),
#  ('tool', 0.8215182285892917),
#  ('lots', 0.8141197310029165),
#  ('weaker', 0.8121666541975385),
#  ('rather', 0.8115110009511691),
#  ('sweet', 0.8073743871951341),
#  ('beast', 0.8055736924454745),
#  ('anticipated', 0.8052984074465579),
#  ('word', 0.8030428099799858),
#  ('quieter', 0.8014596708889399),
#  ('practical', 0.7961162245519263),
#  ('outdoor', 0.7942276958150061),
#  ('heavier', 0.7927265979967378),
#  ('mucho', 0.7926912551325052),
#  ('market', 0.789827903912563),
#  ('lol', 0.7861284752652969),
#  ('imo', 0.7851560828575048),
#  ('amount', 0.7849788836797802),
#  ('lasting', 0.7840060013156355),
#  ('superb', 0.7822922639484752),
#  ('transaction', 0.7822234921757647),
#  ('performs', 0.7818329248413654),
#  ('awsome', 0.7773058315792389),
#  ('ha', 0.7772410427666937),
#  ('fan', 0.775926786574563),
#  ('brought', 0.7754000235205151),
#  ('splendid', 0.7713713760153751),
#  ('gud', 0.7703599893876789),
#  ('bandit', 0.7694356858939637),
#  ('husband', 0.7685141369757911),
#  ('pickup', 0.767637391674964),
#  ('garage', 0.7638146057860465),
#  ('dont', 0.7621064547502076),
#  ('guy', 0.762027504215554),
#  ('nicer', 0.7611406038594111),
#  ('range', 0.7610742047119833),
#  ('treat', 0.7561300442064095),
#  ('drain', 0.7546366671298373),
#  ('sold', 0.7524242548238345),
#  ('efficient', 0.7520618488404355),
#  ('awhile', 0.7512122104832465),
#  ('powa', 0.7504180398450839),
#  ('wanted', 0.7497449890696734),
#  ('complain', 0.7484854002143435),
#  ('system', 0.747167355245378),
#  ('stray', 0.7466627354128174),
#  ('effecient', 0.7443881630354242),
#  ('buy', 0.7442445330291099),
#  ('min', 0.7441861283625604),
#  ('date', 0.7425353609023065),
#  ('vacume', 0.7424807371032969),
#  ('workshop', 0.74146568459282),
#  ('office', 0.739521667295489),
#  ('shipping', 0.7386001360481076),
#  ('said', 0.7342768300922478),
#  ('operated', 0.7329038209645886),
#  ('promised', 0.7327380538842985)]

# %%
# 第5群
get_top100_word(corpus_tfidf5)
# Out:
# [('recharger', 0.6884026896519645),
#  ('attachmt', 0.5968024835589804),
#  ('stink', 0.5960122583370295),
#  ('min', 0.5914437772678641),
#  ('mountable', 0.5872403678987289),
#  ('picks', 0.5725109559554181),
#  ('handy', 0.5644761392996149),
#  ('nine', 0.5443780013675074),
#  ('van', 0.530630107888652),
#  ('volt', 0.5254846659063424),
#  ('litter', 0.5216038705321384),
#  ('fur', 0.5201260309223099),
#  ('cage', 0.5130800009491199),
#  ('overnight', 0.5118226333371005),
#  ('spout', 0.5114045456585579),
#  ('blemish', 0.4953908839348756),
#  ('platform', 0.4929357750052917),
#  ('net', 0.4923700398347856),
#  ('category', 0.4803508214070327),
#  ('folding', 0.47242464358575564),
#  ('equals', 0.46519406799368834),
#  ('vehicle', 0.462118436775721),
#  ('change', 0.4608590525199945),
#  ('price', 0.459552000162939),
#  ('beware', 0.4586921769410948),
#  ('stove', 0.45856579668571085),
#  ('pellet', 0.45856579668571085),
#  ('absolutely', 0.4461282998331951),
#  ('tray', 0.4426416252773846),
#  ('air', 0.43427819307506),
#  ('agitator', 0.43316835501151396),
#  ('thorough', 0.43280472599750014),
#  ('devil', 0.428436722577216),
#  ('flash', 0.42798577405381677),
#  ('bare', 0.42603952494154756),
#  ('bother', 0.4224074584583254),
#  ('mom', 0.4177904837261569),
#  ('painfully', 0.416841856073674),
#  ('cloud', 0.416841856073674),
#  ('dying', 0.41590333956331726),
#  ('bd', 0.41467281686017965),
#  ('string', 0.41284953655662565),
#  ('trimmer', 0.41284953655662565),
#  ('fell', 0.41101746179407167),
#  ('fiddly', 0.40974541015657917),
#  ('suffix', 0.4073308978543854),
#  ('tumble', 0.4066885879301869),
#  ('weeds', 0.4066885879301869),
#  ('superior', 0.4062110683573159),
#  ('door', 0.40582019407572584),
#  ('third', 0.40152168888475853),
#  ('seen', 0.4004958565631532),
#  ('vents', 0.4004480769968811),
#  ('applying', 0.3999176514191735),
#  ('mechanical', 0.397431165957735),
#  ('dc', 0.39721080541971904),
#  ('shredded', 0.39239644291600484),
#  ('powerless', 0.39239644291600484),
#  ('loving', 0.3921385197189817),
#  ('seem', 0.39023189695652705),
#  ('tilts', 0.3900780325688155),
#  ('jammed', 0.3886014488381688),
#  ('nossel', 0.38858196657420513),
#  ('child', 0.38800860932771775),
#  ('modest', 0.3874884961460186),
#  ('reference', 0.3868342124920201),
#  ('trap', 0.3865548951585984),
#  ('experienced', 0.38617669553498196),
#  ('advertised', 0.3825630531441846),
#  ('fabrics', 0.38227403001253857),
#  ('litihum', 0.37866789548347873),
#  ('generation', 0.3769503581276253),
#  ('odd', 0.3763002445218423),
#  ('coming', 0.3763002445218423),
#  ('marked', 0.37601976020496236),
#  ('ruining', 0.3752632631902147),
#  ('windowsills', 0.3710503059739842),
#  ('drawers', 0.3710503059739842),
#  ('projects', 0.3704760361678821),
#  ('dryer', 0.36660391280239646),
#  ('cad', 0.3658025778163958),
#  ('directions', 0.3652694477761103),
#  ('screwing', 0.36519228923398245),
#  ('weight', 0.36488750084326466),
#  ('condition', 0.3644018288358242),
#  ('balance', 0.3644018288358242),
#  ('ipod', 0.36347993319513944),
#  ('ratings', 0.36308459411854493),
#  ('smart', 0.36308459411854493),
#  ('sale', 0.36289725480685886),
#  ('seat', 0.3609769286209),
#  ('appear', 0.36094504063605143),
#  ('manufactures', 0.36094504063605143),
#  ('saver', 0.36037587541212174),
#  ('finer', 0.35924732042904384),
#  ('gently', 0.35924732042904384),
#  ('kinda', 0.3592437178953506),
#  ('deficiencies', 0.35797356085308396),
#  ('peters', 0.35707723927557355),
#  ('needles', 0.3558393011709309)]

# %%
# 第6群
get_top100_word(corpus_tfidf6)
# Out:
# [('conviniet', 0.7995443128381331),
#  ('nimh', 0.6103297150527794),
#  ('cd', 0.5810101589175123),
#  ('chord', 0.5642986569906727),
#  ('procedure', 0.5589495111835322),
#  ('satisfactory', 0.5241094621095366),
#  ('brief', 0.5241094621095366),
#  ('pricy', 0.5219375122969369),
#  ('dyson', 0.5100928444857641),
#  ('replied', 0.504969027778966),
#  ('allow', 0.5021895175293652),
#  ('cannister', 0.5010558318549484),
#  ('soda', 0.49503370411423653),
#  ('upper', 0.4947498220824641),
#  ('shock', 0.4945192287530431),
#  ('dad', 0.49412877162484314),
#  ('portable', 0.4937795395269972),
#  ('lid', 0.49056613951022443),
#  ('workhorse', 0.4864913992997028),
#  ('excellent', 0.4845052248586074),
#  ('inlet', 0.47565890854991427),
#  ('durable', 0.47565890854991427),
#  ('feb', 0.4713212994625085),
#  ('grandchildren', 0.4653010719305335),
#  ('hearth', 0.4596997401103869),
#  ('wireless', 0.45900643682057035),
#  ('cheaper', 0.4530704282071458),
#  ('handful', 0.44405111741788544),
#  ('stink', 0.44401956792465314),
#  ('baking', 0.43918721171935643),
#  ('accessibility', 0.4360417011671817),
#  ('staple', 0.43223901890706995),
#  ('fence', 0.43160859434043525),
#  ('styles', 0.4301649033327919),
#  ('silly', 0.4283207716747573),
#  ('vacumn', 0.4257808867398891),
#  ('downstairs', 0.4257808867398891),
#  ('smooth', 0.4243667990840881),
#  ('drops', 0.424106826575967),
#  ('whim', 0.42254615010915336),
#  ('sooooo', 0.42254615010915336),
#  ('fills', 0.4225060636223358),
#  ('disclaimer', 0.4213900434911353),
#  ('finished', 0.41872813721349783),
#  ('moveable', 0.41589383382748385),
#  ('dish', 0.41280882229392785),
#  ('rabbit', 0.4090440463804855),
#  ('ergonomically', 0.4085269476706679),
#  ('orient', 0.4081686364386113),
#  ('version', 0.40787588558021126),
#  ('batter', 0.40337041477984426),
#  ('sets', 0.4031202980163442),
#  ('crevices', 0.4025135468456725),
#  ('hopeful', 0.40110449629465444),
#  ('sux', 0.40110449629465444),
#  ('preschooler', 0.3992607961496837),
#  ('limits', 0.39837719356301937),
#  ('scatter', 0.39837719356301937),
#  ('questionable', 0.39802660047359684),
#  ('parrots', 0.3973415907420385),
#  ('wth', 0.3973415907420385),
#  ('folding', 0.39640394800454637),
#  ('pellets', 0.39640394800454637),
#  ('family', 0.39594937754157294),
#  ('nearly', 0.3935864529203445),
#  ('whatsoever', 0.39212847945145685),
#  ('amounts', 0.3915490168151007),
#  ('sight', 0.39153652356101554),
#  ('stored', 0.3908837956417554),
#  ('ceiling', 0.3904518169142252),
#  ('beautiful', 0.38685030400432485),
#  ('environment', 0.38685030400432485),
#  ('moldy', 0.3830324373375826),
#  ('hope', 0.3830035339521019),
#  ('hates', 0.3825175702290229),
#  ('blunt', 0.38147310434173853),
#  ('sounding', 0.3793666819062172),
#  ('sexual', 0.3793666819062172),
#  ('lowered', 0.37849888070227583),
#  ('prehistoric', 0.37849888070227583),
#  ('adjustable', 0.3775911561055307),
#  ('creases', 0.3775911561055307),
#  ('cereal', 0.37671976916967354),
#  ('maintain', 0.3757973557613323),
#  ('dirty', 0.37462832958607317),
#  ('cause', 0.3741816813807165),
#  ('difficulty', 0.3741816813807165),
#  ('helds', 0.37385155133692183),
#  ('quits', 0.37291042939549557),
#  ('gradually', 0.37291042939549557),
#  ('dealbreaker', 0.3725219088823939),
#  ('passes', 0.37114544201580424),
#  ('kids', 0.37065629102773456),
#  ('registry', 0.3705669774802086),
#  ('meals', 0.36958480888270184),
#  ('pickup', 0.36958480888270184),
#  ('irritates', 0.3689753884067165),
#  ('lol', 0.3689753884067165),
#  ('reassemble', 0.3689753884067165),
#  ('minor', 0.3687738002780568)]

# %%
# 試一下NLTK
import nltk
from nltk.corpus import treebank

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
print(corpus_clu0_wordlist[1])
# Out:
# ['worked', 'great', 'until', 'last', 'month', 'but', 'doesn', 'charge', 'or', 'turn', 'on', 'now']

# %%
# 標籤詞性
tagged = nltk.pos_tag(corpus_clu0_wordlist[1])

# %%
tagged[0:]
# Out:
# [('worked', 'VBN'),
#  ('great', 'JJ'),
#  ('until', 'IN'),
#  ('last', 'JJ'),
#  ('month', 'NN'),
#  ('but', 'CC'),
#  ('doesn', 'JJ'),
#  ('charge', 'NN'),
#  ('or', 'CC'),
#  ('turn', 'VB'),
#  ('on', 'IN'),
#  ('now', 'RB')]

# %%
entities = nltk.chunk.ne_chunk(tagged)

# %%
print(entities)
# Out:
# (S
#   worked/VBN
#   great/JJ
#   until/IN
#   last/JJ
#   month/NN
#   but/CC
#   doesn/JJ
#   charge/NN
#   or/CC
#   turn/VB
#   on/IN
#   now/RB)

# %%
# 試一下StanfordDependencyParser
from nltk.parse.stanford import StanfordDependencyParser
import os

# %%
# 載入環境變數
os.environ["JAVA_HOME"] = "C:/Program Files/Java/jdk1.8.0_111" 
os.environ["CLASSPATH"] = "C:/Users/lisrba/Documents/StanfordNLP/StanfordNLP/jars"
os.environ["STANFORD_MODELS"] = "C:/Users/lisrba/Documents/StanfordNLP/StanfordNLP/models"

# %%
# 簡單測試
eng_parser = StanfordDependencyParser()
res = list(eng_parser.parse("the quick brown fox jumps over the lazy dog".split()))
for row in res[0].triples():
    print(row)
# Out:
# (('fox', 'NN'), 'det', ('the', 'DT'))
# (('fox', 'NN'), 'amod', ('quick', 'JJ'))
# (('fox', 'NN'), 'amod', ('brown', 'JJ'))
# (('fox', 'NN'), 'dep', ('jumps', 'NNS'))
# (('jumps', 'NNS'), 'nmod', ('dog', 'NN'))
# (('dog', 'NN'), 'case', ('over', 'IN'))
# (('dog', 'NN'), 'det', ('the', 'DT'))
# (('dog', 'NN'), 'amod', ('lazy', 'JJ'))

# %%
# 拿評論測試
eng_parser = StanfordDependencyParser()
res = list(eng_parser.parse(corpus_clu0_wordlist[111]))
for row in res[0].triples():
    print(row)
# Out:
# (('been', 'VBN'), 'nsubj', ('it', 'PRP'))
# (('been', 'VBN'), 'aux', ('has', 'VBZ'))
# (('been', 'VBN'), 'advcl', ('charges', 'VBZ'))
# (('charges', 'VBZ'), 'mark', ('while', 'IN'))
# (('charges', 'VBZ'), 'advcl', ('bought', 'VBD'))
# (('bought', 'VBD'), 'nsubj', ('that', 'WDT'))
# (('bought', 'VBD'), 'dobj', ('this', 'DT'))
# (('bought', 'VBD'), 'cc', ('but', 'CC'))
# (('bought', 'VBD'), 'conj', ('love', 'VBP'))
# (('love', 'VBP'), 'dobj', ('it', 'PRP'))
# (('charges', 'VBZ'), 'nsubj', ('it', 'PRP'))
# (('charges', 'VBZ'), 'advmod', ('well', 'RB'))
# (('charges', 'VBZ'), 'cc', ('and', 'CC'))
# (('charges', 'VBZ'), 'conj', ('stays', 'VBZ'))
# (('stays', 'VBZ'), 'nsubj', ('charge', 'NN'))
# (('charge', 'NN'), 'amod', ('quick', 'JJ'))
# (('stays', 'VBZ'), 'xcomp', ('good', 'JJ'))
# (('good', 'JJ'), 'cc', ('but', 'CC'))
# (('good', 'JJ'), 'conj', ('not', 'RB'))
# (('good', 'JJ'), 'dep', ('long', 'JJ'))
# (('long', 'JJ'), 'advmod', ('too', 'RB'))
# (('been', 'VBN'), 'cc', ('and', 'CC'))
# (('been', 'VBN'), 'conj', ('sucks', 'VBZ'))
# (('sucks', 'VBZ'), 'advmod', ('best', 'RB'))
# (('best', 'RB'), 'advmod', ('well', 'RB'))
# (('sucks', 'VBZ'), 'nmod', ('spaces', 'NNS'))
# (('spaces', 'NNS'), 'case', ('for', 'IN'))
# (('spaces', 'NNS'), 'amod', ('small', 'JJ'))
# (('spaces', 'NNS'), 'cc', ('and', 'CC'))
# (('spaces', 'NNS'), 'conj', ('bathroom', 'NN'))

# %%
review_list = []
def stanford_parser(corpus_clu_wordlist):
    for i in range(len(corpus_clu_wordlist)):
         review_list.append(eng_parser.parse(corpus_clu_wordlist[i]))
    return review_list;

# %%
review_list = stanford_parser(corpus_clu0_wordlist)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-72-be03cb68a81e> in <module>()
# ----> 1 review_list = stanford_parser(corpus_clu0_wordlist)
#
# <ipython-input-70-2bb891891850> in stanford_parser(corpus_clu_wordlist)
#       2 def stanford_parser(corpus_clu_wordlist):
#       3     for i in range(len(corpus_clu_wordlist)):
# ----> 4          review_list.append(eng_parser.parse(corpus_clu_wordlist[i]))
#       5     return review_list;
#
# C:\Users\lisrba\Anaconda3\lib\site-packages\nltk\parse\api.py in parse(self, sent, *args, **kwargs)
#      43         """
#      44         if overridden(self.parse_sents):
# ---> 45             return next(self.parse_sents([sent], *args, **kwargs))
#      46         elif overridden(self.parse_one):
#      47             return (tree for tree in [self.parse_one(sent, *args, **kwargs)] if tree is not None)
#
# StopIteration:

# %%
for i in range(len(review_list)):
    for row in review_list[i].triples():
        print(row)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-dde33aa58f8c> in <module>()
#       1 for i in range(len(review_list)):
# ----> 2     for row in review_list[i].triples():
#       3         print(row)
#
# AttributeError: 'list_iterator' object has no attribute 'triples'

# %% [markdown]
# http://stackoverflow.com/questions/7443330/how-do-i-do-dependency-parsing-in-nltk

# %% [markdown]
# http://www.nltk.org/_modules/nltk/parse/stanford.html
